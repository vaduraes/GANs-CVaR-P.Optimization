# %%
import datetime as dt
import gc
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import pandas as pd
import geopandas as gpd
import imageio
from pathlib import Path

#####--
import numpy as np
from numpy import expand_dims
from numpy import ones
from numpy import zeros
from numpy.random import rand
from numpy.random import randint
from numpy.random import randn
from numpy.random import randint
import numpy.random as random

#Keras and tensorflow
import keras
import tensorflow as tf
import torch
from keras.models import load_model

from keras.datasets.cifar10 import load_data
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM, TimeDistributed, RepeatVector
from keras.layers import Conv2D,BatchNormalization
from keras.layers import MaxPooling2D
from keras.layers import Conv2DTranspose
from keras.layers import Flatten
from keras.layers import Dropout,Cropping2D
from keras.layers import LeakyReLU
from keras.layers import Reshape
from keras.callbacks import ModelCheckpoint, Callback
from keras.constraints import Constraint
from keras.layers import Lambda
from keras.utils.vis_utils import plot_model
from keras.models import Model
from keras import backend
from tensorflow.keras import Input
from tensorflow.keras.optimizers import Adam, RMSprop
from tensorflow.keras.layers import Multiply
from tensorflow_addons.image import translate as translate_tf


### 
from scipy.ndimage import affine_transform
from scipy.ndimage import rotate

### 
from scipy.ndimage import affine_transform
from scipy.ndimage import rotate

import tensorflow as tf
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
  tf.config.experimental.set_memory_growth(gpu, True)

# %%
def PlotData_Stage1(Scenario,Tech,EnergyPu):
  ShapeFileCoast="/home/victor-duraes/Projects/Ocean2/GANs/GEO_data/ne_10m_coastline.shp"
  ShapeFileStates="/home/victor-duraes/Projects/Ocean2/GANs/GEO_data/ne_10m_admin_1_states_provinces_lines.shp"
  X_LAT=np.zeros((int(len(Lat)*len(Long))),dtype=float)
  Y_LONG=np.zeros((int(len(Lat)*len(Long))),dtype=float)

  min_latitude=np.min(Lat)
  max_latitude=np.max(Lat)

  min_longitude=np.min(Long)
  max_longitude=np.max(Long)

  xlim =[min_longitude,max_longitude]
  ylim=[min_latitude, max_latitude]

  df = gpd.read_file(ShapeFileCoast)
  df1 = gpd.read_file(ShapeFileStates)

  fig, ax = plt.subplots(figsize  = None)
  df.plot(color='black',linewidth=1,ax=ax)
  df1.plot(color='black',linewidth=1,ax=ax)

  count=0
  for I_lat in range(len(Lat)):
    for I_long in range(len(Long)):

      Y_LONG[count]=Lat[I_lat]
      X_LAT[count]=Long[I_long]
      count=count+1

  plt.scatter(X_LAT,Y_LONG,c=(EnergyPu[Scenario,:,:,Tech]), s=5, cmap='jet')
  plt.colorbar()
  ax.set_xlim(xlim)
  ax.set_ylim(ylim)

  return plt.show()

NPZ_Data=np.load("/home/victor-duraes/Projects/Ocean2/GANs/AggregatedData_Daily.npz", allow_pickle=True) 
EnergyPu=NPZ_Data["EnergyPu"]
Lat=NPZ_Data["Lat"]
Long=NPZ_Data["Long"]
EnergyPu=NPZ_Data["EnergyPu"]
StartYear=NPZ_Data["StartYear"]
EndYear=NPZ_Data["EndYear"]
WindEnergy_RatedPower=float(NPZ_Data["WindEnergy_RatedPower"])
WaveEnergy_RatedPower=float(NPZ_Data["WaveEnergy_RatedPower"])
OceanEnergy_RatedPower=float(NPZ_Data["OceanEnergy_RatedPower"])

NPZ_Data_Yearly=np.load("/home/victor-duraes/Projects/Ocean2/GANs/AggregatedData_Daily.npz", allow_pickle=True) 
EnergyPu_Yearly=NPZ_Data_Yearly["EnergyPu"]

Idx_Exclude=np.max(EnergyPu_Yearly[:,:,:,1],axis=0)<=0.001
EnergyPu[:,Idx_Exclude,:]=0

Idx_Exclude_Ocean=np.max(EnergyPu_Yearly[:,:,:,2],axis=0)<=0.05
EnergyPu[:,Idx_Exclude_Ocean,2]=0
    
#EnergyPu=np.round(EnergyPu*255)#Put data in image format for convenience
#Extend data 25x25> 26x26 to improve in the padding

Idx_Exclude=np.max(EnergyPu_Yearly[:,:,:,1],axis=0)>0.05

Idx_Exclude_Ocean=np.max(EnergyPu_Yearly[:,:,:,2],axis=0)>0.05
Idx_Exclude_Ocean=np.reshape(Idx_Exclude_Ocean*1,(25,25,1))

Idx_Exclude=np.reshape(Idx_Exclude*1,(25,25,1))
Idx_Exclude=np.repeat(Idx_Exclude,2,axis=2)

Idx_Exclude=np.concatenate((Idx_Exclude,Idx_Exclude_Ocean),axis=2)

PlotData_Stage1(1,2,EnergyPu)

min=np.mean(EnergyPu,axis=0)
MaxMin=1
EnergyPu=(EnergyPu-min)

# %%
#Function to smooth zeros points
XY=np.zeros((25,25,2),dtype=float)

for x in range(25):
    for y in range(25):
        XY[x,y,0]=x
        XY[x,y,1]=y

def distance_matrix(x0, y0, x1, y1):
    obs = np.vstack((x0, y0)).T
    interp = np.vstack((x1, y1)).T

    d0 = np.subtract.outer(obs[:,0], interp[:,0])
    d1 = np.subtract.outer(obs[:,1], interp[:,1])

    return np.hypot(d0, d1)

EnergyPu_tmp=np.copy(EnergyPu)
for t in range(3):
    for x in range(25):
        for y in range(25):
            if Idx_Exclude[x,y,t]==0:
                z=EnergyPu[:,Idx_Exclude[:,:,t]==1,t]
                xy=XY[Idx_Exclude[:,:,t]==1,:]
                d=distance_matrix(xy[:,0], xy[:,1], x, y)
                weights = 1.0 / d**3
                weights  /= weights.sum(axis=0)
                for i in range(z.shape[0]):
                    EnergyPu_tmp[i,x,y,t]=np.dot(weights[:,0], z[i])
                    
EnergyPu=EnergyPu_tmp

# %%
def MAKE_GIF (GENERATOR, latent_dim_G, TrainData,ImageShape,number=0):
  for j in range(1):
    X_gan = generate_latent_points(latent_dim_G, 3)
    FakeImage=GENERATOR.predict(X_gan)*MaxMin+min

    IDX_REAL=random.randint(0, 2000)

    RealImage=TrainData[IDX_REAL,:,:,:]

    count=0
    X_LAT=np.zeros((int(len(Lat)*len(Long))),dtype=float)
    Y_LONG=np.zeros((int(len(Lat)*len(Long))),dtype=float)

    for I_lat in range(len(Lat)):
      for I_long in range(len(Long)):

        Y_LONG[count]=Lat[I_lat]
        X_LAT[count]=Long[I_long]
        count=count+1

    min_longitude=-77
    max_longitude=-74.5

    min_latitude=34
    max_latitude=36.5
    xlim =[min_longitude,max_longitude]
    ylim=[min_latitude, max_latitude]

    ShapeFileCoast="/home/victor-duraes/Projects/Ocean2/GANs/GEO_data/ne_10m_coastline.shp"
    ShapeFileStates="/home/victor-duraes/Projects/Ocean2/GANs/GEO_data/ne_10m_admin_1_states_provinces_lines.shp"

    df = gpd.read_file(ShapeFileCoast)
    df1 = gpd.read_file(ShapeFileStates)

    Real_FLAT=np.zeros((int(RealImage.shape[0]*RealImage.shape[1]),RealImage.shape[2]))
    Fake_FLAT=np.zeros((int(RealImage.shape[0]*RealImage.shape[1]),RealImage.shape[2]))

    for i in range(RealImage.shape[2]):
      Real_FLAT[:,i]=np.reshape(TrainData[random.randint(0, 2000),:,:,2],-1)
      Fake_FLAT[:,i]=np.reshape(FakeImage[i,:,:,2],-1)

    print("Processing Figure "+str(j))
    fig, axs = plt.subplots(RealImage.shape[2], 2)

    for i in range(RealImage.shape[2]):

      z1_plot=axs[i,0].scatter(X_LAT,Y_LONG,c=Real_FLAT[:,i], s=0.3, cmap='jet')
      df.plot(color='black',linewidth=1,ax=axs[i,0])
      df1.plot(color='black',linewidth=1,ax=axs[i,0])
      axs[i,0].set_xlim(xlim)
      axs[i,0].set_ylim(ylim)
      axs[0,0].set_title('Real Data', fontsize=10)

      axs[i,0].set_xlabel('Longitude', fontsize=10)
      axs[i,0].set_ylabel('Latitude', fontsize=10)


      if i<=1: 
        axs[i,0].get_xaxis().set_visible(False)

      clb=fig.colorbar(z1_plot, ax=axs[i,0])

      z2_plot =axs[i,1].scatter(X_LAT,Y_LONG,c=Fake_FLAT[:,i], s=0.3, cmap='jet')
      df.plot(color='black',linewidth=1,ax=axs[i,1])
      df1.plot(color='black',linewidth=1,ax=axs[i,1])


      if i==0:
        clb.ax.set_title('CF', fontsize=8)
      axs[i,1].set_xlim(xlim)
      axs[i,1].set_ylim(ylim)

      axs[i,1].set_xlabel('Longitude', fontsize=10)
      axs[i,1].set_ylabel('Latitude', fontsize=10)

      if i<=1: 
        axs[i,1].get_xaxis().set_visible(False)

      clb=fig.colorbar(z1_plot, ax=axs[i,1])

      if i==0:
        clb.ax.set_title('CF', fontsize=8)

      if i<=1: 
        axs[i,1].get_xaxis().set_visible(False)
      axs[0,1].set_title('Fake Data', fontsize=10)

    

    plt.savefig('/home/victor-duraes/Projects/Ocean2/GANs/Plots/Iteration'+str(number)+'.png',dpi=200)
    plt.close()

# %%
def MMD(x, y, kernel="rbf"):
    """Emprical maximum mean discrepancy. The lower the result
       the more evidence that distributions are the same.

    Args:
        x: first sample, distribution P
        y: second sample, distribution Q
        kernel: kernel type such as "multiscale" or "rbf"
    """
    device = torch.device("cpu")
    x.to(device)
    y.to(device)

    xx, yy, zz = torch.mm(x, x.t()), torch.mm(y, y.t()), torch.mm(x, y.t())
    rx = (xx.diag().unsqueeze(0).expand_as(xx))
    ry = (yy.diag().unsqueeze(0).expand_as(yy))

    dxx = rx.t() + rx - 2. * xx 
    dyy = ry.t() + ry - 2. * yy 
    dxy = rx.t() + ry - 2. * zz 

    dxx=dxx.to(device)
    dyy=dyy.to(device)
    dxy=dxy.to(device)

    XX, YY, XY = (torch.zeros(xx.shape).to(device),
                  torch.zeros(xx.shape).to(device),
                  torch.zeros(xx.shape).to(device))

    if kernel == "multiscale":
        
        bandwidth_range = [0.2, 0.5, 0.9, 1.3]
        for a in bandwidth_range:
            XX += a**2 * (a**2 + dxx)**-1
            YY += a**2 * (a**2 + dyy)**-1
            XY += a**2 * (a**2 + dxy)**-1
            
    if kernel == "rbf":
      
        bandwidth_range = [10, 15, 20, 50]
        for a in bandwidth_range:
            XX += torch.exp(-0.5*dxx/a)
            YY += torch.exp(-0.5*dyy/a)
            XY += torch.exp(-0.5*dxy/a)
     
    return torch.mean(XX + YY - 2. * XY)

# %%
# implementation of wasserstein loss
def wasserstein_loss(y_true, y_pred):
	return backend.mean(y_true * y_pred)

# clip model weights to a given hypercube
class ClipConstraint(Constraint):
	# set clip value when initialized
	def __init__(self, clip_value):
		self.clip_value = clip_value
 
	# clip model weights to hypercube
	def __call__(self, weights):
		return backend.clip(weights, -self.clip_value, self.clip_value)
 
	# get the config
	def get_config(self):
		return {'clip_value': self.clip_value}

# %%
def Augmentation_Layer(in_shape=[25,25,3]):
    x                = Input(shape=(25,25,3,))

    p                = Input(shape=(6,))#Apply Transformation
    InvP             = Lambda(lambda p: 1. - p)(p) #Not Apply Transformation

    x_shape=x.shape[2]
    y_shape=x.shape[1]
    
    #Reflect Image Reflect image in all directions to assure that minimize the effect of distortions
    ImageFlip_x      = tf.image.flip_left_right(x)
    x_flat           = tf.keras.layers.Reshape((x.shape[1],x.shape[2],x.shape[3]))(x)
    x_temp           = tf.keras.backend.stack([ImageFlip_x, x_flat, ImageFlip_x],axis=2)
    x_temp           = tf.keras.layers.Reshape((y_shape,x_shape*3,3))(x_temp)

    ImageFlip_y      = tf.image.flip_up_down(x_temp)
    x_temp           = tf.keras.backend.stack([ImageFlip_y, x_temp, ImageFlip_y],axis=1)
    x_reflected      = tf.keras.layers.Reshape((y_shape*3,x_shape*3,3))(x_temp)
    y=x_reflected

    #Augmentation 1: Flip-x
    y_temp_1         = tf.keras.layers.RandomFlip(mode="horizontal")(y,training=True)
    y                = tf.keras.layers.Add()([tf.keras.layers.Multiply()([y_temp_1,p[:,0]]), tf.keras.layers.Multiply()([y,InvP[:,0]])]) #Differentiable equation to define if the change will be propagated or not

    #Augmentation 2: 90 Rotations
    K                = Lambda(lambda m: tf.keras.backend.round(tf.squeeze(tf.keras.backend.random_uniform([1],minval=1,maxval=4.1))))(x) 
    K                = tf.cast(K,tf.int32)
    y_temp_2         = tf.image.rot90(y, k=K) #90, 180, 270 degrees
    y                = tf.keras.layers.Add()([tf.keras.layers.Multiply()([y_temp_2, p[:,1]]), tf.keras.layers.Multiply()([y, InvP[:,1]])]) #Differentiable equation to define if the change will be propagated or not

    #Augmentation 3: Translation (will not show outside traning)
    y_temp_3         = tf.keras.layers.experimental.preprocessing.RandomTranslation(0.1, 0.1)(y,training=True)
    y                = tf.keras.layers.Add()([tf.keras.layers.Multiply()([y_temp_3, p[:,2]]), tf.keras.layers.Multiply()([y, InvP[:,2]])]) #Differentiable equation to define if the change will be propagated or not

    #Augmentation 4: Arbitrary Rotation
    y_temp_4         = tf.keras.layers.experimental.preprocessing.RandomRotation(0.5)(y,training=True) #https://docs.w3cub.com/tensorflow~2.3/keras/layers/experimental/preprocessing/randomrotation
    y                = tf.keras.layers.Add()([tf.keras.layers.Multiply()([y_temp_4,p[:,3]]), tf.keras.layers.Multiply()([y,InvP[:,3]])]) #Differentiable equation to define if the change will be propagated or not

    #Augmentation 5: Isotropic Scaling
    y_temp_5         = tf.keras.layers.RandomZoom(0.1)(y,training=True)
    y                = tf.keras.layers.Add()([tf.keras.layers.Multiply()([y_temp_5,p[:,4]]), tf.keras.layers.Multiply()([y,InvP[:,4]])]) #Differentiable equation to define if the change will be propagated or not

    #Augmentation 6: Anisotropic Scaling
    y_temp_6         = tf.keras.layers.RandomZoom(0.1,0.1)(y,training=True)
    y                = tf.keras.layers.Add()([tf.keras.layers.Multiply()([y_temp_6,p[:,5]]), tf.keras.layers.Multiply()([y,InvP[:,5]])]) #Differentiable equation to define if the change will be propagated or not

    #Reduce shape to the Original Size (Last Step)
    y=tf.keras.layers.CenterCrop(25, 25)(y)

    model=Model(inputs=[x,p], outputs=y)
    return model

# %%
Idx_Exclude1=np.ones((25,25,3))
def G_Create_CNN(latent_dim_G,Idx_Exclude=Idx_Exclude1, in_shape=(25,25,3)):
  
  x = Input(shape=(latent_dim_G,),name="Image")
  #Layer1

  n_nodes = 512* 4 * 4 # foundation for 4x4 image

  y=Dense(n_nodes)(x)
  y=BatchNormalization()(y)
  y=LeakyReLU(alpha=0.2)(y)
  y=Reshape((4, 4, 512))(y)

  y=Conv2DTranspose(512, (3,3), strides=(2,2), padding='same')(y)
  y=BatchNormalization()(y)
  y=LeakyReLU(alpha=0.2)(y)

  y=Conv2DTranspose(512, (3,3), strides=(1,1), padding='same')(y)
  y=BatchNormalization()(y)
  y=LeakyReLU(alpha=0.2)(y)

  #Layer2
  y=Conv2DTranspose(256, (3,3), strides=(2,2), padding='same')(y)
  y=BatchNormalization()(y)
  y=LeakyReLU(alpha=0.2)(y)

  y=Conv2DTranspose(256, (3,3), strides=(1,1), padding='same')(y)
  y=BatchNormalization()(y)
  y=LeakyReLU(alpha=0.2)(y)

  #Layer3
  y=Conv2DTranspose(256, (3,3), strides=(2,2), padding='same')(y)
  y=BatchNormalization()(y)
  y012=LeakyReLU(alpha=0.2)(y)


  #Layer 0
  y0=Conv2DTranspose(128, (3,3), strides=(1,1), padding='same')(y012)
  y0=BatchNormalization()(y0)
  y0=LeakyReLU(alpha=0.2)(y0)

  y0=Conv2D(1, (3,3), activation='tanh', padding='same')(y0)
  y0=Cropping2D(cropping=((4, 3), (4, 3)))(y0)

  #Layer 1
  y1=Conv2DTranspose(128, (3,3), strides=(1,1), padding='same')(y012)
  y1=BatchNormalization()(y1)
  y1=LeakyReLU(alpha=0.2)(y1)

  y1=Conv2D(1, (3,3), activation='tanh', padding='same')(y1)
  y1=Cropping2D(cropping=((4, 3), (4, 3)))(y1)

  #Layer 2
  y2=Conv2DTranspose(128, (3,3), strides=(1,1), padding='same')(y012)
  y2=BatchNormalization()(y2)
  y2=LeakyReLU(alpha=0.2)(y2)

  y2=Conv2D(1, (3,3), activation='tanh', padding='same')(y2)
  y2=Cropping2D(cropping=((4, 3), (4, 3)))(y2)

  # # upsample to 40x60
  # y=Conv2DTranspose(128, (3,3), strides=(1,1), padding='same')(y)
  # y=BatchNormalization()(y)
  # y=LeakyReLU(alpha=0.2)(y)


  # # output layer
  # y=Conv2D(3, (3,3), activation='tanh', padding='same')(y)
  # y=Cropping2D(cropping=((4, 3), (4, 3)))(y)

  y=tf.concat([y0,y1,y2], axis=3)
  y=Lambda(lambda InputLayer: InputLayer*Idx_Exclude,input_shape=in_shape)(y)
  model=Model(x, y)

  opt = Adam(learning_rate=0.0000002, beta_1=0.5)
  model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])

  return model

# use the generator to generate n fake examples
def generate_fake_samples(GENERATOR, latent_dim_G, n_samples):
  x_input = generate_latent_points(latent_dim_G, n_samples)

  # predict outputs
  X = GENERATOR.predict(x_input)

  # create 'fake' class labels (0)
  y = zeros((n_samples, 1))
  return X, y

def generate_latent_points(latent_dim_G, n_samples):
  x_input = randn(latent_dim_G * n_samples)
  x_input = x_input.reshape(n_samples, latent_dim_G)

  return x_input

# %%
# define the standalone generator model (CNN)
# define the standalone discriminator model
AugmentModel=Augmentation_Layer(in_shape=[25,25,3])
AugmentModel.__name__="Augmentation"
def D_Create_CNN(in_shape=(25,25,3),AugmentModel=AugmentModel):

  # Layer1
  x = Input(shape=(in_shape[0],in_shape[1],in_shape[2],),name="Image")
  p = Input(shape=(6,),name="Maskp")
  y = Lambda(AugmentModel)((x,p))

  y=Conv2D(64, (3,3), padding='same', input_shape=in_shape)(y)
  y=LeakyReLU(alpha=0.2)(y)
  
  y=Conv2D(128, (3,3), padding='same')(y)
  y=LeakyReLU(alpha=0.2)(y)
  
  y=Conv2D(128, (3,3), strides=(2,2), padding='same')(y)
  y=LeakyReLU(alpha=0.2)(y)

  # # Layer2 
  y=Conv2D(256, (3,3), strides=(1,1), padding='same')(y)
  y=LeakyReLU(alpha=0.2)(y)

  y=Conv2D(256, (3,3), strides=(2,2), padding='same')(y)
  y=LeakyReLU(alpha=0.2)(y)

  ##Layer3
  y=Conv2D(512, (3,3), strides=(1,1), padding='same')(y)
  y=LeakyReLU(alpha=0.2)(y)

  y=Conv2D(512, (3,3), strides=(2,2), padding='same')(y)
  y=LeakyReLU(alpha=0.2)(y)

  # #Layer4
  y=Flatten()(y)
  y=Dense(1, activation='sigmoid')(y)
  opt = Adam(learning_rate=0.0000002, beta_1=0.5)

  model = Model((x,p), y)
  model.compile(loss='binary_crossentropy', optimizer=opt,metrics=['accuracy'])

  return model
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-36dd24afe370> in <module>
#       1 # define the standalone generator model (CNN)
#       2 # define the standalone discriminator model
# ----> 3 AugmentModel=Augmentation_Layer(in_shape=[25,25,3])
#       4 AugmentModel.__name__="Augmentation"
#       5 def D_Create_CNN(in_shape=(25,25,3),AugmentModel=AugmentModel):
#
# NameError: name 'Augmentation_Layer' is not defined

# %%
D.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Image (InputLayer)              [(None, 100)]        0
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 8192)         827392      Image[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 8192)         32768       dense_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 8192)         0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# reshape_3 (Reshape)             (None, 4, 4, 512)    0           leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 8, 8, 512)    2359808     reshape_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 8, 8, 512)    2048        conv2d_transpose[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 8, 8, 512)    0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 8, 8, 512)    2359808     leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 8, 8, 512)    2048        conv2d_transpose_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, 8, 8, 512)    0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 16, 16, 256)  1179904     leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 16, 16, 256)  1024        conv2d_transpose_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)      (None, 16, 16, 256)  0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 16, 16, 256)  590080      leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 16, 16, 256)  1024        conv2d_transpose_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)      (None, 16, 16, 256)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 32, 32, 256)  590080      leaky_re_lu_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 32, 32, 256)  1024        conv2d_transpose_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)      (None, 32, 32, 256)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_5 (Conv2DTrans (None, 32, 32, 128)  295040      leaky_re_lu_12[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_6 (Conv2DTrans (None, 32, 32, 128)  295040      leaky_re_lu_12[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_7 (Conv2DTrans (None, 32, 32, 128)  295040      leaky_re_lu_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 32, 32, 128)  512         conv2d_transpose_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 32, 32, 128)  512         conv2d_transpose_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 32, 32, 128)  512         conv2d_transpose_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)      (None, 32, 32, 128)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)      (None, 32, 32, 128)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)      (None, 32, 32, 128)  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 1)    1153        leaky_re_lu_13[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 32, 32, 1)    1153        leaky_re_lu_14[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 32, 32, 1)    1153        leaky_re_lu_15[0][0]
# __________________________________________________________________________________________________
# cropping2d (Cropping2D)         (None, 25, 25, 1)    0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# cropping2d_1 (Cropping2D)       (None, 25, 25, 1)    0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# cropping2d_2 (Cropping2D)       (None, 25, 25, 1)    0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# tf.concat (TFOpLambda)          (None, 25, 25, 3)    0           cropping2d[0][0]
#                                                                  cropping2d_1[0][0]
#                                                                  cropping2d_2[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 25, 25, 3)    0           tf.concat[0][0]
# ==================================================================================================
# Total params: 8,837,123
# Trainable params: 8,816,387
# Non-trainable params: 20,736
# __________________________________________________________________________________________________

# %%
def GAN_MODEL(GENERATOR,latent_dim_G, DISCRIMINATOR):
	# make weights in the discriminator not trainable
  DISCRIMINATOR.trainable = False

  x= Input(shape=(latent_dim_G,),name='GansLatentD')
  y= GENERATOR(x)
  p= Input(shape=(6,),name='MaskP')
  
  y = DISCRIMINATOR([y,p])

  model=Model((x,p),y)

  opt = Adam(learning_rate=0.0000002, beta_1=0.5)
  model.compile(loss='binary_crossentropy', optimizer=opt,metrics=['accuracy'])
  return model

# %%
class KerasBatchGenerator(object):

    def __init__(self, data, batch_size, ImageShape):
        self.data = data
        self.ImageShape=ImageShape #[x, y, # of chanels]
        self.batch_size = batch_size
        # this will track the progress of the batches sequentially through the
        # data set - once the data reaches the end of the data set it will reset
        # back to zero
        self.current_idx = 0

    def generate(self):
        x = np.zeros((self.batch_size, self.ImageShape[0], self.ImageShape[1], self.ImageShape[2]),dtype=float)
        y = np.zeros((self.batch_size, 1),dtype=float)
        while True:
            for i in range(self.batch_size):
                if self.current_idx>= len(self.data):
                    # reset the index back to the start of the data set
                    self.current_idx = 0
                x[i,:,:,:] = self.data[self.current_idx]
                # convert all of temp_y into a one hot representation
                y[i, 0] = 1
                self.current_idx += 1
            yield x, y

# %%
def train(GENERATOR, DISCRIMINATOR, GAN, latent_dim_G, TrainData, batch_size, NumEpochs,ImageShape):
  Prob_Limit=0 #% of time the augmentation is applied
  bat_per_epo = int(TrainData.shape[0] / (batch_size/2))+1
  half_batch = int(batch_size / 2)
  train_data_generator=KerasBatchGenerator (TrainData, half_batch, ImageShape)

  KID=[]
  KID_A=0
  BestKID=999
  count_Extra=1

  dR_hist_L, dF_hist_L, g_hist_L, dR_hist_A, dF_hist_A, g_hist_A, g_hist_AS = list(), list(), list(), list(), list(), list(), list()
  # manually enumerate epochs

  count_p_update=0
  for i in range(NumEpochs):
    if i!=0 and i%5==0:
      MAKE_GIF (GENERATOR, latent_dim_G, TrainData, ImageShape, number=i)
      DISCRIMINATOR.save("/home/victor-duraes/Projects/Ocean2/GANs/SaveStep/DISCRIMINATOR_W_V0"+str(i)+".hdf5")
      GENERATOR.save("/home/victor-duraes/Projects/Ocean2/GANs/SaveStep/GENERATOR_W_V0"+str(i)+".hdf5")
      GAN.save("/home/victor-duraes/Projects/Ocean2/GANs/SaveStep/GAN_W_V0"+str(i)+".hdf5")
      np.savez("/home/victor-duraes/Projects/Ocean2/GANs/SaveStep/PerformanceTrack.npz", dR_hist_L=dR_hist_L, dF_hist_L=dF_hist_L, g_hist_L=g_hist_L, dR_hist_A=dR_hist_A, dF_hist_A=dF_hist_A,g_hist_A=g_hist_AS, KID=KID)
      x_torch=torch.from_numpy(np.reshape(TrainData,(TrainData.shape[0],-1))).double()
      y_gan, _ = generate_fake_samples(GENERATOR, latent_dim_G, TrainData.shape[0])
      y_torch=torch.from_numpy(np.reshape(y_gan,(y_gan.shape[0],-1))).double()
      KID_A=MMD(x_torch, y_torch, kernel="rbf")

    for j in range(bat_per_epo):
      
#-------------------------------------------------------------------------------      
      # update discriminator model weights (Real Exmples)
      X_TD,y_TD=next(train_data_generator.generate()) #Get real examples
      p_r=np.random.random((X_TD.shape[0],6))    
      p_r=(p_r<=Prob_Limit)*1# If 1 we appy the augmentation, if 0 we do not apply the augmentation
      history_DR = DISCRIMINATOR.train_on_batch((X_TD,p_r),y_TD, return_dict=True)

      D_lossR = history_DR['loss']
      D_AC_R = history_DR['accuracy']
      dR_hist_L.append(D_lossR)
      dR_hist_A.append(D_AC_R)

#-------------------------------------------------------------------------------
      # update discriminator model weights (Fake Exmples)
      X_fake, y_fake = generate_fake_samples(GENERATOR, latent_dim_G, half_batch)
      p_f=np.random.random((X_fake.shape[0],6))    
      p_f=(p_f<=Prob_Limit)*1# If 1 we appy the augmentation, if 0 we do not apply the augmentation
      history_DF = DISCRIMINATOR.train_on_batch((X_fake,p_f), y_fake, return_dict=True)

      D_lossF = history_DF['loss']
      D_AC_F = history_DF['accuracy']
      dF_hist_L.append(D_lossF)
      dF_hist_A.append(D_AC_F)

#-------------------------------------------------------------------------------
      for k in range(count_Extra):#count_Extra
        # prepare points in latent space as input for the generator (update the generator via the discriminator's error)
        X_gan = generate_latent_points(latent_dim_G, batch_size)
        y_gan = ones((batch_size, 1))
        p_f_g=np.random.random((X_gan.shape[0],6))    
        p_f_g=(p_f_g<=Prob_Limit)*1# If 1 we appy the augmentation, if 0 we do not apply the augmentation
        history_G = GAN.train_on_batch((X_gan,p_f_g), y_gan, return_dict=True)
        G_loss = history_G['loss']
        G_AC = history_G['accuracy']
        g_hist_A.append(G_AC)


      g_hist_L.append(G_loss)
      g_hist_AS.append(G_AC)
      
      KID.append(KID_A)

#-------------------------------------------------------------------------------      
      # summarize loss on this batch
      print('>%d, %d/%d, DReal=%.3f, DFake=%.3f G_Joker=%.3f-------- DR_AC=%.3f, DF_AC=%.3f G_AC=%.3f \nProb_Limit: %.2f ,KID= %.5f, Extra =%d'  % (i+1, j+1, bat_per_epo, D_lossR, D_lossF, G_loss, D_AC_R, D_AC_F, G_AC, Prob_Limit, KID[-1], count_Extra))	
      
#-------------------------------------------------------------------------------   
      #Update "p" every 4 minibatches as in the original paper      
      count_p_update+=1     	

      if count_p_update==4:
        count_p_update=0
        AverageAccuracy_Discriminator=dF_hist_A[-4:] + dR_hist_A[-4:] #concatenate accuracy of the discriminator for fake and real iamges
        AverageAccuracy_Discriminator=np.mean(AverageAccuracy_Discriminator)

        AverageAccuracy_Generator=g_hist_A[-4:] #concatenate accuracy of the discriminator for fake and real iamges
        AverageAccuracy_Generator=np.mean(AverageAccuracy_Generator)

        if AverageAccuracy_Generator<=0.3: #Value suggested by the paper

          count_Extra=np.minimum(8,count_Extra+1)
        
        if AverageAccuracy_Generator>=0.7:
 
          count_Extra=np.maximum(1,count_Extra-1)


        if AverageAccuracy_Discriminator>=0.6: #Value suggested by the paper
          Prob_Limit=np.minimum(0.8,Prob_Limit+0.01) #Too precise need better gradients. More augmentation
        else:
          Prob_Limit=np.maximum(0,Prob_Limit-0.01)


  return dR_hist_L, dF_hist_L, g_hist_L, dR_hist_A, dF_hist_A, KID


def plot_history(dR_hist_L, dF_hist_L, g_hist_L,dR_hist_A, dF_hist_A):
  # plot loss
  plt.plot(dR_hist_L, label='d-real')
  plt.plot(dF_hist_L, label='d-fake')
  plt.plot(g_hist_L, label='gen')
  plt.legend()

  # save plot to file
  plt.show()
  plt.savefig('/home/victor-duraes/Projects/Ocean2/GANs/Plots/plot_line_plot_loss.png')
  plt.close()

  # plot loss
  plt.plot(dR_hist_A, label='d-real')
  plt.plot(dF_hist_A, label='d-fake')
  plt.legend()

  # save plot to file
  plt.show()
  plt.savefig('/home/victor-duraes/Projects/Ocean2/GANs/Plots/plot_line_plot_accuracy.png')
  plt.close()

# %%
import tensorflow as tf

latent_dim_G=100 #40
batch_size=64#64/2
NumEpochs=10000
ImageShape=EnergyPu.shape[1:]
TrainData=EnergyPu

DISCRIMINATOR=D_Create_CNN(in_shape=ImageShape)
DISCRIMINATOR._name="Discriminator"

GENERATOR=G_Create_CNN(latent_dim_G)
GENERATOR._name="Generator"

GAN=GAN_MODEL(GENERATOR, latent_dim_G, DISCRIMINATOR)

dR_hist_L, dF_hist_L, g_hist_L, dR_hist_A, dF_hist_A, KID=train(GENERATOR, DISCRIMINATOR, GAN, latent_dim_G, TrainData, batch_size, NumEpochs,ImageShape)

plot_history(dR_hist_L, dF_hist_L, g_hist_L, dR_hist_A, dF_hist_A)
MAKE_GIF (GENERATOR, latent_dim_G, TrainData,ImageShape)
# Out:
# >1, 1/80, DReal=0.692, DFake=0.693 G_Joker=0.693-------- DR_AC=0.719, DF_AC=0.562 G_AC=0.609
# Prob_Limit: 0.00 ,KID= 0.00000, Extra =1
# >1, 2/80, DReal=0.692, DFake=0.693 G_Joker=0.692-------- DR_AC=0.844, DF_AC=0.375 G_AC=0.688
# Prob_Limit: 0.00 ,KID= 0.00000, Extra =1
# >1, 3/80, DReal=0.693, DFake=0.693 G_Joker=0.692-------- DR_AC=0.531, DF_AC=0.594 G_AC=0.688
# Prob_Limit: 0.00 ,KID= 0.00000, Extra =1
# >1, 4/80, DReal=0.691, DFake=0.693 G_Joker=0.692-------- DR_AC=0.906, DF_AC=0.812 G_AC=0.594
# Prob_Limit: 0.00 ,KID= 0.00000, Extra =1
# >1, 5/80, DReal=0.693, DFake=0.693 G_Joker=0.693-------- DR_AC=0.688, DF_AC=0.875 G_AC=0.641
# Prob_Limit: 0.01 ,KID= 0.00000, Extra =1
# >1, 6/80, DReal=0.693, DFake=0.693 G_Joker=0.693-------- DR_AC=0.750, DF_AC=0.938 G_AC=0.594
# Prob_Limit: 0.01 ,KID= 0.00000, Extra =1
# >1, 7/80, DReal=0.693, DFake=0.693 G_Joker=0.692-------- DR_AC=0.781, DF_AC=0.969 G_AC=0.672
# Prob_Limit: 0.01 ,KID= 0.00000, Extra =1
# >1, 8/80, DReal=0.693, DFake=0.693 G_Joker=0.692-------- DR_AC=0.688, DF_AC=1.000 G_AC=0.688
# Prob_Limit: 0.01 ,KID= 0.00000, Extra =1
# >1, 9/80, DReal=0.693, DFake=0.693 G_Joker=0.692-------- DR_AC=0.625, DF_AC=1.000 G_AC=0.703
# Prob_Limit: 0.02 ,KID= 0.00000, Extra =1
# >1, 10/80, DReal=0.692, DFake=0.693 G_Joker=0.692-------- DR_AC=0.906, DF_AC=0.938 G_AC=0.641
# Prob_Limit: 0.02 ,KID= 0.00000, Extra =1
# >1, 11/80, DReal=0.692, DFake=0.693 G_Joker=0.691-------- DR_AC=0.875, DF_AC=1.000 G_AC=0.766
# Prob_Limit: 0.02 ,KID= 0.00000, Extra =1
# >1, 12/80, DReal=0.692, DFake=0.693 G_Joker=0.692-------- DR_AC=0.906, DF_AC=1.000 G_AC=0.703
# Prob_Limit: 0.02 ,KID= 0.00000, Extra =1
# >1, 13/80, DReal=0.692, DFake=0.693 G_Joker=0.691-------- DR_AC=0.781, DF_AC=1.000 G_AC=0.750
# Prob_Limit: 0.03 ,KID= 0.00000, Extra =1
# >1, 14/80, DReal=0.691, DFake=0.693 G_Joker=0.691-------- DR_AC=0.844, DF_AC=0.938 G_AC=0.812
# Prob_Limit: 0.03 ,KID= 0.00000, Extra =1
# >1, 15/80, DReal=0.691, DFake=0.693 G_Joker=0.691-------- DR_AC=0.906, DF_AC=1.000 G_AC=0.797
# Prob_Limit: 0.03 ,KID= 0.00000, Extra =1
# >1, 16/80, DReal=0.692, DFake=0.693 G_Joker=0.691-------- DR_AC=0.844, DF_AC=1.000 G_AC=0.766
# Prob_Limit: 0.03 ,KID= 0.00000, Extra =1
# >1, 17/80, DReal=0.692, DFake=0.693 G_Joker=0.691-------- DR_AC=1.000, DF_AC=0.969 G_AC=0.766
# Prob_Limit: 0.04 ,KID= 0.00000, Extra =1
# >1, 18/80, DReal=0.692, DFake=0.693 G_Joker=0.690-------- DR_AC=0.719, DF_AC=0.969 G_AC=0.938
# Prob_Limit: 0.04 ,KID= 0.00000, Extra =1
# >1, 19/80, DReal=0.693, DFake=0.693 G_Joker=0.690-------- DR_AC=0.844, DF_AC=1.000 G_AC=0.812
# Prob_Limit: 0.04 ,KID= 0.00000, Extra =1
# >1, 20/80, DReal=0.692, DFake=0.693 G_Joker=0.690-------- DR_AC=0.625, DF_AC=0.969 G_AC=0.875
# Prob_Limit: 0.04 ,KID= 0.00000, Extra =1
# >1, 21/80, DReal=0.692, DFake=0.693 G_Joker=0.690-------- DR_AC=0.875, DF_AC=1.000 G_AC=0.875
# Prob_Limit: 0.05 ,KID= 0.00000, Extra =1
# >1, 22/80, DReal=0.691, DFake=0.693 G_Joker=0.691-------- DR_AC=1.000, DF_AC=0.938 G_AC=0.750
# Prob_Limit: 0.05 ,KID= 0.00000, Extra =1
# >1, 23/80, DReal=0.692, DFake=0.693 G_Joker=0.690-------- DR_AC=0.906, DF_AC=0.875 G_AC=0.875
# Prob_Limit: 0.05 ,KID= 0.00000, Extra =1
# >1, 24/80, DReal=0.691, DFake=0.693 G_Joker=0.690-------- DR_AC=0.906, DF_AC=1.000 G_AC=0.766
# Prob_Limit: 0.05 ,KID= 0.00000, Extra =1
# >1, 25/80, DReal=0.691, DFake=0.693 G_Joker=0.690-------- DR_AC=1.000, DF_AC=0.875 G_AC=0.812
# Prob_Limit: 0.06 ,KID= 0.00000, Extra =1
# >1, 26/80, DReal=0.691, DFake=0.693 G_Joker=0.690-------- DR_AC=0.844, DF_AC=0.906 G_AC=0.844
# Prob_Limit: 0.06 ,KID= 0.00000, Extra =1
# >1, 27/80, DReal=0.691, DFake=0.693 G_Joker=0.690-------- DR_AC=0.969, DF_AC=0.969 G_AC=0.859
# Prob_Limit: 0.06 ,KID= 0.00000, Extra =1
# >1, 28/80, DReal=0.692, DFake=0.693 G_Joker=0.690-------- DR_AC=0.875, DF_AC=0.938 G_AC=0.875
# Prob_Limit: 0.06 ,KID= 0.00000, Extra =1
# >1, 29/80, DReal=0.692, DFake=0.693 G_Joker=0.690-------- DR_AC=0.906, DF_AC=0.969 G_AC=0.859
# Prob_Limit: 0.07 ,KID= 0.00000, Extra =1
# >1, 30/80, DReal=0.692, DFake=0.693 G_Joker=0.690-------- DR_AC=0.969, DF_AC=1.000 G_AC=0.906
# Prob_Limit: 0.07 ,KID= 0.00000, Extra =1
# >1, 31/80, DReal=0.693, DFake=0.693 G_Joker=0.690-------- DR_AC=0.656, DF_AC=1.000 G_AC=0.875
# Prob_Limit: 0.07 ,KID= 0.00000, Extra =1
# >1, 32/80, DReal=0.692, DFake=0.693 G_Joker=0.690-------- DR_AC=0.844, DF_AC=0.906 G_AC=0.922
# Prob_Limit: 0.07 ,KID= 0.00000, Extra =1
# >1, 33/80, DReal=0.691, DFake=0.693 G_Joker=0.690-------- DR_AC=1.000, DF_AC=0.969 G_AC=0.859
# Prob_Limit: 0.08 ,KID= 0.00000, Extra =1
# >1, 34/80, DReal=0.691, DFake=0.693 G_Joker=0.689-------- DR_AC=0.938, DF_AC=1.000 G_AC=0.938
# Prob_Limit: 0.08 ,KID= 0.00000, Extra =1
# >1, 35/80, DReal=0.690, DFake=0.693 G_Joker=0.689-------- DR_AC=1.000, DF_AC=1.000 G_AC=0.953
# Prob_Limit: 0.08 ,KID= 0.00000, Extra =1
# >1, 36/80, DReal=0.690, DFake=0.693 G_Joker=0.689-------- DR_AC=1.000, DF_AC=0.969 G_AC=0.875
# Prob_Limit: 0.08 ,KID= 0.00000, Extra =1
# >1, 37/80, DReal=0.690, DFake=0.693 G_Joker=0.689-------- DR_AC=1.000, DF_AC=1.000 G_AC=0.938
# Prob_Limit: 0.09 ,KID= 0.00000, Extra =1
# >1, 38/80, DReal=0.690, DFake=0.693 G_Joker=0.689-------- DR_AC=1.000, DF_AC=0.969 G_AC=0.891
# Prob_Limit: 0.09 ,KID= 0.00000, Extra =1
# >1, 39/80, DReal=0.691, DFake=0.693 G_Joker=0.688-------- DR_AC=0.969, DF_AC=0.844 G_AC=0.969
# Prob_Limit: 0.09 ,KID= 0.00000, Extra =1
# >1, 40/80, DReal=0.691, DFake=0.693 G_Joker=0.689-------- DR_AC=0.969, DF_AC=0.812 G_AC=0.938
# Prob_Limit: 0.09 ,KID= 0.00000, Extra =1
# >1, 41/80, DReal=0.691, DFake=0.693 G_Joker=0.689-------- DR_AC=0.938, DF_AC=1.000 G_AC=0.953
# Prob_Limit: 0.10 ,KID= 0.00000, Extra =1
# >1, 42/80, DReal=0.692, DFake=0.693 G_Joker=0.688-------- DR_AC=0.969, DF_AC=0.969 G_AC=0.984
# Prob_Limit: 0.10 ,KID= 0.00000, Extra =1
# >1, 43/80, DReal=0.691, DFake=0.693 G_Joker=0.689-------- DR_AC=0.969, DF_AC=0.969 G_AC=0.938
# Prob_Limit: 0.10 ,KID= 0.00000, Extra =1
# >1, 44/80, DReal=0.691, DFake=0.693 G_Joker=0.689-------- DR_AC=1.000, DF_AC=1.000 G_AC=0.953
# Prob_Limit: 0.10 ,KID= 0.00000, Extra =1
# >1, 45/80, DReal=0.690, DFake=0.693 G_Joker=0.689-------- DR_AC=1.000, DF_AC=0.969 G_AC=0.969
# Prob_Limit: 0.11 ,KID= 0.00000, Extra =1
# >1, 46/80, DReal=0.689, DFake=0.693 G_Joker=0.688-------- DR_AC=1.000, DF_AC=1.000 G_AC=0.938
# Prob_Limit: 0.11 ,KID= 0.00000, Extra =1
# >1, 47/80, DReal=0.690, DFake=0.693 G_Joker=0.688-------- DR_AC=1.000, DF_AC=0.906 G_AC=0.984
# Prob_Limit: 0.11 ,KID= 0.00000, Extra =1
# >1, 48/80, DReal=0.690, DFake=0.693 G_Joker=0.689-------- DR_AC=1.000, DF_AC=1.000 G_AC=0.938
# Prob_Limit: 0.11 ,KID= 0.00000, Extra =1
# >1, 49/80, DReal=0.690, DFake=0.693 G_Joker=0.688-------- DR_AC=1.000, DF_AC=0.969 G_AC=1.000
# Prob_Limit: 0.12 ,KID= 0.00000, Extra =1
# >1, 50/80, DReal=0.691, DFake=0.693 G_Joker=0.688-------- DR_AC=1.000, DF_AC=0.969 G_AC=0.969
# Prob_Limit: 0.12 ,KID= 0.00000, Extra =1
# >1, 51/80, DReal=0.691, DFake=0.693 G_Joker=0.688-------- DR_AC=1.000, DF_AC=0.969 G_AC=0.969
# Prob_Limit: 0.12 ,KID= 0.00000, Extra =1
# >1, 52/80, DReal=0.691, DFake=0.693 G_Joker=0.688-------- DR_AC=0.906, DF_AC=1.000 G_AC=0.984
# Prob_Limit: 0.12 ,KID= 0.00000, Extra =1
# >1, 53/80, DReal=0.692, DFake=0.693 G_Joker=0.688-------- DR_AC=0.969, DF_AC=0.844 G_AC=0.969
# Prob_Limit: 0.13 ,KID= 0.00000, Extra =1
# >1, 54/80, DReal=0.692, DFake=0.693 G_Joker=0.688-------- DR_AC=0.812, DF_AC=1.000 G_AC=0.969
# Prob_Limit: 0.13 ,KID= 0.00000, Extra =1
# >1, 55/80, DReal=0.691, DFake=0.693 G_Joker=0.688-------- DR_AC=1.000, DF_AC=1.000 G_AC=0.984
# Prob_Limit: 0.13 ,KID= 0.00000, Extra =1
# >1, 56/80, DReal=0.690, DFake=0.693 G_Joker=0.688-------- DR_AC=1.000, DF_AC=0.844 G_AC=0.984
# Prob_Limit: 0.13 ,KID= 0.00000, Extra =1
# >1, 57/80, DReal=0.690, DFake=0.693 G_Joker=0.688-------- DR_AC=1.000, DF_AC=1.000 G_AC=0.984
# Prob_Limit: 0.14 ,KID= 0.00000, Extra =1
# >1, 58/80, DReal=0.690, DFake=0.693 G_Joker=0.688-------- DR_AC=0.938, DF_AC=0.938 G_AC=1.000
# Prob_Limit: 0.14 ,KID= 0.00000, Extra =1
# >1, 59/80, DReal=0.691, DFake=0.693 G_Joker=0.688-------- DR_AC=0.938, DF_AC=1.000 G_AC=0.984
# Prob_Limit: 0.14 ,KID= 0.00000, Extra =1
# >1, 60/80, DReal=0.691, DFake=0.693 G_Joker=0.688-------- DR_AC=0.969, DF_AC=1.000 G_AC=0.969
# Prob_Limit: 0.14 ,KID= 0.00000, Extra =1
# >1, 61/80, DReal=0.691, DFake=0.693 G_Joker=0.688-------- DR_AC=0.969, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.15 ,KID= 0.00000, Extra =1
# >1, 62/80, DReal=0.692, DFake=0.693 G_Joker=0.688-------- DR_AC=0.875, DF_AC=1.000 G_AC=0.984
# Prob_Limit: 0.15 ,KID= 0.00000, Extra =1
# >1, 63/80, DReal=0.691, DFake=0.693 G_Joker=0.688-------- DR_AC=1.000, DF_AC=1.000 G_AC=0.969
# Prob_Limit: 0.15 ,KID= 0.00000, Extra =1
# >1, 64/80, DReal=0.691, DFake=0.693 G_Joker=0.688-------- DR_AC=0.969, DF_AC=1.000 G_AC=0.984
# Prob_Limit: 0.15 ,KID= 0.00000, Extra =1
# >1, 65/80, DReal=0.691, DFake=0.693 G_Joker=0.688-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.16 ,KID= 0.00000, Extra =1
# >1, 66/80, DReal=0.691, DFake=0.693 G_Joker=0.688-------- DR_AC=1.000, DF_AC=0.969 G_AC=0.969
# Prob_Limit: 0.16 ,KID= 0.00000, Extra =1
# >1, 67/80, DReal=0.690, DFake=0.693 G_Joker=0.688-------- DR_AC=1.000, DF_AC=0.969 G_AC=0.984
# Prob_Limit: 0.16 ,KID= 0.00000, Extra =1
# >1, 68/80, DReal=0.689, DFake=0.692 G_Joker=0.688-------- DR_AC=0.969, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.16 ,KID= 0.00000, Extra =1
# >1, 69/80, DReal=0.690, DFake=0.692 G_Joker=0.688-------- DR_AC=0.969, DF_AC=1.000 G_AC=0.984
# Prob_Limit: 0.17 ,KID= 0.00000, Extra =1
# >1, 70/80, DReal=0.690, DFake=0.693 G_Joker=0.687-------- DR_AC=1.000, DF_AC=0.969 G_AC=1.000
# Prob_Limit: 0.17 ,KID= 0.00000, Extra =1
# >1, 71/80, DReal=0.690, DFake=0.692 G_Joker=0.687-------- DR_AC=0.969, DF_AC=0.969 G_AC=1.000
# Prob_Limit: 0.17 ,KID= 0.00000, Extra =1
# >1, 72/80, DReal=0.690, DFake=0.692 G_Joker=0.687-------- DR_AC=0.969, DF_AC=1.000 G_AC=0.969
# Prob_Limit: 0.17 ,KID= 0.00000, Extra =1
# >1, 73/80, DReal=0.690, DFake=0.692 G_Joker=0.688-------- DR_AC=1.000, DF_AC=0.906 G_AC=0.984
# Prob_Limit: 0.18 ,KID= 0.00000, Extra =1
# >1, 74/80, DReal=0.691, DFake=0.692 G_Joker=0.688-------- DR_AC=1.000, DF_AC=0.969 G_AC=0.984
# Prob_Limit: 0.18 ,KID= 0.00000, Extra =1
# >1, 75/80, DReal=0.691, DFake=0.692 G_Joker=0.688-------- DR_AC=0.938, DF_AC=1.000 G_AC=0.984
# Prob_Limit: 0.18 ,KID= 0.00000, Extra =1
# >1, 76/80, DReal=0.692, DFake=0.692 G_Joker=0.688-------- DR_AC=0.938, DF_AC=0.969 G_AC=0.984
# Prob_Limit: 0.18 ,KID= 0.00000, Extra =1
# >1, 77/80, DReal=0.692, DFake=0.692 G_Joker=0.688-------- DR_AC=1.000, DF_AC=0.969 G_AC=0.984
# Prob_Limit: 0.19 ,KID= 0.00000, Extra =1
# >1, 78/80, DReal=0.690, DFake=0.692 G_Joker=0.688-------- DR_AC=1.000, DF_AC=1.000 G_AC=0.984
# Prob_Limit: 0.19 ,KID= 0.00000, Extra =1
# >1, 79/80, DReal=0.689, DFake=0.692 G_Joker=0.688-------- DR_AC=1.000, DF_AC=1.000 G_AC=0.969
# Prob_Limit: 0.19 ,KID= 0.00000, Extra =1
# >1, 80/80, DReal=0.690, DFake=0.692 G_Joker=0.687-------- DR_AC=0.938, DF_AC=1.000 G_AC=0.984
# Prob_Limit: 0.19 ,KID= 0.00000, Extra =1
# >2, 1/80, DReal=0.690, DFake=0.692 G_Joker=0.687-------- DR_AC=1.000, DF_AC=1.000 G_AC=0.984
# Prob_Limit: 0.20 ,KID= 0.00000, Extra =1
# >2, 2/80, DReal=0.690, DFake=0.692 G_Joker=0.687-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.20 ,KID= 0.00000, Extra =1
# >2, 3/80, DReal=0.691, DFake=0.692 G_Joker=0.688-------- DR_AC=0.969, DF_AC=1.000 G_AC=0.984
# Prob_Limit: 0.20 ,KID= 0.00000, Extra =1
# >2, 4/80, DReal=0.689, DFake=0.692 G_Joker=0.687-------- DR_AC=1.000, DF_AC=0.969 G_AC=1.000
# Prob_Limit: 0.20 ,KID= 0.00000, Extra =1
# >2, 5/80, DReal=0.691, DFake=0.692 G_Joker=0.686-------- DR_AC=0.969, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.21 ,KID= 0.00000, Extra =1
# >2, 6/80, DReal=0.691, DFake=0.692 G_Joker=0.687-------- DR_AC=1.000, DF_AC=0.969 G_AC=1.000
# Prob_Limit: 0.21 ,KID= 0.00000, Extra =1
# >2, 7/80, DReal=0.691, DFake=0.692 G_Joker=0.688-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.21 ,KID= 0.00000, Extra =1
# >2, 8/80, DReal=0.691, DFake=0.692 G_Joker=0.688-------- DR_AC=0.969, DF_AC=1.000 G_AC=0.984
# Prob_Limit: 0.21 ,KID= 0.00000, Extra =1
# >2, 9/80, DReal=0.691, DFake=0.692 G_Joker=0.687-------- DR_AC=0.969, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.22 ,KID= 0.00000, Extra =1
# >2, 10/80, DReal=0.689, DFake=0.692 G_Joker=0.687-------- DR_AC=1.000, DF_AC=1.000 G_AC=0.984
# Prob_Limit: 0.22 ,KID= 0.00000, Extra =1
# >2, 11/80, DReal=0.689, DFake=0.692 G_Joker=0.687-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.22 ,KID= 0.00000, Extra =1
# >2, 12/80, DReal=0.689, DFake=0.692 G_Joker=0.688-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.22 ,KID= 0.00000, Extra =1
# >2, 13/80, DReal=0.690, DFake=0.692 G_Joker=0.687-------- DR_AC=0.938, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.23 ,KID= 0.00000, Extra =1
# >2, 14/80, DReal=0.690, DFake=0.692 G_Joker=0.687-------- DR_AC=0.969, DF_AC=1.000 G_AC=0.984
# Prob_Limit: 0.23 ,KID= 0.00000, Extra =1
# >2, 15/80, DReal=0.688, DFake=0.692 G_Joker=0.687-------- DR_AC=0.969, DF_AC=1.000 G_AC=0.984
# Prob_Limit: 0.23 ,KID= 0.00000, Extra =1
# >2, 16/80, DReal=0.689, DFake=0.692 G_Joker=0.688-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.23 ,KID= 0.00000, Extra =1
# >2, 17/80, DReal=0.690, DFake=0.692 G_Joker=0.687-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.24 ,KID= 0.00000, Extra =1
# >2, 18/80, DReal=0.692, DFake=0.692 G_Joker=0.687-------- DR_AC=0.812, DF_AC=1.000 G_AC=0.984
# Prob_Limit: 0.24 ,KID= 0.00000, Extra =1
# >2, 19/80, DReal=0.692, DFake=0.692 G_Joker=0.687-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.24 ,KID= 0.00000, Extra =1
# >2, 20/80, DReal=0.690, DFake=0.692 G_Joker=0.687-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.24 ,KID= 0.00000, Extra =1
# >2, 21/80, DReal=0.689, DFake=0.692 G_Joker=0.687-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.25 ,KID= 0.00000, Extra =1
# >2, 22/80, DReal=0.689, DFake=0.692 G_Joker=0.686-------- DR_AC=1.000, DF_AC=0.969 G_AC=1.000
# Prob_Limit: 0.25 ,KID= 0.00000, Extra =1
# >2, 23/80, DReal=0.690, DFake=0.692 G_Joker=0.687-------- DR_AC=0.906, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.25 ,KID= 0.00000, Extra =1
# >2, 24/80, DReal=0.690, DFake=0.692 G_Joker=0.687-------- DR_AC=0.969, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.25 ,KID= 0.00000, Extra =1
# >2, 25/80, DReal=0.688, DFake=0.692 G_Joker=0.687-------- DR_AC=1.000, DF_AC=1.000 G_AC=0.984
# Prob_Limit: 0.26 ,KID= 0.00000, Extra =1
# >2, 26/80, DReal=0.689, DFake=0.692 G_Joker=0.687-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.26 ,KID= 0.00000, Extra =1
# >2, 27/80, DReal=0.689, DFake=0.692 G_Joker=0.687-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.26 ,KID= 0.00000, Extra =1
# >2, 28/80, DReal=0.691, DFake=0.691 G_Joker=0.686-------- DR_AC=0.938, DF_AC=1.000 G_AC=0.984
# Prob_Limit: 0.26 ,KID= 0.00000, Extra =1
# >2, 29/80, DReal=0.691, DFake=0.691 G_Joker=0.686-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.27 ,KID= 0.00000, Extra =1
# >2, 30/80, DReal=0.691, DFake=0.691 G_Joker=0.687-------- DR_AC=0.906, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.27 ,KID= 0.00000, Extra =1
# >2, 31/80, DReal=0.692, DFake=0.691 G_Joker=0.687-------- DR_AC=0.938, DF_AC=1.000 G_AC=0.984
# Prob_Limit: 0.27 ,KID= 0.00000, Extra =1
# >2, 32/80, DReal=0.690, DFake=0.691 G_Joker=0.687-------- DR_AC=0.969, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.27 ,KID= 0.00000, Extra =1
# >2, 33/80, DReal=0.689, DFake=0.691 G_Joker=0.687-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.28 ,KID= 0.00000, Extra =1
# >2, 34/80, DReal=0.689, DFake=0.691 G_Joker=0.687-------- DR_AC=0.969, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.28 ,KID= 0.00000, Extra =1
# >2, 35/80, DReal=0.688, DFake=0.691 G_Joker=0.687-------- DR_AC=1.000, DF_AC=1.000 G_AC=0.984
# Prob_Limit: 0.28 ,KID= 0.00000, Extra =1
# >2, 36/80, DReal=0.688, DFake=0.691 G_Joker=0.687-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.28 ,KID= 0.00000, Extra =1
# >2, 37/80, DReal=0.688, DFake=0.691 G_Joker=0.686-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.29 ,KID= 0.00000, Extra =1
# >2, 38/80, DReal=0.688, DFake=0.691 G_Joker=0.687-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.29 ,KID= 0.00000, Extra =1
# >2, 39/80, DReal=0.689, DFake=0.691 G_Joker=0.686-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.29 ,KID= 0.00000, Extra =1
# >2, 40/80, DReal=0.690, DFake=0.691 G_Joker=0.686-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.29 ,KID= 0.00000, Extra =1
# >2, 41/80, DReal=0.691, DFake=0.691 G_Joker=0.686-------- DR_AC=0.875, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.30 ,KID= 0.00000, Extra =1
# >2, 42/80, DReal=0.691, DFake=0.691 G_Joker=0.687-------- DR_AC=0.969, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.30 ,KID= 0.00000, Extra =1
# >2, 43/80, DReal=0.690, DFake=0.691 G_Joker=0.686-------- DR_AC=1.000, DF_AC=1.000 G_AC=0.984
# Prob_Limit: 0.30 ,KID= 0.00000, Extra =1
# >2, 44/80, DReal=0.688, DFake=0.691 G_Joker=0.687-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.30 ,KID= 0.00000, Extra =1
# >2, 45/80, DReal=0.688, DFake=0.691 G_Joker=0.687-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.31 ,KID= 0.00000, Extra =1
# >2, 46/80, DReal=0.687, DFake=0.691 G_Joker=0.686-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.31 ,KID= 0.00000, Extra =1
# >2, 47/80, DReal=0.688, DFake=0.691 G_Joker=0.687-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.31 ,KID= 0.00000, Extra =1
# >2, 48/80, DReal=0.688, DFake=0.691 G_Joker=0.686-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.31 ,KID= 0.00000, Extra =1
# >2, 49/80, DReal=0.689, DFake=0.691 G_Joker=0.687-------- DR_AC=1.000, DF_AC=1.000 G_AC=0.984
# Prob_Limit: 0.32 ,KID= 0.00000, Extra =1
# >2, 50/80, DReal=0.690, DFake=0.691 G_Joker=0.686-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.32 ,KID= 0.00000, Extra =1
# >2, 51/80, DReal=0.691, DFake=0.691 G_Joker=0.687-------- DR_AC=0.969, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.32 ,KID= 0.00000, Extra =1
# >2, 52/80, DReal=0.691, DFake=0.691 G_Joker=0.686-------- DR_AC=0.844, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.32 ,KID= 0.00000, Extra =1
# >2, 53/80, DReal=0.692, DFake=0.691 G_Joker=0.687-------- DR_AC=0.875, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.33 ,KID= 0.00000, Extra =1
# >2, 54/80, DReal=0.691, DFake=0.691 G_Joker=0.687-------- DR_AC=0.906, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.33 ,KID= 0.00000, Extra =1
# >2, 55/80, DReal=0.689, DFake=0.690 G_Joker=0.686-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.33 ,KID= 0.00000, Extra =1
# >2, 56/80, DReal=0.688, DFake=0.691 G_Joker=0.686-------- DR_AC=0.969, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.33 ,KID= 0.00000, Extra =1
# >2, 57/80, DReal=0.689, DFake=0.690 G_Joker=0.686-------- DR_AC=0.969, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.34 ,KID= 0.00000, Extra =1
# >2, 58/80, DReal=0.690, DFake=0.690 G_Joker=0.686-------- DR_AC=0.906, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.34 ,KID= 0.00000, Extra =1
# >2, 59/80, DReal=0.690, DFake=0.690 G_Joker=0.686-------- DR_AC=0.875, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.34 ,KID= 0.00000, Extra =1
# >2, 60/80, DReal=0.690, DFake=0.690 G_Joker=0.686-------- DR_AC=0.969, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.34 ,KID= 0.00000, Extra =1
# >2, 61/80, DReal=0.690, DFake=0.690 G_Joker=0.686-------- DR_AC=0.969, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.35 ,KID= 0.00000, Extra =1
# >2, 62/80, DReal=0.691, DFake=0.690 G_Joker=0.687-------- DR_AC=0.938, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.35 ,KID= 0.00000, Extra =1
# >2, 63/80, DReal=0.690, DFake=0.690 G_Joker=0.687-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.35 ,KID= 0.00000, Extra =1
# >2, 64/80, DReal=0.691, DFake=0.690 G_Joker=0.686-------- DR_AC=0.969, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.35 ,KID= 0.00000, Extra =1
# >2, 65/80, DReal=0.691, DFake=0.690 G_Joker=0.687-------- DR_AC=0.969, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.36 ,KID= 0.00000, Extra =1
# >2, 66/80, DReal=0.690, DFake=0.690 G_Joker=0.687-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.36 ,KID= 0.00000, Extra =1
# >2, 67/80, DReal=0.688, DFake=0.690 G_Joker=0.686-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.36 ,KID= 0.00000, Extra =1
# >2, 68/80, DReal=0.688, DFake=0.690 G_Joker=0.686-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.36 ,KID= 0.00000, Extra =1
# >2, 69/80, DReal=0.689, DFake=0.690 G_Joker=0.686-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.37 ,KID= 0.00000, Extra =1
# >2, 70/80, DReal=0.689, DFake=0.690 G_Joker=0.687-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.37 ,KID= 0.00000, Extra =1
# >2, 71/80, DReal=0.688, DFake=0.690 G_Joker=0.686-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.37 ,KID= 0.00000, Extra =1
# >2, 72/80, DReal=0.688, DFake=0.690 G_Joker=0.686-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.37 ,KID= 0.00000, Extra =1
# >2, 73/80, DReal=0.690, DFake=0.690 G_Joker=0.687-------- DR_AC=0.906, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.38 ,KID= 0.00000, Extra =1
# >2, 74/80, DReal=0.690, DFake=0.690 G_Joker=0.687-------- DR_AC=0.906, DF_AC=1.000 G_AC=0.984
# Prob_Limit: 0.38 ,KID= 0.00000, Extra =1
# >2, 75/80, DReal=0.691, DFake=0.690 G_Joker=0.686-------- DR_AC=0.906, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.38 ,KID= 0.00000, Extra =1
# >2, 76/80, DReal=0.691, DFake=0.690 G_Joker=0.686-------- DR_AC=0.906, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.38 ,KID= 0.00000, Extra =1
# >2, 77/80, DReal=0.691, DFake=0.690 G_Joker=0.686-------- DR_AC=0.969, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.39 ,KID= 0.00000, Extra =1
# >2, 78/80, DReal=0.688, DFake=0.690 G_Joker=0.686-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.39 ,KID= 0.00000, Extra =1
# >2, 79/80, DReal=0.689, DFake=0.689 G_Joker=0.686-------- DR_AC=0.969, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.39 ,KID= 0.00000, Extra =1
# >2, 80/80, DReal=0.689, DFake=0.690 G_Joker=0.686-------- DR_AC=0.938, DF_AC=1.000 G_AC=0.984
# Prob_Limit: 0.39 ,KID= 0.00000, Extra =1
# >3, 1/80, DReal=0.688, DFake=0.689 G_Joker=0.686-------- DR_AC=0.969, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.40 ,KID= 0.00000, Extra =1
# >3, 2/80, DReal=0.689, DFake=0.689 G_Joker=0.686-------- DR_AC=0.906, DF_AC=1.000 G_AC=0.984
# Prob_Limit: 0.40 ,KID= 0.00000, Extra =1
# >3, 3/80, DReal=0.690, DFake=0.689 G_Joker=0.687-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.40 ,KID= 0.00000, Extra =1
# >3, 4/80, DReal=0.688, DFake=0.689 G_Joker=0.687-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.40 ,KID= 0.00000, Extra =1
# >3, 5/80, DReal=0.691, DFake=0.689 G_Joker=0.687-------- DR_AC=0.938, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.41 ,KID= 0.00000, Extra =1
# >3, 6/80, DReal=0.690, DFake=0.689 G_Joker=0.686-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.41 ,KID= 0.00000, Extra =1
# >3, 7/80, DReal=0.691, DFake=0.689 G_Joker=0.686-------- DR_AC=0.875, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.41 ,KID= 0.00000, Extra =1
# >3, 8/80, DReal=0.691, DFake=0.689 G_Joker=0.687-------- DR_AC=0.969, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.41 ,KID= 0.00000, Extra =1
# >3, 9/80, DReal=0.690, DFake=0.689 G_Joker=0.686-------- DR_AC=0.969, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.42 ,KID= 0.00000, Extra =1
# >3, 10/80, DReal=0.688, DFake=0.689 G_Joker=0.687-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.42 ,KID= 0.00000, Extra =1
# >3, 11/80, DReal=0.688, DFake=0.689 G_Joker=0.686-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.42 ,KID= 0.00000, Extra =1
# >3, 12/80, DReal=0.688, DFake=0.689 G_Joker=0.687-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.42 ,KID= 0.00000, Extra =1
# >3, 13/80, DReal=0.690, DFake=0.689 G_Joker=0.686-------- DR_AC=0.781, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.43 ,KID= 0.00000, Extra =1
# >3, 14/80, DReal=0.688, DFake=0.689 G_Joker=0.686-------- DR_AC=0.938, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.43 ,KID= 0.00000, Extra =1
# >3, 15/80, DReal=0.687, DFake=0.689 G_Joker=0.686-------- DR_AC=1.000, DF_AC=1.000 G_AC=0.984
# Prob_Limit: 0.43 ,KID= 0.00000, Extra =1
# >3, 16/80, DReal=0.688, DFake=0.689 G_Joker=0.685-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.43 ,KID= 0.00000, Extra =1
# >3, 17/80, DReal=0.689, DFake=0.689 G_Joker=0.686-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.44 ,KID= 0.00000, Extra =1
# >3, 18/80, DReal=0.693, DFake=0.689 G_Joker=0.686-------- DR_AC=0.406, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.44 ,KID= 0.00000, Extra =1
# >3, 19/80, DReal=0.692, DFake=0.689 G_Joker=0.686-------- DR_AC=0.969, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.44 ,KID= 0.00000, Extra =1
# >3, 20/80, DReal=0.690, DFake=0.689 G_Joker=0.686-------- DR_AC=0.938, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.44 ,KID= 0.00000, Extra =1
# >3, 21/80, DReal=0.688, DFake=0.688 G_Joker=0.686-------- DR_AC=1.000, DF_AC=1.000 G_AC=0.984
# Prob_Limit: 0.45 ,KID= 0.00000, Extra =1
# >3, 22/80, DReal=0.688, DFake=0.689 G_Joker=0.686-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.45 ,KID= 0.00000, Extra =1
# >3, 23/80, DReal=0.689, DFake=0.688 G_Joker=0.686-------- DR_AC=0.906, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.45 ,KID= 0.00000, Extra =1
# >3, 24/80, DReal=0.689, DFake=0.688 G_Joker=0.686-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.45 ,KID= 0.00000, Extra =1
# >3, 25/80, DReal=0.687, DFake=0.688 G_Joker=0.685-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.46 ,KID= 0.00000, Extra =1
# >3, 26/80, DReal=0.687, DFake=0.688 G_Joker=0.686-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.46 ,KID= 0.00000, Extra =1
# >3, 27/80, DReal=0.688, DFake=0.688 G_Joker=0.686-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.46 ,KID= 0.00000, Extra =1
# >3, 28/80, DReal=0.692, DFake=0.688 G_Joker=0.686-------- DR_AC=0.906, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.46 ,KID= 0.00000, Extra =1
# >3, 29/80, DReal=0.690, DFake=0.688 G_Joker=0.686-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.47 ,KID= 0.00000, Extra =1
# >3, 30/80, DReal=0.692, DFake=0.688 G_Joker=0.686-------- DR_AC=0.688, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.47 ,KID= 0.00000, Extra =1
# >3, 31/80, DReal=0.692, DFake=0.688 G_Joker=0.686-------- DR_AC=0.656, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.47 ,KID= 0.00000, Extra =1
# >3, 32/80, DReal=0.689, DFake=0.688 G_Joker=0.687-------- DR_AC=0.844, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.47 ,KID= 0.00000, Extra =1
# >3, 33/80, DReal=0.688, DFake=0.688 G_Joker=0.686-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.48 ,KID= 0.00000, Extra =1
# >3, 34/80, DReal=0.687, DFake=0.688 G_Joker=0.686-------- DR_AC=0.969, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.48 ,KID= 0.00000, Extra =1
# >3, 35/80, DReal=0.686, DFake=0.688 G_Joker=0.686-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.48 ,KID= 0.00000, Extra =1
# >3, 36/80, DReal=0.686, DFake=0.688 G_Joker=0.686-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.48 ,KID= 0.00000, Extra =1
# >3, 37/80, DReal=0.686, DFake=0.688 G_Joker=0.686-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.49 ,KID= 0.00000, Extra =1
# >3, 38/80, DReal=0.686, DFake=0.688 G_Joker=0.686-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.49 ,KID= 0.00000, Extra =1
# >3, 39/80, DReal=0.688, DFake=0.688 G_Joker=0.686-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.49 ,KID= 0.00000, Extra =1
# >3, 40/80, DReal=0.691, DFake=0.688 G_Joker=0.686-------- DR_AC=0.969, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.49 ,KID= 0.00000, Extra =1
# >3, 41/80, DReal=0.691, DFake=0.688 G_Joker=0.686-------- DR_AC=0.594, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.50 ,KID= 0.00000, Extra =1
# >3, 42/80, DReal=0.690, DFake=0.687 G_Joker=0.686-------- DR_AC=0.969, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.50 ,KID= 0.00000, Extra =1
# >3, 43/80, DReal=0.689, DFake=0.688 G_Joker=0.686-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.50 ,KID= 0.00000, Extra =1
# >3, 44/80, DReal=0.686, DFake=0.687 G_Joker=0.686-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.50 ,KID= 0.00000, Extra =1
# >3, 45/80, DReal=0.687, DFake=0.687 G_Joker=0.685-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.51 ,KID= 0.00000, Extra =1
# >3, 46/80, DReal=0.686, DFake=0.687 G_Joker=0.686-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.51 ,KID= 0.00000, Extra =1
# >3, 47/80, DReal=0.687, DFake=0.687 G_Joker=0.685-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.51 ,KID= 0.00000, Extra =1
# >3, 48/80, DReal=0.686, DFake=0.687 G_Joker=0.686-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.51 ,KID= 0.00000, Extra =1
# >3, 49/80, DReal=0.687, DFake=0.687 G_Joker=0.686-------- DR_AC=1.000, DF_AC=1.000 G_AC=0.984
# Prob_Limit: 0.52 ,KID= 0.00000, Extra =1
# >3, 50/80, DReal=0.690, DFake=0.687 G_Joker=0.686-------- DR_AC=0.969, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.52 ,KID= 0.00000, Extra =1
# >3, 51/80, DReal=0.690, DFake=0.687 G_Joker=0.685-------- DR_AC=0.938, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.52 ,KID= 0.00000, Extra =1
# >3, 52/80, DReal=0.692, DFake=0.687 G_Joker=0.685-------- DR_AC=0.562, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.52 ,KID= 0.00000, Extra =1
# >3, 53/80, DReal=0.692, DFake=0.687 G_Joker=0.685-------- DR_AC=0.750, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.53 ,KID= 0.00000, Extra =1
# >3, 54/80, DReal=0.691, DFake=0.687 G_Joker=0.686-------- DR_AC=0.906, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.53 ,KID= 0.00000, Extra =1
# >3, 55/80, DReal=0.688, DFake=0.687 G_Joker=0.685-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.53 ,KID= 0.00000, Extra =1
# >3, 56/80, DReal=0.687, DFake=0.687 G_Joker=0.686-------- DR_AC=0.938, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.53 ,KID= 0.00000, Extra =1
# >3, 57/80, DReal=0.688, DFake=0.687 G_Joker=0.686-------- DR_AC=0.906, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.54 ,KID= 0.00000, Extra =1
# >3, 58/80, DReal=0.690, DFake=0.687 G_Joker=0.686-------- DR_AC=0.656, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.54 ,KID= 0.00000, Extra =1
# >3, 59/80, DReal=0.689, DFake=0.687 G_Joker=0.685-------- DR_AC=0.781, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.54 ,KID= 0.00000, Extra =1
# >3, 60/80, DReal=0.690, DFake=0.687 G_Joker=0.686-------- DR_AC=0.688, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.54 ,KID= 0.00000, Extra =1
# >3, 61/80, DReal=0.690, DFake=0.687 G_Joker=0.686-------- DR_AC=0.906, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.55 ,KID= 0.00000, Extra =1
# >3, 62/80, DReal=0.690, DFake=0.687 G_Joker=0.686-------- DR_AC=0.875, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.55 ,KID= 0.00000, Extra =1
# >3, 63/80, DReal=0.689, DFake=0.687 G_Joker=0.685-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.55 ,KID= 0.00000, Extra =1
# >3, 64/80, DReal=0.691, DFake=0.686 G_Joker=0.686-------- DR_AC=0.875, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.55 ,KID= 0.00000, Extra =1
# >3, 65/80, DReal=0.692, DFake=0.687 G_Joker=0.685-------- DR_AC=0.844, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.56 ,KID= 0.00000, Extra =1
# >3, 66/80, DReal=0.690, DFake=0.687 G_Joker=0.685-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.56 ,KID= 0.00000, Extra =1
# >3, 67/80, DReal=0.686, DFake=0.686 G_Joker=0.685-------- DR_AC=0.938, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.56 ,KID= 0.00000, Extra =1
# >3, 68/80, DReal=0.688, DFake=0.687 G_Joker=0.686-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.56 ,KID= 0.00000, Extra =1
# >3, 69/80, DReal=0.689, DFake=0.686 G_Joker=0.686-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.57 ,KID= 0.00000, Extra =1
# >3, 70/80, DReal=0.688, DFake=0.686 G_Joker=0.685-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.57 ,KID= 0.00000, Extra =1
# >3, 71/80, DReal=0.686, DFake=0.686 G_Joker=0.686-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.57 ,KID= 0.00000, Extra =1
# >3, 72/80, DReal=0.688, DFake=0.686 G_Joker=0.686-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.57 ,KID= 0.00000, Extra =1
# >3, 73/80, DReal=0.689, DFake=0.686 G_Joker=0.686-------- DR_AC=0.969, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.58 ,KID= 0.00000, Extra =1
# >3, 74/80, DReal=0.688, DFake=0.687 G_Joker=0.686-------- DR_AC=0.844, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.58 ,KID= 0.00000, Extra =1
# >3, 75/80, DReal=0.692, DFake=0.686 G_Joker=0.686-------- DR_AC=0.438, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.58 ,KID= 0.00000, Extra =1
# >3, 76/80, DReal=0.692, DFake=0.686 G_Joker=0.685-------- DR_AC=0.812, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.58 ,KID= 0.00000, Extra =1
# >3, 77/80, DReal=0.691, DFake=0.686 G_Joker=0.686-------- DR_AC=0.750, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.59 ,KID= 0.00000, Extra =1
# >3, 78/80, DReal=0.687, DFake=0.686 G_Joker=0.685-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.59 ,KID= 0.00000, Extra =1
# >3, 79/80, DReal=0.688, DFake=0.686 G_Joker=0.685-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.59 ,KID= 0.00000, Extra =1
# >3, 80/80, DReal=0.689, DFake=0.686 G_Joker=0.685-------- DR_AC=0.812, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.59 ,KID= 0.00000, Extra =1
# >4, 1/80, DReal=0.688, DFake=0.686 G_Joker=0.685-------- DR_AC=0.812, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.60 ,KID= 0.00000, Extra =1
# >4, 2/80, DReal=0.689, DFake=0.686 G_Joker=0.685-------- DR_AC=0.812, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.60 ,KID= 0.00000, Extra =1
# >4, 3/80, DReal=0.689, DFake=0.686 G_Joker=0.685-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.60 ,KID= 0.00000, Extra =1
# >4, 4/80, DReal=0.688, DFake=0.686 G_Joker=0.685-------- DR_AC=0.938, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.60 ,KID= 0.00000, Extra =1
# >4, 5/80, DReal=0.691, DFake=0.686 G_Joker=0.685-------- DR_AC=0.812, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.61 ,KID= 0.00000, Extra =1
# >4, 6/80, DReal=0.691, DFake=0.686 G_Joker=0.685-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.61 ,KID= 0.00000, Extra =1
# >4, 7/80, DReal=0.692, DFake=0.686 G_Joker=0.686-------- DR_AC=0.625, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.61 ,KID= 0.00000, Extra =1
# >4, 8/80, DReal=0.690, DFake=0.686 G_Joker=0.685-------- DR_AC=0.969, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.61 ,KID= 0.00000, Extra =1
# >4, 9/80, DReal=0.689, DFake=0.686 G_Joker=0.685-------- DR_AC=0.969, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.62 ,KID= 0.00000, Extra =1
# >4, 10/80, DReal=0.686, DFake=0.685 G_Joker=0.685-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.62 ,KID= 0.00000, Extra =1
# >4, 11/80, DReal=0.686, DFake=0.686 G_Joker=0.685-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.62 ,KID= 0.00000, Extra =1
# >4, 12/80, DReal=0.687, DFake=0.686 G_Joker=0.685-------- DR_AC=0.969, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.62 ,KID= 0.00000, Extra =1
# >4, 13/80, DReal=0.689, DFake=0.686 G_Joker=0.685-------- DR_AC=0.594, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.63 ,KID= 0.00000, Extra =1
# >4, 14/80, DReal=0.686, DFake=0.685 G_Joker=0.685-------- DR_AC=0.812, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.63 ,KID= 0.00000, Extra =1
# >4, 15/80, DReal=0.686, DFake=0.685 G_Joker=0.685-------- DR_AC=0.969, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.63 ,KID= 0.00000, Extra =1
# >4, 16/80, DReal=0.687, DFake=0.685 G_Joker=0.685-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.63 ,KID= 0.00000, Extra =1
# >4, 17/80, DReal=0.689, DFake=0.686 G_Joker=0.685-------- DR_AC=0.906, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.64 ,KID= 0.00000, Extra =1
# >4, 18/80, DReal=0.694, DFake=0.686 G_Joker=0.685-------- DR_AC=0.188, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.64 ,KID= 0.00000, Extra =1
# >4, 19/80, DReal=0.692, DFake=0.686 G_Joker=0.685-------- DR_AC=0.625, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.64 ,KID= 0.00000, Extra =1
# >4, 20/80, DReal=0.690, DFake=0.685 G_Joker=0.685-------- DR_AC=0.625, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.64 ,KID= 0.00000, Extra =1
# >4, 21/80, DReal=0.686, DFake=0.685 G_Joker=0.685-------- DR_AC=0.938, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.65 ,KID= 0.00000, Extra =1
# >4, 22/80, DReal=0.686, DFake=0.686 G_Joker=0.684-------- DR_AC=0.969, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.65 ,KID= 0.00000, Extra =1
# >4, 23/80, DReal=0.689, DFake=0.686 G_Joker=0.685-------- DR_AC=0.750, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.65 ,KID= 0.00000, Extra =1
# >4, 24/80, DReal=0.688, DFake=0.685 G_Joker=0.685-------- DR_AC=0.938, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.65 ,KID= 0.00000, Extra =1
# >4, 25/80, DReal=0.686, DFake=0.685 G_Joker=0.685-------- DR_AC=0.969, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.66 ,KID= 0.00000, Extra =1
# >4, 26/80, DReal=0.686, DFake=0.685 G_Joker=0.685-------- DR_AC=0.969, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.66 ,KID= 0.00000, Extra =1
# >4, 27/80, DReal=0.687, DFake=0.685 G_Joker=0.686-------- DR_AC=0.875, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.66 ,KID= 0.00000, Extra =1
# >4, 28/80, DReal=0.692, DFake=0.685 G_Joker=0.685-------- DR_AC=0.625, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.66 ,KID= 0.00000, Extra =1
# >4, 29/80, DReal=0.690, DFake=0.686 G_Joker=0.685-------- DR_AC=0.875, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.67 ,KID= 0.00000, Extra =1
# >4, 30/80, DReal=0.692, DFake=0.686 G_Joker=0.685-------- DR_AC=0.438, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.67 ,KID= 0.00000, Extra =1
# >4, 31/80, DReal=0.692, DFake=0.686 G_Joker=0.685-------- DR_AC=0.562, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.67 ,KID= 0.00000, Extra =1
# >4, 32/80, DReal=0.689, DFake=0.685 G_Joker=0.684-------- DR_AC=0.719, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.67 ,KID= 0.00000, Extra =1
# >4, 33/80, DReal=0.686, DFake=0.685 G_Joker=0.684-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.68 ,KID= 0.00000, Extra =1
# >4, 34/80, DReal=0.686, DFake=0.685 G_Joker=0.685-------- DR_AC=0.938, DF_AC=1.000 G_AC=0.984
# Prob_Limit: 0.68 ,KID= 0.00000, Extra =1
# >4, 35/80, DReal=0.684, DFake=0.686 G_Joker=0.685-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.68 ,KID= 0.00000, Extra =1
# >4, 36/80, DReal=0.684, DFake=0.686 G_Joker=0.684-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.68 ,KID= 0.00000, Extra =1
# >4, 37/80, DReal=0.685, DFake=0.685 G_Joker=0.685-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.69 ,KID= 0.00000, Extra =1
# >4, 38/80, DReal=0.685, DFake=0.686 G_Joker=0.684-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.69 ,KID= 0.00000, Extra =1
# >4, 39/80, DReal=0.688, DFake=0.686 G_Joker=0.685-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.69 ,KID= 0.00000, Extra =1
# >4, 40/80, DReal=0.692, DFake=0.685 G_Joker=0.684-------- DR_AC=0.562, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.69 ,KID= 0.00000, Extra =1
# >4, 41/80, DReal=0.692, DFake=0.685 G_Joker=0.684-------- DR_AC=0.531, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.70 ,KID= 0.00000, Extra =1
# >4, 42/80, DReal=0.690, DFake=0.685 G_Joker=0.684-------- DR_AC=0.938, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.70 ,KID= 0.00000, Extra =1
# >4, 43/80, DReal=0.688, DFake=0.685 G_Joker=0.684-------- DR_AC=0.938, DF_AC=1.000 G_AC=0.984
# Prob_Limit: 0.70 ,KID= 0.00000, Extra =1
# >4, 44/80, DReal=0.685, DFake=0.685 G_Joker=0.684-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.70 ,KID= 0.00000, Extra =1
# >4, 45/80, DReal=0.685, DFake=0.685 G_Joker=0.684-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.71 ,KID= 0.00000, Extra =1
# >4, 46/80, DReal=0.684, DFake=0.685 G_Joker=0.684-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.71 ,KID= 0.00000, Extra =1
# >4, 47/80, DReal=0.685, DFake=0.686 G_Joker=0.684-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.71 ,KID= 0.00000, Extra =1
# >4, 48/80, DReal=0.685, DFake=0.685 G_Joker=0.684-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.71 ,KID= 0.00000, Extra =1
# >4, 49/80, DReal=0.686, DFake=0.685 G_Joker=0.684-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.72 ,KID= 0.00000, Extra =1
# >4, 50/80, DReal=0.690, DFake=0.686 G_Joker=0.684-------- DR_AC=0.812, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.72 ,KID= 0.00000, Extra =1
# >4, 51/80, DReal=0.690, DFake=0.686 G_Joker=0.684-------- DR_AC=0.844, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.72 ,KID= 0.00000, Extra =1
# >4, 52/80, DReal=0.692, DFake=0.686 G_Joker=0.683-------- DR_AC=0.500, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.72 ,KID= 0.00000, Extra =1
# >4, 53/80, DReal=0.693, DFake=0.686 G_Joker=0.684-------- DR_AC=0.500, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.73 ,KID= 0.00000, Extra =1
# >4, 54/80, DReal=0.690, DFake=0.685 G_Joker=0.684-------- DR_AC=0.781, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.73 ,KID= 0.00000, Extra =1
# >4, 55/80, DReal=0.686, DFake=0.685 G_Joker=0.683-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.73 ,KID= 0.00000, Extra =1
# >4, 56/80, DReal=0.686, DFake=0.686 G_Joker=0.684-------- DR_AC=0.906, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.73 ,KID= 0.00000, Extra =1
# >4, 57/80, DReal=0.687, DFake=0.685 G_Joker=0.684-------- DR_AC=0.844, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.74 ,KID= 0.00000, Extra =1
# >4, 58/80, DReal=0.691, DFake=0.686 G_Joker=0.684-------- DR_AC=0.469, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.74 ,KID= 0.00000, Extra =1
# >4, 59/80, DReal=0.688, DFake=0.686 G_Joker=0.684-------- DR_AC=0.781, DF_AC=1.000 G_AC=0.984
# Prob_Limit: 0.74 ,KID= 0.00000, Extra =1
# >4, 60/80, DReal=0.690, DFake=0.686 G_Joker=0.683-------- DR_AC=0.625, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.74 ,KID= 0.00000, Extra =1
# >4, 61/80, DReal=0.691, DFake=0.685 G_Joker=0.683-------- DR_AC=0.688, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.75 ,KID= 0.00000, Extra =1
# >4, 62/80, DReal=0.689, DFake=0.686 G_Joker=0.684-------- DR_AC=0.875, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.75 ,KID= 0.00000, Extra =1
# >4, 63/80, DReal=0.689, DFake=0.686 G_Joker=0.684-------- DR_AC=0.938, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.75 ,KID= 0.00000, Extra =1
# >4, 64/80, DReal=0.691, DFake=0.685 G_Joker=0.684-------- DR_AC=0.656, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.75 ,KID= 0.00000, Extra =1
# >4, 65/80, DReal=0.691, DFake=0.685 G_Joker=0.684-------- DR_AC=0.844, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.76 ,KID= 0.00000, Extra =1
# >4, 66/80, DReal=0.690, DFake=0.686 G_Joker=0.684-------- DR_AC=0.938, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.76 ,KID= 0.00000, Extra =1
# >4, 67/80, DReal=0.683, DFake=0.686 G_Joker=0.684-------- DR_AC=0.906, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.76 ,KID= 0.00000, Extra =1
# >4, 68/80, DReal=0.687, DFake=0.686 G_Joker=0.683-------- DR_AC=0.969, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.76 ,KID= 0.00000, Extra =1
# >4, 69/80, DReal=0.688, DFake=0.686 G_Joker=0.684-------- DR_AC=0.969, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.77 ,KID= 0.00000, Extra =1
# >4, 70/80, DReal=0.688, DFake=0.686 G_Joker=0.683-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.77 ,KID= 0.00000, Extra =1
# >4, 71/80, DReal=0.685, DFake=0.686 G_Joker=0.683-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.77 ,KID= 0.00000, Extra =1
# >4, 72/80, DReal=0.686, DFake=0.686 G_Joker=0.683-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.77 ,KID= 0.00000, Extra =1
# >4, 73/80, DReal=0.688, DFake=0.686 G_Joker=0.683-------- DR_AC=0.781, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.78 ,KID= 0.00000, Extra =1
# >4, 74/80, DReal=0.687, DFake=0.686 G_Joker=0.683-------- DR_AC=0.812, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.78 ,KID= 0.00000, Extra =1
# >4, 75/80, DReal=0.693, DFake=0.686 G_Joker=0.683-------- DR_AC=0.375, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.78 ,KID= 0.00000, Extra =1
# >4, 76/80, DReal=0.692, DFake=0.686 G_Joker=0.683-------- DR_AC=0.656, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.78 ,KID= 0.00000, Extra =1
# >4, 77/80, DReal=0.691, DFake=0.686 G_Joker=0.683-------- DR_AC=0.562, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.79 ,KID= 0.00000, Extra =1
# >4, 78/80, DReal=0.686, DFake=0.686 G_Joker=0.683-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.79 ,KID= 0.00000, Extra =1
# >4, 79/80, DReal=0.687, DFake=0.686 G_Joker=0.683-------- DR_AC=0.906, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.79 ,KID= 0.00000, Extra =1
# >4, 80/80, DReal=0.687, DFake=0.686 G_Joker=0.683-------- DR_AC=0.781, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.79 ,KID= 0.00000, Extra =1
# >5, 1/80, DReal=0.688, DFake=0.686 G_Joker=0.683-------- DR_AC=0.688, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.80 ,KID= 0.00000, Extra =1
# >5, 2/80, DReal=0.687, DFake=0.687 G_Joker=0.683-------- DR_AC=0.781, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.80 ,KID= 0.00000, Extra =1
# >5, 3/80, DReal=0.688, DFake=0.687 G_Joker=0.683-------- DR_AC=0.938, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.80 ,KID= 0.00000, Extra =1
# >5, 4/80, DReal=0.687, DFake=0.687 G_Joker=0.683-------- DR_AC=0.875, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.80 ,KID= 0.00000, Extra =1
# >5, 5/80, DReal=0.691, DFake=0.687 G_Joker=0.683-------- DR_AC=0.750, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.80 ,KID= 0.00000, Extra =1
# >5, 6/80, DReal=0.689, DFake=0.687 G_Joker=0.683-------- DR_AC=0.969, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.80 ,KID= 0.00000, Extra =1
# >5, 7/80, DReal=0.693, DFake=0.687 G_Joker=0.683-------- DR_AC=0.469, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.80 ,KID= 0.00000, Extra =1
# >5, 8/80, DReal=0.690, DFake=0.687 G_Joker=0.683-------- DR_AC=0.812, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.80 ,KID= 0.00000, Extra =1
# >5, 9/80, DReal=0.688, DFake=0.687 G_Joker=0.683-------- DR_AC=0.938, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.80 ,KID= 0.00000, Extra =1
# >5, 10/80, DReal=0.684, DFake=0.687 G_Joker=0.682-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.80 ,KID= 0.00000, Extra =1
# >5, 11/80, DReal=0.685, DFake=0.687 G_Joker=0.683-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.80 ,KID= 0.00000, Extra =1
# >5, 12/80, DReal=0.686, DFake=0.687 G_Joker=0.683-------- DR_AC=0.906, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.80 ,KID= 0.00000, Extra =1
# >5, 13/80, DReal=0.690, DFake=0.687 G_Joker=0.683-------- DR_AC=0.531, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.80 ,KID= 0.00000, Extra =1
# >5, 14/80, DReal=0.684, DFake=0.687 G_Joker=0.682-------- DR_AC=0.875, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.80 ,KID= 0.00000, Extra =1
# >5, 15/80, DReal=0.685, DFake=0.688 G_Joker=0.683-------- DR_AC=0.969, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.80 ,KID= 0.00000, Extra =1
# >5, 16/80, DReal=0.685, DFake=0.688 G_Joker=0.682-------- DR_AC=0.969, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.80 ,KID= 0.00000, Extra =1
# >5, 17/80, DReal=0.689, DFake=0.688 G_Joker=0.683-------- DR_AC=0.844, DF_AC=0.969 G_AC=1.000
# Prob_Limit: 0.80 ,KID= 0.00000, Extra =1
# >5, 18/80, DReal=0.695, DFake=0.687 G_Joker=0.682-------- DR_AC=0.094, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.80 ,KID= 0.00000, Extra =1
# >5, 19/80, DReal=0.692, DFake=0.688 G_Joker=0.682-------- DR_AC=0.594, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.80 ,KID= 0.00000, Extra =1
# >5, 20/80, DReal=0.688, DFake=0.688 G_Joker=0.682-------- DR_AC=0.625, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.80 ,KID= 0.00000, Extra =1
# >5, 21/80, DReal=0.685, DFake=0.688 G_Joker=0.682-------- DR_AC=0.906, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.80 ,KID= 0.00000, Extra =1
# >5, 22/80, DReal=0.685, DFake=0.688 G_Joker=0.682-------- DR_AC=0.938, DF_AC=1.000 G_AC=0.984
# Prob_Limit: 0.80 ,KID= 0.00000, Extra =1
# >5, 23/80, DReal=0.688, DFake=0.688 G_Joker=0.682-------- DR_AC=0.688, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.80 ,KID= 0.00000, Extra =1
# >5, 24/80, DReal=0.686, DFake=0.688 G_Joker=0.682-------- DR_AC=0.938, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.80 ,KID= 0.00000, Extra =1
# >5, 25/80, DReal=0.684, DFake=0.687 G_Joker=0.682-------- DR_AC=0.969, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.80 ,KID= 0.00000, Extra =1
# >5, 26/80, DReal=0.684, DFake=0.688 G_Joker=0.682-------- DR_AC=0.969, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.80 ,KID= 0.00000, Extra =1
# >5, 27/80, DReal=0.687, DFake=0.688 G_Joker=0.682-------- DR_AC=0.781, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.80 ,KID= 0.00000, Extra =1
# >5, 28/80, DReal=0.692, DFake=0.689 G_Joker=0.682-------- DR_AC=0.500, DF_AC=0.969 G_AC=1.000
# Prob_Limit: 0.80 ,KID= 0.00000, Extra =1
# >5, 29/80, DReal=0.689, DFake=0.688 G_Joker=0.682-------- DR_AC=0.875, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.80 ,KID= 0.00000, Extra =1
# >5, 30/80, DReal=0.694, DFake=0.689 G_Joker=0.682-------- DR_AC=0.312, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.80 ,KID= 0.00000, Extra =1
# >5, 31/80, DReal=0.691, DFake=0.688 G_Joker=0.681-------- DR_AC=0.562, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.80 ,KID= 0.00000, Extra =1
# >5, 32/80, DReal=0.688, DFake=0.689 G_Joker=0.681-------- DR_AC=0.812, DF_AC=0.969 G_AC=1.000
# Prob_Limit: 0.80 ,KID= 0.00000, Extra =1
# >5, 33/80, DReal=0.685, DFake=0.689 G_Joker=0.682-------- DR_AC=1.000, DF_AC=0.906 G_AC=1.000
# Prob_Limit: 0.80 ,KID= 0.00000, Extra =1
# ...
# >82, 36/80, DReal=0.693, DFake=0.688 G_Joker=0.696-------- DR_AC=0.500, DF_AC=0.906 G_AC=0.406
# Prob_Limit: 0.16 ,KID= 3.32904, Extra =8
# >82, 37/80, DReal=0.693, DFake=0.688 G_Joker=0.697-------- DR_AC=0.406, DF_AC=0.844 G_AC=0.344
# Prob_Limit: 0.17 ,KID= 3.32904, Extra =8
# >82, 38/80, DReal=0.694, DFake=0.688 G_Joker=0.699-------- DR_AC=0.375, DF_AC=0.844 G_AC=0.297
# Prob_Limit: 0.17 ,KID= 3.32904, Extra =8
# >82, 39/80, DReal=0.691, DFake=0.688 G_Joker=0.697-------- DR_AC=0.688, DF_AC=0.812 G_AC=0.469
# Prob_Limit: 0.17 ,KID= 3.32904, Extra =8
# >82, 40/80, DReal=0.692, DFake=0.688 G_Joker=0.697-------- DR_AC=0.594, DF_AC=0.844 G_AC=0.375
# Prob_Limit: 0.17 ,KID= 3.32904, Extra =8
# >82, 41/80, DReal=0.695, DFake=0.689 G_Joker=0.696-------- DR_AC=0.312, DF_AC=0.750 G_AC=0.344
# Prob_Limit: 0.18 ,KID= 3.32904, Extra =8
# >82, 42/80, DReal=0.693, DFake=0.688 G_Joker=0.698-------- DR_AC=0.500, DF_AC=0.875 G_AC=0.297
# Prob_Limit: 0.18 ,KID= 3.32904, Extra =8
# >82, 43/80, DReal=0.690, DFake=0.689 G_Joker=0.696-------- DR_AC=0.750, DF_AC=0.812 G_AC=0.453
# Prob_Limit: 0.18 ,KID= 3.32904, Extra =8
# >82, 44/80, DReal=0.696, DFake=0.689 G_Joker=0.697-------- DR_AC=0.406, DF_AC=0.812 G_AC=0.328
# Prob_Limit: 0.18 ,KID= 3.32904, Extra =8
# >82, 45/80, DReal=0.693, DFake=0.687 G_Joker=0.698-------- DR_AC=0.500, DF_AC=0.875 G_AC=0.312
# Prob_Limit: 0.19 ,KID= 3.32904, Extra =8
# >82, 46/80, DReal=0.692, DFake=0.687 G_Joker=0.696-------- DR_AC=0.688, DF_AC=0.906 G_AC=0.422
# Prob_Limit: 0.19 ,KID= 3.32904, Extra =8
# >82, 47/80, DReal=0.694, DFake=0.689 G_Joker=0.697-------- DR_AC=0.469, DF_AC=0.781 G_AC=0.359
# Prob_Limit: 0.19 ,KID= 3.32904, Extra =8
# >82, 48/80, DReal=0.696, DFake=0.691 G_Joker=0.698-------- DR_AC=0.281, DF_AC=0.719 G_AC=0.266
# Prob_Limit: 0.19 ,KID= 3.32904, Extra =8
# >82, 49/80, DReal=0.692, DFake=0.688 G_Joker=0.697-------- DR_AC=0.500, DF_AC=0.875 G_AC=0.328
# Prob_Limit: 0.20 ,KID= 3.32904, Extra =8
# >82, 50/80, DReal=0.696, DFake=0.688 G_Joker=0.696-------- DR_AC=0.375, DF_AC=0.812 G_AC=0.375
# Prob_Limit: 0.20 ,KID= 3.32904, Extra =8
# >82, 51/80, DReal=0.695, DFake=0.687 G_Joker=0.696-------- DR_AC=0.500, DF_AC=0.875 G_AC=0.375
# Prob_Limit: 0.20 ,KID= 3.32904, Extra =8
# >82, 52/80, DReal=0.695, DFake=0.688 G_Joker=0.697-------- DR_AC=0.344, DF_AC=0.812 G_AC=0.281
# Prob_Limit: 0.20 ,KID= 3.32904, Extra =8
# >82, 53/80, DReal=0.695, DFake=0.691 G_Joker=0.697-------- DR_AC=0.375, DF_AC=0.625 G_AC=0.328
# Prob_Limit: 0.21 ,KID= 3.32904, Extra =8
# >82, 54/80, DReal=0.694, DFake=0.690 G_Joker=0.697-------- DR_AC=0.500, DF_AC=0.719 G_AC=0.344
# Prob_Limit: 0.21 ,KID= 3.32904, Extra =8
# >82, 55/80, DReal=0.693, DFake=0.688 G_Joker=0.697-------- DR_AC=0.469, DF_AC=0.812 G_AC=0.250
# Prob_Limit: 0.21 ,KID= 3.32904, Extra =8
# >82, 56/80, DReal=0.692, DFake=0.688 G_Joker=0.697-------- DR_AC=0.531, DF_AC=0.844 G_AC=0.312
# Prob_Limit: 0.21 ,KID= 3.32904, Extra =8
# >82, 57/80, DReal=0.688, DFake=0.690 G_Joker=0.696-------- DR_AC=0.750, DF_AC=0.625 G_AC=0.359
# Prob_Limit: 0.22 ,KID= 3.32904, Extra =8
# >82, 58/80, DReal=0.688, DFake=0.688 G_Joker=0.697-------- DR_AC=0.750, DF_AC=0.812 G_AC=0.234
# Prob_Limit: 0.22 ,KID= 3.32904, Extra =8
# >82, 59/80, DReal=0.691, DFake=0.689 G_Joker=0.697-------- DR_AC=0.562, DF_AC=0.812 G_AC=0.297
# Prob_Limit: 0.22 ,KID= 3.32904, Extra =8
# >82, 60/80, DReal=0.694, DFake=0.688 G_Joker=0.696-------- DR_AC=0.438, DF_AC=0.812 G_AC=0.344
# Prob_Limit: 0.22 ,KID= 3.32904, Extra =8
# >82, 61/80, DReal=0.692, DFake=0.689 G_Joker=0.697-------- DR_AC=0.594, DF_AC=0.688 G_AC=0.266
# Prob_Limit: 0.23 ,KID= 3.32904, Extra =8
# >82, 62/80, DReal=0.692, DFake=0.689 G_Joker=0.697-------- DR_AC=0.594, DF_AC=0.750 G_AC=0.266
# Prob_Limit: 0.23 ,KID= 3.32904, Extra =8
# >82, 63/80, DReal=0.694, DFake=0.691 G_Joker=0.696-------- DR_AC=0.438, DF_AC=0.531 G_AC=0.391
# Prob_Limit: 0.23 ,KID= 3.32904, Extra =8
# >82, 64/80, DReal=0.694, DFake=0.690 G_Joker=0.697-------- DR_AC=0.531, DF_AC=0.781 G_AC=0.328
# Prob_Limit: 0.23 ,KID= 3.32904, Extra =8
# >82, 65/80, DReal=0.696, DFake=0.690 G_Joker=0.697-------- DR_AC=0.281, DF_AC=0.625 G_AC=0.203
# Prob_Limit: 0.24 ,KID= 3.32904, Extra =8
# >82, 66/80, DReal=0.694, DFake=0.689 G_Joker=0.696-------- DR_AC=0.438, DF_AC=0.656 G_AC=0.266
# Prob_Limit: 0.24 ,KID= 3.32904, Extra =8
# >82, 67/80, DReal=0.698, DFake=0.689 G_Joker=0.696-------- DR_AC=0.344, DF_AC=0.938 G_AC=0.375
# Prob_Limit: 0.24 ,KID= 3.32904, Extra =8
# >82, 68/80, DReal=0.693, DFake=0.690 G_Joker=0.697-------- DR_AC=0.531, DF_AC=0.688 G_AC=0.172
# Prob_Limit: 0.24 ,KID= 3.32904, Extra =8
# >82, 69/80, DReal=0.689, DFake=0.690 G_Joker=0.696-------- DR_AC=0.750, DF_AC=0.688 G_AC=0.375
# Prob_Limit: 0.23 ,KID= 3.32904, Extra =8
# >82, 70/80, DReal=0.691, DFake=0.689 G_Joker=0.697-------- DR_AC=0.594, DF_AC=0.812 G_AC=0.234
# Prob_Limit: 0.23 ,KID= 3.32904, Extra =8
# >82, 71/80, DReal=0.692, DFake=0.690 G_Joker=0.696-------- DR_AC=0.562, DF_AC=0.594 G_AC=0.281
# Prob_Limit: 0.23 ,KID= 3.32904, Extra =8
# >82, 72/80, DReal=0.695, DFake=0.690 G_Joker=0.696-------- DR_AC=0.375, DF_AC=0.656 G_AC=0.359
# Prob_Limit: 0.23 ,KID= 3.32904, Extra =8
# >82, 73/80, DReal=0.696, DFake=0.690 G_Joker=0.696-------- DR_AC=0.250, DF_AC=0.750 G_AC=0.234
# Prob_Limit: 0.24 ,KID= 3.32904, Extra =8
# >82, 74/80, DReal=0.697, DFake=0.690 G_Joker=0.697-------- DR_AC=0.250, DF_AC=0.656 G_AC=0.234
# Prob_Limit: 0.24 ,KID= 3.32904, Extra =8
# >82, 75/80, DReal=0.695, DFake=0.690 G_Joker=0.697-------- DR_AC=0.406, DF_AC=0.688 G_AC=0.172
# Prob_Limit: 0.24 ,KID= 3.32904, Extra =8
# >82, 76/80, DReal=0.695, DFake=0.689 G_Joker=0.696-------- DR_AC=0.375, DF_AC=0.812 G_AC=0.266
# Prob_Limit: 0.24 ,KID= 3.32904, Extra =8
# >82, 77/80, DReal=0.693, DFake=0.691 G_Joker=0.696-------- DR_AC=0.562, DF_AC=0.688 G_AC=0.281
# Prob_Limit: 0.23 ,KID= 3.32904, Extra =8
# >82, 78/80, DReal=0.692, DFake=0.691 G_Joker=0.695-------- DR_AC=0.625, DF_AC=0.719 G_AC=0.359
# Prob_Limit: 0.23 ,KID= 3.32904, Extra =8
# >82, 79/80, DReal=0.690, DFake=0.691 G_Joker=0.696-------- DR_AC=0.562, DF_AC=0.688 G_AC=0.297
# Prob_Limit: 0.23 ,KID= 3.32904, Extra =8
# >82, 80/80, DReal=0.689, DFake=0.691 G_Joker=0.696-------- DR_AC=0.688, DF_AC=0.625 G_AC=0.297
# Prob_Limit: 0.23 ,KID= 3.32904, Extra =8
# >83, 1/80, DReal=0.692, DFake=0.690 G_Joker=0.694-------- DR_AC=0.562, DF_AC=0.844 G_AC=0.453
# Prob_Limit: 0.24 ,KID= 3.32904, Extra =8
# >83, 2/80, DReal=0.692, DFake=0.691 G_Joker=0.696-------- DR_AC=0.562, DF_AC=0.656 G_AC=0.266
# Prob_Limit: 0.24 ,KID= 3.32904, Extra =8
# >83, 3/80, DReal=0.694, DFake=0.690 G_Joker=0.695-------- DR_AC=0.406, DF_AC=0.781 G_AC=0.391
# Prob_Limit: 0.24 ,KID= 3.32904, Extra =8
# >83, 4/80, DReal=0.692, DFake=0.690 G_Joker=0.694-------- DR_AC=0.438, DF_AC=0.750 G_AC=0.406
# Prob_Limit: 0.24 ,KID= 3.32904, Extra =8
# >83, 5/80, DReal=0.696, DFake=0.691 G_Joker=0.696-------- DR_AC=0.344, DF_AC=0.656 G_AC=0.250
# Prob_Limit: 0.25 ,KID= 3.32904, Extra =8
# >83, 6/80, DReal=0.697, DFake=0.690 G_Joker=0.695-------- DR_AC=0.344, DF_AC=0.781 G_AC=0.359
# Prob_Limit: 0.25 ,KID= 3.32904, Extra =8
# >83, 7/80, DReal=0.699, DFake=0.690 G_Joker=0.696-------- DR_AC=0.156, DF_AC=0.719 G_AC=0.203
# Prob_Limit: 0.25 ,KID= 3.32904, Extra =8
# >83, 8/80, DReal=0.695, DFake=0.690 G_Joker=0.694-------- DR_AC=0.344, DF_AC=0.750 G_AC=0.422
# Prob_Limit: 0.25 ,KID= 3.32904, Extra =8
# >83, 9/80, DReal=0.690, DFake=0.691 G_Joker=0.695-------- DR_AC=0.688, DF_AC=0.594 G_AC=0.234
# Prob_Limit: 0.24 ,KID= 3.32904, Extra =8
# >83, 10/80, DReal=0.692, DFake=0.691 G_Joker=0.694-------- DR_AC=0.531, DF_AC=0.688 G_AC=0.453
# Prob_Limit: 0.24 ,KID= 3.32904, Extra =8
# >83, 11/80, DReal=0.689, DFake=0.691 G_Joker=0.693-------- DR_AC=0.750, DF_AC=0.656 G_AC=0.578
# Prob_Limit: 0.24 ,KID= 3.32904, Extra =8
# >83, 12/80, DReal=0.689, DFake=0.691 G_Joker=0.696-------- DR_AC=0.625, DF_AC=0.656 G_AC=0.250
# Prob_Limit: 0.24 ,KID= 3.32904, Extra =8
# >83, 13/80, DReal=0.693, DFake=0.693 G_Joker=0.695-------- DR_AC=0.500, DF_AC=0.469 G_AC=0.344
# Prob_Limit: 0.25 ,KID= 3.32904, Extra =8
# >83, 14/80, DReal=0.694, DFake=0.691 G_Joker=0.694-------- DR_AC=0.375, DF_AC=0.781 G_AC=0.344
# Prob_Limit: 0.25 ,KID= 3.32904, Extra =8
# >83, 15/80, DReal=0.695, DFake=0.691 G_Joker=0.694-------- DR_AC=0.375, DF_AC=0.688 G_AC=0.438
# Prob_Limit: 0.25 ,KID= 3.32904, Extra =8
# >83, 16/80, DReal=0.695, DFake=0.692 G_Joker=0.694-------- DR_AC=0.375, DF_AC=0.594 G_AC=0.344
# Prob_Limit: 0.25 ,KID= 3.32904, Extra =8
# >83, 17/80, DReal=0.695, DFake=0.693 G_Joker=0.694-------- DR_AC=0.406, DF_AC=0.438 G_AC=0.391
# Prob_Limit: 0.24 ,KID= 3.32904, Extra =8
# >83, 18/80, DReal=0.695, DFake=0.692 G_Joker=0.694-------- DR_AC=0.344, DF_AC=0.562 G_AC=0.406
# Prob_Limit: 0.24 ,KID= 3.32904, Extra =8
# >83, 19/80, DReal=0.694, DFake=0.693 G_Joker=0.694-------- DR_AC=0.406, DF_AC=0.469 G_AC=0.438
# Prob_Limit: 0.24 ,KID= 3.32904, Extra =8
# >83, 20/80, DReal=0.695, DFake=0.693 G_Joker=0.695-------- DR_AC=0.438, DF_AC=0.594 G_AC=0.375
# Prob_Limit: 0.24 ,KID= 3.32904, Extra =8
# >83, 21/80, DReal=0.689, DFake=0.692 G_Joker=0.693-------- DR_AC=0.781, DF_AC=0.688 G_AC=0.500
# Prob_Limit: 0.23 ,KID= 3.32904, Extra =8
# >83, 22/80, DReal=0.692, DFake=0.692 G_Joker=0.694-------- DR_AC=0.500, DF_AC=0.562 G_AC=0.469
# Prob_Limit: 0.23 ,KID= 3.32904, Extra =8
# >83, 23/80, DReal=0.693, DFake=0.692 G_Joker=0.693-------- DR_AC=0.531, DF_AC=0.750 G_AC=0.438
# Prob_Limit: 0.23 ,KID= 3.32904, Extra =8
# >83, 24/80, DReal=0.692, DFake=0.691 G_Joker=0.694-------- DR_AC=0.594, DF_AC=0.688 G_AC=0.453
# Prob_Limit: 0.23 ,KID= 3.32904, Extra =8
# >83, 25/80, DReal=0.693, DFake=0.692 G_Joker=0.693-------- DR_AC=0.438, DF_AC=0.625 G_AC=0.531
# Prob_Limit: 0.24 ,KID= 3.32904, Extra =8
# >83, 26/80, DReal=0.696, DFake=0.692 G_Joker=0.694-------- DR_AC=0.250, DF_AC=0.531 G_AC=0.391
# Prob_Limit: 0.24 ,KID= 3.32904, Extra =8
# >83, 27/80, DReal=0.695, DFake=0.693 G_Joker=0.694-------- DR_AC=0.344, DF_AC=0.531 G_AC=0.312
# Prob_Limit: 0.24 ,KID= 3.32904, Extra =8
# >83, 28/80, DReal=0.695, DFake=0.692 G_Joker=0.694-------- DR_AC=0.375, DF_AC=0.625 G_AC=0.422
# Prob_Limit: 0.24 ,KID= 3.32904, Extra =8
# >83, 29/80, DReal=0.693, DFake=0.692 G_Joker=0.694-------- DR_AC=0.500, DF_AC=0.531 G_AC=0.438
# Prob_Limit: 0.23 ,KID= 3.32904, Extra =8
# >83, 30/80, DReal=0.692, DFake=0.693 G_Joker=0.694-------- DR_AC=0.500, DF_AC=0.531 G_AC=0.359
# Prob_Limit: 0.23 ,KID= 3.32904, Extra =8
# >83, 31/80, DReal=0.689, DFake=0.692 G_Joker=0.693-------- DR_AC=0.719, DF_AC=0.656 G_AC=0.500
# Prob_Limit: 0.23 ,KID= 3.32904, Extra =8
# >83, 32/80, DReal=0.689, DFake=0.693 G_Joker=0.694-------- DR_AC=0.719, DF_AC=0.562 G_AC=0.422
# Prob_Limit: 0.23 ,KID= 3.32904, Extra =8
# >83, 33/80, DReal=0.695, DFake=0.693 G_Joker=0.694-------- DR_AC=0.406, DF_AC=0.531 G_AC=0.438
# Prob_Limit: 0.22 ,KID= 3.32904, Extra =8
# >83, 34/80, DReal=0.685, DFake=0.693 G_Joker=0.694-------- DR_AC=0.875, DF_AC=0.531 G_AC=0.359
# Prob_Limit: 0.22 ,KID= 3.32904, Extra =8
# >83, 35/80, DReal=0.686, DFake=0.693 G_Joker=0.693-------- DR_AC=0.812, DF_AC=0.500 G_AC=0.438
# Prob_Limit: 0.22 ,KID= 3.32904, Extra =8
# >83, 36/80, DReal=0.693, DFake=0.695 G_Joker=0.693-------- DR_AC=0.375, DF_AC=0.344 G_AC=0.516
# Prob_Limit: 0.22 ,KID= 3.32904, Extra =8
# >83, 37/80, DReal=0.692, DFake=0.691 G_Joker=0.694-------- DR_AC=0.594, DF_AC=0.750 G_AC=0.406
# Prob_Limit: 0.21 ,KID= 3.32904, Extra =8
# >83, 38/80, DReal=0.692, DFake=0.693 G_Joker=0.693-------- DR_AC=0.406, DF_AC=0.531 G_AC=0.438
# Prob_Limit: 0.21 ,KID= 3.32904, Extra =8
# >83, 39/80, DReal=0.691, DFake=0.692 G_Joker=0.694-------- DR_AC=0.625, DF_AC=0.594 G_AC=0.328
# Prob_Limit: 0.21 ,KID= 3.32904, Extra =8
# >83, 40/80, DReal=0.694, DFake=0.693 G_Joker=0.693-------- DR_AC=0.375, DF_AC=0.531 G_AC=0.516
# Prob_Limit: 0.21 ,KID= 3.32904, Extra =8
# >83, 41/80, DReal=0.696, DFake=0.693 G_Joker=0.692-------- DR_AC=0.312, DF_AC=0.469 G_AC=0.562
# Prob_Limit: 0.20 ,KID= 3.32904, Extra =8
# >83, 42/80, DReal=0.694, DFake=0.693 G_Joker=0.693-------- DR_AC=0.438, DF_AC=0.656 G_AC=0.453
# Prob_Limit: 0.20 ,KID= 3.32904, Extra =8
# >83, 43/80, DReal=0.687, DFake=0.694 G_Joker=0.693-------- DR_AC=0.688, DF_AC=0.406 G_AC=0.531
# Prob_Limit: 0.20 ,KID= 3.32904, Extra =8
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-34-7793d2e50e01> in <module>
#      15 GAN=GAN_MODEL(GENERATOR, latent_dim_G, DISCRIMINATOR)
#      16
# ---> 17 dR_hist_L, dF_hist_L, g_hist_L, dR_hist_A, dF_hist_A, KID=train(GENERATOR, DISCRIMINATOR, GAN, latent_dim_G, TrainData, batch_size, NumEpochs,ImageShape)
#      18
#      19 plot_history(dR_hist_L, dF_hist_L, g_hist_L, dR_hist_A, dF_hist_A)
#
# <ipython-input-33-8f843d430795> in train(GENERATOR, DISCRIMINATOR, GAN, latent_dim_G, TrainData, batch_size, NumEpochs, ImageShape)
#      45       p_f=np.random.random((X_fake.shape[0],6))
#      46       p_f=(p_f<=Prob_Limit)*1# If 1 we appy the augmentation, if 0 we do not apply the augmentation
# ---> 47       history_DF = DISCRIMINATOR.train_on_batch((X_fake,p_f), y_fake, return_dict=True)
#      48
#      49       D_lossF = history_DF['loss']
#
# /opt/anaconda3/envs/py38tf25/lib/python3.9/site-packages/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight, reset_metrics, return_dict)
#    1854                                                     class_weight)
#    1855       self.train_function = self.make_train_function()
# -> 1856       logs = self.train_function(iterator)
#    1857
#    1858     if reset_metrics:
#
# /opt/anaconda3/envs/py38tf25/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     883
#     884       with OptionalXlaContext(self._jit_compile):
# --> 885         result = self._call(*args, **kwds)
#     886
#     887       new_tracing_count = self.experimental_get_tracing_count()
#
# /opt/anaconda3/envs/py38tf25/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     915       # In this case we have created variables on the first call, so we run the
#     916       # defunned version which is guaranteed to never create variables.
# --> 917       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     918     elif self._stateful_fn is not None:
#     919       # Release the lock early so that multiple threads can perform the call
#
# /opt/anaconda3/envs/py38tf25/lib/python3.9/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    3037       (graph_function,
#    3038        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 3039     return graph_function._call_flat(
#    3040         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    3041
#
# /opt/anaconda3/envs/py38tf25/lib/python3.9/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1961         and executing_eagerly):
#    1962       # No tape is watching; skip to running the function.
# -> 1963       return self._build_call_outputs(self._inference_function.call(
#    1964           ctx, args, cancellation_manager=cancellation_manager))
#    1965     forward_backward = self._select_forward_and_backward_functions(
#
# /opt/anaconda3/envs/py38tf25/lib/python3.9/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     589       with _InterpolateFunctionError(self):
#     590         if cancellation_manager is None:
# --> 591           outputs = execute.execute(
#     592               str(self.signature.name),
#     593               num_outputs=self._num_outputs,
#
# /opt/anaconda3/envs/py38tf25/lib/python3.9/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57   try:
#      58     ctx.ensure_initialized()
# ---> 59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
#historical Values
Save=[]
from tqdm import tqdm

Step_T=365

for i in tqdm(range(1000)):
    EnergyPu=EnergyPu[np.random.permutation(EnergyPu.shape[0]),:,:,:]

    x=EnergyPu[Step_T*0:Step_T*1,:,:,:]
    y=EnergyPu[Step_T*1:Step_T*2,:,:,:]
    x_torch=torch.from_numpy(np.reshape(x,(x.shape[0],-1))).double()
    y_torch=torch.from_numpy(np.reshape(y,(y.shape[0],-1))).double()

    Save.append(MMD(x_torch, y_torch, kernel="rbf"))
 
Save=np.array(Save)
plt.boxplot(Save)  
plt.show()

# %%
plt.boxplot(Save)  
plt.show()
A=Save

# %%
#synthetic Values
Save=[]
def generate_latent_points(latent_dim_G, n_samples):
  x_input = randn(latent_dim_G * n_samples)
  x_input = x_input.reshape(n_samples, latent_dim_G)

  return x_input

GENERATOR = load_model("/home/victor-duraes/Projects/Ocean2/GANs/SaveStep/GENERATOR_W14.hdf5")
latent_dim_G=GENERATOR.input_shape[1]
n_samples=365


from tqdm import tqdm
for i in tqdm(range(1000)):
    x_input=generate_latent_points(latent_dim_G, n_samples)
    y=(GENERATOR.predict(x_input))
    y[y<0]=0
    y[:,Idx_Exclude]=0

    x_input=generate_latent_points(latent_dim_G, n_samples)
    x=(GENERATOR.predict(x_input))
    x[x<0]=0
    x[:,Idx_Exclude]=0

    x_torch=torch.from_numpy(np.reshape(x,(x.shape[0],-1))).double()
    y_torch=torch.from_numpy(np.reshape(y,(y.shape[0],-1))).double()

    Save.append(MMD(x_torch, y_torch, kernel="rbf"))
 
Save=np.array(Save)
plt.boxplot(Save)  
plt.show()

# %%
RealData=A
SyntheticData=Save
plt.boxplot([RealData,SyntheticData])
plt.show()

# %%
#KID comparison Real with Synthetic
KID_RS=[]
def generate_latent_points(latent_dim_G, n_samples):
  x_input = randn(latent_dim_G * n_samples)
  x_input = x_input.reshape(n_samples, latent_dim_G)

  return x_input

GENERATOR = load_model("/home/victor-duraes/Projects/Ocean2/GANs/SaveStep/GENERATOR_W1.hdf5")
latent_dim_G=GENERATOR.input_shape[1]
n_samples=365

from tqdm import tqdm
for i in tqdm(range(1000)):
    x_input=generate_latent_points(latent_dim_G, n_samples)
    y=(GENERATOR.predict(x_input))
    y=y[:,Idx_Exclude]

    EnergyPu=EnergyPu[np.random.permutation(EnergyPu.shape[0]),:,:,:]
    x=EnergyPu[0:n_samples,:,:,:]
    x=x[:,Idx_Exclude]

    x_torch=torch.from_numpy(np.reshape(x,(x.shape[0],-1))).double()
    y_torch=torch.from_numpy(np.reshape(y,(y.shape[0],-1))).double()

    KID_RS.append(MMD(x_torch, y_torch, kernel="rbf"))
 
KID_RS=np.array(KID_RS)

# %%
RealData=A
SyntheticData=Save
plt.boxplot([KID_RS])
plt.show()

# %%
plt.boxplot([KID_RS,RealData])
plt.show()

# %%
#Evaluate Model
from tqdm import tqdm
from keras.models import load_model


Save=[]
Index_i=[]
for i in tqdm(np.arange(0,40,5)):

  n_samples=2550
  GENERATOR = load_model("/home/victor-duraes/Projects/Ocean2/GANs/SaveStep/GENERATOR_W"+str(i)+".hdf5")
  latent_dim_G=GENERATOR.input_shape[1]

  Y, _ = generate_fake_samples(GENERATOR, latent_dim_G, n_samples)
  Y=np.reshape(Y,(Y.shape[0],-1))
  EnergyPu=EnergyPu[np.random.permutation(EnergyPu.shape[0]),:,:,:]
  Idx_Exclude=np.reshape(Idx_Exclude,(-1))
  Y=Y[:,Idx_Exclude==1]


  x=EnergyPu
  x=np.reshape(x,(x.shape[0],-1))
  x=x[0:n_samples,Idx_Exclude==1]

  x_torch=torch.from_numpy(x).double()
  y_torch=torch.from_numpy(Y).double()

  Save.append(MMD(x_torch, y_torch, kernel="rbf"))
  Index_i.append(i)

Save=np.array(Save)
plt.plot(Index_i, Save)  
plt.show()
# Out:
# 100%|██████████| 62/62 [02:15<00:00,  2.18s/it]

# %%
Save
# Out:
# array([3.34938], dtype=float32)
