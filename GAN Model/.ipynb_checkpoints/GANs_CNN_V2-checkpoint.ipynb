# %%
import datetime as dt
import gc
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import pandas as pd
import geopandas as gpd
import imageio
from pathlib import Path

#####--
import numpy as np
from numpy import expand_dims
from numpy import ones
from numpy import zeros
from numpy.random import rand
from numpy.random import randint
from numpy.random import randn
from numpy.random import randint
import numpy.random as random

#Keras and tensorflow
import keras
import tensorflow as tf
import torch
from keras.models import load_model

from keras.datasets.cifar10 import load_data
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM, TimeDistributed, RepeatVector
from keras.layers import Conv2D,BatchNormalization
from keras.layers import MaxPooling2D
from keras.layers import Conv2DTranspose
from keras.layers import Flatten
from keras.layers import Dropout,Cropping2D
from keras.layers import LeakyReLU
from keras.layers import Reshape
from keras.callbacks import ModelCheckpoint, Callback
from keras.constraints import Constraint
from keras.layers import Lambda
from keras.utils.vis_utils import plot_model
from keras.models import Model
from keras import backend
from tensorflow.keras import Input
from tensorflow.keras.optimizers import Adam, RMSprop
from tensorflow.keras.layers import Multiply
from tensorflow_addons.image import translate as translate_tf


### 
from scipy.ndimage import affine_transform
from scipy.ndimage import rotate

### 
from scipy.ndimage import affine_transform
from scipy.ndimage import rotate

import tensorflow as tf
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
  tf.config.experimental.set_memory_growth(gpu, True)

# %%
def PlotData_Stage1(Scenario,Tech,EnergyPu):
  ShapeFileCoast="/home/victor-duraes/Projects/Ocean2/GANs/GEO_data/ne_10m_coastline.shp"
  ShapeFileStates="/home/victor-duraes/Projects/Ocean2/GANs/GEO_data/ne_10m_admin_1_states_provinces_lines.shp"
  X_LAT=np.zeros((int(len(Lat)*len(Long))),dtype=float)
  Y_LONG=np.zeros((int(len(Lat)*len(Long))),dtype=float)

  min_latitude=np.min(Lat)
  max_latitude=np.max(Lat)

  min_longitude=np.min(Long)
  max_longitude=np.max(Long)

  xlim =[min_longitude,max_longitude]
  ylim=[min_latitude, max_latitude]

  df = gpd.read_file(ShapeFileCoast)
  df1 = gpd.read_file(ShapeFileStates)

  fig, ax = plt.subplots(figsize  = None)
  df.plot(color='black',linewidth=1,ax=ax)
  df1.plot(color='black',linewidth=1,ax=ax)

  count=0
  for I_lat in range(len(Lat)):
    for I_long in range(len(Long)):

      Y_LONG[count]=Lat[I_lat]
      X_LAT[count]=Long[I_long]
      count=count+1

  plt.scatter(X_LAT,Y_LONG,c=(EnergyPu[Scenario,:,:,Tech])/255, s=5, cmap='jet')
  plt.colorbar()
  ax.set_xlim(xlim)
  ax.set_ylim(ylim)

  return plt.show()

NPZ_Data=np.load("/home/victor-duraes/Projects/Ocean2/GANs/AggregatedData_Daily.npz", allow_pickle=True) 
EnergyPu=NPZ_Data["EnergyPu"]
Lat=NPZ_Data["Lat"]
Long=NPZ_Data["Long"]
EnergyPu=NPZ_Data["EnergyPu"]
StartYear=NPZ_Data["StartYear"]
EndYear=NPZ_Data["EndYear"]
WindEnergy_RatedPower=float(NPZ_Data["WindEnergy_RatedPower"])
WaveEnergy_RatedPower=float(NPZ_Data["WaveEnergy_RatedPower"])
OceanEnergy_RatedPower=float(NPZ_Data["OceanEnergy_RatedPower"])

NPZ_Data_Yearly=np.load("/home/victor-duraes/Projects/Ocean2/GANs/AggregatedData_Daily.npz", allow_pickle=True) 
EnergyPu_Yearly=NPZ_Data_Yearly["EnergyPu"]

Idx_Exclude=np.max(EnergyPu_Yearly[:,:,:,1],axis=0)<=0.001
EnergyPu[:,Idx_Exclude,:]=0

Idx_Exclude_Ocean=np.max(EnergyPu_Yearly[:,:,:,2],axis=0)<=0.05
EnergyPu[:,Idx_Exclude_Ocean,2]=0
    
#EnergyPu=np.round(EnergyPu*255)#Put data in image format for convenience
#Extend data 25x25> 26x26 to improve in the padding
PlotData_Stage1(0,1,EnergyPu)

max=1
min=0
MaxMin=(max-min)

EnergyPu=(EnergyPu-min)/MaxMin
Idx_Exclude=np.max(EnergyPu_Yearly[:,:,:,1],axis=0)>0.001

Idx_Exclude_Ocean=np.max(EnergyPu_Yearly[:,:,:,2],axis=0)>0.05
Idx_Exclude_Ocean=np.reshape(Idx_Exclude_Ocean*1,(25,25,1))

Idx_Exclude=np.reshape(Idx_Exclude*1,(25,25,1))
Idx_Exclude=np.repeat(Idx_Exclude,2,axis=2)

Idx_Exclude=np.concatenate((Idx_Exclude,Idx_Exclude_Ocean),axis=2)

# %%
def MAKE_GIF (GENERATOR, latent_dim_G, TrainData,ImageShape,number=0):
  for j in range(1):
    X_gan = generate_latent_points(latent_dim_G, 1)
    FakeImage=GENERATOR.predict(X_gan)

    AVG_DATA=np.average(np.reshape(np.abs(FakeImage[:,:,:,:]-TrainData),(TrainData.shape[0],-1)),axis=1)
    IDX_REAL=np.argmin(AVG_DATA)

    RealImage=TrainData[IDX_REAL,:,:,:]
    FakeImage=FakeImage

    count=0
    X_LAT=np.zeros((int(len(Lat)*len(Long))),dtype=float)
    Y_LONG=np.zeros((int(len(Lat)*len(Long))),dtype=float)

    for I_lat in range(len(Lat)):
      for I_long in range(len(Long)):

        Y_LONG[count]=Lat[I_lat]
        X_LAT[count]=Long[I_long]
        count=count+1

    min_longitude=-77
    max_longitude=-74.5

    min_latitude=34
    max_latitude=36.5
    xlim =[min_longitude,max_longitude]
    ylim=[min_latitude, max_latitude]

    ShapeFileCoast="/home/victor-duraes/Projects/Ocean2/GANs/GEO_data/ne_10m_coastline.shp"
    ShapeFileStates="/home/victor-duraes/Projects/Ocean2/GANs/GEO_data/ne_10m_admin_1_states_provinces_lines.shp"

    df = gpd.read_file(ShapeFileCoast)
    df1 = gpd.read_file(ShapeFileStates)

    Real_FLAT=np.zeros((int(RealImage.shape[0]*RealImage.shape[1]),RealImage.shape[2]))
    Fake_FLAT=np.zeros((int(RealImage.shape[0]*RealImage.shape[1]),RealImage.shape[2]))

    for i in range(RealImage.shape[2]):
      Real_FLAT[:,i]=np.reshape(RealImage[:,:,i],-1)
      Fake_FLAT[:,i]=np.reshape(FakeImage[0,:,:,i],-1)

    print("Processing Figure "+str(j))
    fig, axs = plt.subplots(RealImage.shape[2], 2)
    for i in range(RealImage.shape[2]):

      z1_plot=axs[i,0].scatter(X_LAT,Y_LONG,c=Real_FLAT[:,i], s=0.3, cmap='jet')
      df.plot(color='black',linewidth=1,ax=axs[i,0])
      df1.plot(color='black',linewidth=1,ax=axs[i,0])
      axs[i,0].set_xlim(xlim)
      axs[i,0].set_ylim(ylim)
      axs[0,0].set_title('Real Data', fontsize=10)

      axs[i,0].set_xlabel('Longitude', fontsize=10)
      axs[i,0].set_ylabel('Latitude', fontsize=10)


      if i<=1: 
        axs[i,0].get_xaxis().set_visible(False)

      clb=fig.colorbar(z1_plot, ax=axs[i,0])

      z2_plot =axs[i,1].scatter(X_LAT,Y_LONG,c=Fake_FLAT[:,i], s=0.3, cmap='jet')
      df.plot(color='black',linewidth=1,ax=axs[i,1])
      df1.plot(color='black',linewidth=1,ax=axs[i,1])


      if i==0:
        clb.ax.set_title('CF', fontsize=8)
      axs[i,1].set_xlim(xlim)
      axs[i,1].set_ylim(ylim)

      axs[i,1].set_xlabel('Longitude', fontsize=10)
      axs[i,1].set_ylabel('Latitude', fontsize=10)

      if i<=1: 
        axs[i,1].get_xaxis().set_visible(False)

      clb=fig.colorbar(z1_plot, ax=axs[i,1])

      if i==0:
        clb.ax.set_title('CF', fontsize=8)

      if i<=1: 
        axs[i,1].get_xaxis().set_visible(False)
      axs[0,1].set_title('Fake Data', fontsize=10)

    

    plt.savefig('/home/victor-duraes/Projects/Ocean2/GANs/Plots/Iteration'+str(number)+'.png',dpi=400)
    plt.close()

# %%
def MMD(x, y, kernel="rbf"):
    """Emprical maximum mean discrepancy. The lower the result
       the more evidence that distributions are the same.

    Args:
        x: first sample, distribution P
        y: second sample, distribution Q
        kernel: kernel type such as "multiscale" or "rbf"
    """
    device = torch.device("cpu")
    x.to(device)
    y.to(device)

    xx, yy, zz = torch.mm(x, x.t()), torch.mm(y, y.t()), torch.mm(x, y.t())
    rx = (xx.diag().unsqueeze(0).expand_as(xx))
    ry = (yy.diag().unsqueeze(0).expand_as(yy))

    dxx = rx.t() + rx - 2. * xx 
    dyy = ry.t() + ry - 2. * yy 
    dxy = rx.t() + ry - 2. * zz 

    dxx=dxx.to(device)
    dyy=dyy.to(device)
    dxy=dxy.to(device)

    XX, YY, XY = (torch.zeros(xx.shape).to(device),
                  torch.zeros(xx.shape).to(device),
                  torch.zeros(xx.shape).to(device))

    if kernel == "multiscale":
        
        bandwidth_range = [0.2, 0.5, 0.9, 1.3]
        for a in bandwidth_range:
            XX += a**2 * (a**2 + dxx)**-1
            YY += a**2 * (a**2 + dyy)**-1
            XY += a**2 * (a**2 + dxy)**-1
            
    if kernel == "rbf":
      
        bandwidth_range = [10, 15, 20, 50]
        for a in bandwidth_range:
            XX += torch.exp(-0.5*dxx/a)
            YY += torch.exp(-0.5*dyy/a)
            XY += torch.exp(-0.5*dxy/a)
     
    return torch.mean(XX + YY - 2. * XY)

# %%
# implementation of wasserstein loss
def wasserstein_loss(y_true, y_pred):
	return backend.mean(y_true * y_pred)

# clip model weights to a given hypercube
class ClipConstraint(Constraint):
	# set clip value when initialized
	def __init__(self, clip_value):
		self.clip_value = clip_value
 
	# clip model weights to hypercube
	def __call__(self, weights):
		return backend.clip(weights, -self.clip_value, self.clip_value)
 
	# get the config
	def get_config(self):
		return {'clip_value': self.clip_value}

# %%
def Augmentation_Layer(in_shape=[25,25,3]):
    x                = Input(shape=(in_shape[0],in_shape[1],in_shape[2],))

    p                = Input(shape=(6,))#Apply Transformation
    InvP             = Lambda(lambda p: 1. - p)(p) #Not Apply Transformation

    x_shape=x.shape[2]
    y_shape=x.shape[1]
    
    #Reflect Image Reflect image in all directions to assure that minimize the effect of distortions
    ImageFlip_x      = tf.image.flip_left_right(x)
    x_flat           = tf.keras.layers.Reshape((x.shape[1],x.shape[2],x.shape[3]))(x)
    x_temp           = tf.keras.backend.stack([ImageFlip_x, x_flat, ImageFlip_x],axis=2)
    x_temp           = tf.keras.layers.Reshape((y_shape,x_shape*3,3))(x_temp)

    ImageFlip_y      = tf.image.flip_up_down(x_temp)
    x_temp           = tf.keras.backend.stack([ImageFlip_y, x_temp, ImageFlip_y],axis=1)
    x_reflected      = tf.keras.layers.Reshape((y_shape*3,x_shape*3,3))(x_temp)
    y=x_reflected

    #Augmentation 1: Flip-x
    y_temp_1         = tf.keras.layers.RandomFlip(mode="horizontal")(y,training=True)
    y                = tf.keras.layers.Add()([tf.keras.layers.Multiply()([y_temp_1,p[:,0]]), tf.keras.layers.Multiply()([y,InvP[:,0]])]) #Differentiable equation to define if the change will be propagated or not

    #Augmentation 2: 90 Rotations
    K                = Lambda(lambda m: tf.keras.backend.round(tf.squeeze(tf.keras.backend.random_uniform([1],minval=1,maxval=4.1))))(x) 
    K                = tf.cast(K,tf.int32)
    y_temp_2         = tf.image.rot90(y, k=K) #90, 180, 270 degrees
    y                = tf.keras.layers.Add()([tf.keras.layers.Multiply()([y_temp_2, p[:,1]]), tf.keras.layers.Multiply()([y, InvP[:,1]])]) #Differentiable equation to define if the change will be propagated or not

    #Augmentation 3: Translation (will not show outside traning)
    y_temp_3         = tf.keras.layers.experimental.preprocessing.RandomTranslation(0.1, 0.1)(y,training=True)
    y                = tf.keras.layers.Add()([tf.keras.layers.Multiply()([y_temp_3, p[:,2]]), tf.keras.layers.Multiply()([y, InvP[:,2]])]) #Differentiable equation to define if the change will be propagated or not

    #Augmentation 4: Arbitrary Rotation
    y_temp_4         = tf.keras.layers.experimental.preprocessing.RandomRotation(0.5)(y,training=True) #https://docs.w3cub.com/tensorflow~2.3/keras/layers/experimental/preprocessing/randomrotation
    y                = tf.keras.layers.Add()([tf.keras.layers.Multiply()([y_temp_4,p[:,3]]), tf.keras.layers.Multiply()([y,InvP[:,3]])]) #Differentiable equation to define if the change will be propagated or not

    #Augmentation 5: Isotropic Scaling
    y_temp_5         = tf.keras.layers.RandomZoom(0.1)(y,training=True)
    y                = tf.keras.layers.Add()([tf.keras.layers.Multiply()([y_temp_5,p[:,4]]), tf.keras.layers.Multiply()([y,InvP[:,4]])]) #Differentiable equation to define if the change will be propagated or not

    #Augmentation 6: Anisotropic Scaling
    y_temp_6         = tf.keras.layers.RandomZoom(0.1,0.1)(y,training=True)
    y                = tf.keras.layers.Add()([tf.keras.layers.Multiply()([y_temp_6,p[:,5]]), tf.keras.layers.Multiply()([y,InvP[:,5]])]) #Differentiable equation to define if the change will be propagated or not

    #Reduce shape to the Original Size (Last Step)
    y=tf.keras.layers.CenterCrop(25, 25)(y)

    model=Model(inputs=[x,p], outputs=y)
    return model

# %%
def G_Create_CNN(latent_dim_G,Idx_Exclude=Idx_Exclude, in_shape=(25,25,3)):
  x = Input(shape=(latent_dim_G,),name="Image")
  #Layer1

  n_nodes = 512* 4 * 4 # foundation for 4x4 image

  y=Dense(n_nodes)(x)
  y=BatchNormalization()(y)
  y=LeakyReLU(alpha=0.2)(y)
  y=Reshape((4, 4, 512))(y)

  y=Conv2DTranspose(512, (3,3), strides=(2,2), padding='same')(y)
  y=BatchNormalization()(y)
  y=LeakyReLU(alpha=0.2)(y)

  # y=Conv2DTranspose(512, (3,3), strides=(1,1), padding='same')(y)
  # y=BatchNormalization()(y)
  # y=LeakyReLU(alpha=0.2)(y)

  #Layer2
  y=Conv2DTranspose(256, (3,3), strides=(2,2), padding='same')(y)
  y=BatchNormalization()(y)
  y=LeakyReLU(alpha=0.2)(y)

  y=Conv2DTranspose(256, (3,3), strides=(1,1), padding='same')(y)
  y=BatchNormalization()(y)
  y=LeakyReLU(alpha=0.2)(y)

  #Layer3
  y=Conv2DTranspose(256, (3,3), strides=(2,2), padding='same')(y)
  y=BatchNormalization()(y)
  y=LeakyReLU(alpha=0.2)(y)

  # upsample to 40x60
  y=Conv2DTranspose(128, (3,3), strides=(1,1), padding='same')(y)
  y=BatchNormalization()(y)
  y=LeakyReLU(alpha=0.2)(y)


  # output layer
  y=Conv2D(3, (3,3), activation='tanh', padding='same')(y)
  y=Cropping2D(cropping=((4, 3), (4, 3)))(y)
  y=Lambda(lambda InputLayer: InputLayer*Idx_Exclude,input_shape=in_shape)(y)
  model=Model(x, y)

  opt = Adam(learning_rate=0.000002, beta_1=0.5)
  model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])

  return model

# use the generator to generate n fake examples
def generate_fake_samples(GENERATOR, latent_dim_G, n_samples):
  x_input = generate_latent_points(latent_dim_G, n_samples)

  # predict outputs
  X = GENERATOR.predict(x_input)

  # create 'fake' class labels (0)
  y = zeros((n_samples, 1))
  return X, y

def generate_latent_points(latent_dim_G, n_samples):
  x_input = randn(latent_dim_G * n_samples)
  x_input = x_input.reshape(n_samples, latent_dim_G)

  return x_input

# %%
# define the standalone generator model (CNN)
# define the standalone discriminator model

def D_Create_CNN(in_shape=(25,25,3)):
  AugmentModel=Augmentation_Layer(in_shape=[25,25,3])
  AugmentModel.__name__="Augmentation"
  
  # Layer1
  x = Input(shape=(in_shape[0],in_shape[1],in_shape[2],),name="Image")
  p = Input(shape=(6,),name="Maskp")
  y = Lambda(AugmentModel)((x,p))

  y=Conv2D(64, (3,3), padding='same', input_shape=in_shape)(y)
  y=LeakyReLU(alpha=0.2)(y)
  
  y=Conv2D(128, (3,3), padding='same')(y)
  y=LeakyReLU(alpha=0.2)(y)
  
  y=Conv2D(128, (3,3), strides=(2,2), padding='same')(y)
  y=LeakyReLU(alpha=0.2)(y)

  # # Layer2 
  y=Conv2D(256, (3,3), strides=(1,1), padding='same')(y)
  y=LeakyReLU(alpha=0.2)(y)

  y=Conv2D(256, (3,3), strides=(2,2), padding='same')(y)
  y=LeakyReLU(alpha=0.2)(y)

  ##Layer3
  y=Conv2D(512, (3,3), strides=(1,1), padding='same')(y)
  y=LeakyReLU(alpha=0.2)(y)

  y=Conv2D(512, (3,3), strides=(2,2), padding='same')(y)
  y=LeakyReLU(alpha=0.2)(y)

  # #Layer4
  y=Flatten()(y)
  y=Dense(1, activation='sigmoid')(y)
  opt = Adam(learning_rate=0.000002, beta_1=0.5)

  model = Model((x,p), y)
  model.compile(loss='binary_crossentropy', optimizer=opt,metrics=['accuracy'])

  return model

# %%
def GAN_MODEL(GENERATOR,latent_dim_G, DISCRIMINATOR):
	# make weights in the discriminator not trainable
  DISCRIMINATOR.trainable = False

  x= Input(shape=(latent_dim_G,),name='GansLatentD')
  y= GENERATOR(x)
  p= Input(shape=(6,),name='MaskP')
  
  y = DISCRIMINATOR([y,p])

  model=Model((x,p),y)

  opt = Adam(learning_rate=0.000002, beta_1=0.5)
  model.compile(loss='binary_crossentropy', optimizer=opt,metrics=['accuracy'])
  return model

# %%
class KerasBatchGenerator(object):

    def __init__(self, data, batch_size, ImageShape):
        self.data = data
        self.ImageShape=ImageShape #[x, y, # of chanels]
        self.batch_size = batch_size
        # this will track the progress of the batches sequentially through the
        # data set - once the data reaches the end of the data set it will reset
        # back to zero
        self.current_idx = 0

    def generate(self):
        x = np.zeros((self.batch_size, self.ImageShape[0], self.ImageShape[1], self.ImageShape[2]),dtype=float)
        y = np.zeros((self.batch_size, 1),dtype=float)
        while True:
            for i in range(self.batch_size):
                if self.current_idx>= len(self.data):
                    # reset the index back to the start of the data set
                    self.current_idx = 0
                x[i,:,:,:] = self.data[self.current_idx]
                # convert all of temp_y into a one hot representation
                y[i, 0] = 1
                self.current_idx += 1
            yield x, y

# %%
def train(GENERATOR, DISCRIMINATOR, GAN, latent_dim_G, TrainData, batch_size, NumEpochs,ImageShape):
  Prob_Limit=0 #% of time the augmentation is applied
  bat_per_epo = int(TrainData.shape[0] / (batch_size/2))+1
  half_batch = int(batch_size / 2)
  train_data_generator=KerasBatchGenerator (TrainData, half_batch, ImageShape)


  x_torch=torch.from_numpy(np.reshape(TrainData,(TrainData.shape[0],-1))).double()
  KID=[]
  BestKID=999
  count_Extra=1

  dR_hist_L, dF_hist_L, g_hist_L, dR_hist_A, dF_hist_A, g_hist_A = list(), list(), list(), list(), list(), list()
  # manually enumerate epochs
  count_p_update=0
  for i in range(NumEpochs):
    # if i%10==0 and i!=0:
    #   MAKE_GIF (GENERATOR, latent_dim_G, TrainData, ImageShape, number=i)
    #   DISCRIMINATOR.save("/content/drive/My Drive/Colab Notebooks/Ocean2_ScenarioGeneration/SaveStep/DISCRIMINATOR_W"+str(i)+".hdf5")
    #   GENERATOR.save("/content/drive/My Drive/Colab Notebooks/Ocean2_ScenarioGeneration/SaveStep/GENERATOR_W"+str(i)+".hdf5")
    #   GAN.save("/content/drive/My Drive/Colab Notebooks/Ocean2_ScenarioGeneration/SaveStep/GAN_W"+str(i)+".hdf5")
    #   np.savez("/content/drive/My Drive/Colab Notebooks/Ocean2_ScenarioGeneration/SaveStep/PerformanceTrack.npz", dR_hist_L=dR_hist_L, dF_hist_L=dF_hist_L, g_hist_L=g_hist_L, dR_hist_A=dR_hist_A, dF_hist_A=dF_hist_A, KID=KID)

#-------------------------------------------------------------------------------     
#KID
    y_gan, _ = generate_fake_samples(GENERATOR, latent_dim_G, TrainData.shape[0])
    y_torch=torch.from_numpy(np.reshape(y_gan,(y_gan.shape[0],-1))).double()
    KID.append(MMD(x_torch, y_torch, kernel="rbf"))
    if KID[-1]<BestKID and i>=1:
      BestKID=KID[-1]
      #MAKE_GIF (GENERATOR, latent_dim_G, TrainData, ImageShape, number=i)
      #DISCRIMINATOR.save("/home/victor-duraes/Projects/Ocean2/GANs/SaveStep/DISCRIMINATOR_W"+str(i)+".hdf5")
      GENERATOR.save("/home/victor-duraes/Projects/Ocean2/GANs/SaveStep/GENERATOR_W"+str(i)+".hdf5")
      #GAN.save("/home/victor-duraes/Projects/Ocean2/GANs/SaveStep/GAN_W"+str(i)+".hdf5")
      np.savez("/home/victor-duraes/Projects/Ocean2/GANs/SaveStep/PerformanceTrack.npz", dR_hist_L=dR_hist_L, dF_hist_L=dF_hist_L, g_hist_L=g_hist_L, dR_hist_A=dR_hist_A, dF_hist_A=dF_hist_A, KID=KID)



      
#-------------------------------------------------------------------------------  
    
    for j in range(bat_per_epo):

#-------------------------------------------------------------------------------      
      # update discriminator model weights (Real Exmples)
      X_TD,y_TD=next(train_data_generator.generate()) #Get real examples
      p_r=np.random.random((X_TD.shape[0],6))    
      p_r=(p_r<=Prob_Limit)*1# If 1 we appy the augmentation, if 0 we do not apply the augmentation
      history_DR = DISCRIMINATOR.train_on_batch((X_TD,p_r),y_TD, return_dict=True)

      D_lossR = history_DR['loss']
      D_AC_R = history_DR['accuracy']
      dR_hist_L.append(D_lossR)
      dR_hist_A.append(D_AC_R)

 
#-------------------------------------------------------------------------------
      # update discriminator model weights (Fake Exmples)
      X_fake, y_fake = generate_fake_samples(GENERATOR, latent_dim_G, half_batch)
      p_f=np.random.random((X_fake.shape[0],6))    
      p_f=(p_f<=Prob_Limit)*1# If 1 we appy the augmentation, if 0 we do not apply the augmentation
      history_DF = DISCRIMINATOR.train_on_batch((X_fake,p_f), y_fake, return_dict=True)

      D_lossF = history_DF['loss']
      D_AC_F = history_DF['accuracy']
      dF_hist_L.append(D_lossF)
      dF_hist_A.append(D_AC_F)


#-------------------------------------------------------------------------------
      for k in range(count_Extra):#count_Extra
        # prepare points in latent space as input for the generator (update the generator via the discriminator's error)
        X_gan = generate_latent_points(latent_dim_G, batch_size)
        y_gan = ones((batch_size, 1))
        p_f_g=np.random.random((X_gan.shape[0],6))    
        p_f_g=(p_f_g<=Prob_Limit)*1# If 1 we appy the augmentation, if 0 we do not apply the augmentation
        history_G = GAN.train_on_batch((X_gan,p_f_g), y_gan, return_dict=True)

        G_loss = history_G['loss']
        G_AC = history_G['accuracy']
        g_hist_L.append(G_loss)
        g_hist_A.append(G_AC)


#-------------------------------------------------------------------------------      
      # summarize loss on this batch
      print('>%d, %d/%d, DReal=%.3f, DFake=%.3f G_Joker=%.3f-------- DR_AC=%.3f, DF_AC=%.3f G_AC=%.3f \nProb_Limit: %.2f ,KID= %.5f, Extra =%d'  % (i+1, j+1, bat_per_epo, D_lossR, D_lossF, G_loss, D_AC_R, D_AC_F, G_AC, Prob_Limit, KID[-1], count_Extra))	
      
#-------------------------------------------------------------------------------   
      #Update "p" every 4 minibatches as in the original paper      
      count_p_update+=1     	

      if count_p_update==4:
        count_p_update=0
        AverageAccuracy_Discriminator=dF_hist_A[-4:] + dR_hist_A[-4:] #concatenate accuracy of the discriminator for fake and real iamges
        AverageAccuracy_Discriminator=np.mean(AverageAccuracy_Discriminator)

        AverageAccuracy_Generator=g_hist_A[-4:] #concatenate accuracy of the discriminator for fake and real iamges
        AverageAccuracy_Generator=np.mean(AverageAccuracy_Generator)

        if AverageAccuracy_Generator<=0.3: #Value suggested by the paper

          count_Extra=np.minimum(8,count_Extra+1)
        
        if AverageAccuracy_Generator>=0.7:
 
          count_Extra=np.maximum(1,count_Extra-1)


        if AverageAccuracy_Discriminator>=0.6: #Value suggested by the paper
          Prob_Limit=np.minimum(0.8,Prob_Limit+0.01) #Too precise need better gradients. More augmentation
        else:
          Prob_Limit=np.maximum(0,Prob_Limit-0.01)


  return dR_hist_L, dF_hist_L, g_hist_L, dR_hist_A, dF_hist_A, KID


def plot_history(dR_hist_L, dF_hist_L, g_hist_L,dR_hist_A, dF_hist_A):
  # plot loss
  plt.plot(dR_hist_L, label='d-real')
  plt.plot(dF_hist_L, label='d-fake')
  plt.plot(g_hist_L, label='gen')
  plt.legend()

  # save plot to file
  plt.show()
  plt.savefig('/home/victor-duraes/Projects/Ocean2/GANs/Plots/plot_line_plot_loss.png')
  plt.close()

  # plot loss
  plt.plot(dR_hist_A, label='d-real')
  plt.plot(dF_hist_A, label='d-fake')
  plt.legend()

  # save plot to file
  plt.show()
  plt.savefig('/home/victor-duraes/Projects/Ocean2/GANs/Plots/plot_line_plot_accuracy.png')
  plt.close()

# %%
import tensorflow as tf

latent_dim_G=100 #40
batch_size=64#64/2
NumEpochs=10000
ImageShape=EnergyPu.shape[1:]
TrainData=EnergyPu

DISCRIMINATOR=D_Create_CNN(in_shape=ImageShape)
DISCRIMINATOR._name="Discriminator"

GENERATOR=G_Create_CNN(latent_dim_G)
GENERATOR._name="Generator"

GAN=GAN_MODEL(GENERATOR, latent_dim_G, DISCRIMINATOR)

dR_hist_L, dF_hist_L, g_hist_L, dR_hist_A, dF_hist_A, KID=train(GENERATOR, DISCRIMINATOR, GAN, latent_dim_G, TrainData, batch_size, NumEpochs,ImageShape)

plot_history(dR_hist_L, dF_hist_L, g_hist_L, dR_hist_A, dF_hist_A)
MAKE_GIF (GENERATOR, latent_dim_G, TrainData,ImageShape)
# Out:
# >1, 1/80, DReal=0.696, DFake=0.693 G_Joker=0.692-------- DR_AC=0.000, DF_AC=0.000 G_AC=0.766
# Prob_Limit: 0.00 ,KID= 3.83569, Extra =1
# >1, 2/80, DReal=0.695, DFake=0.693 G_Joker=0.691-------- DR_AC=0.000, DF_AC=0.000 G_AC=0.875
# Prob_Limit: 0.00 ,KID= 3.83569, Extra =1
# >1, 3/80, DReal=0.694, DFake=0.693 G_Joker=0.690-------- DR_AC=0.375, DF_AC=0.000 G_AC=0.938
# Prob_Limit: 0.00 ,KID= 3.83569, Extra =1
# >1, 4/80, DReal=0.693, DFake=0.693 G_Joker=0.689-------- DR_AC=0.719, DF_AC=0.000 G_AC=1.000
# Prob_Limit: 0.00 ,KID= 3.83569, Extra =1
# >1, 5/80, DReal=0.692, DFake=0.693 G_Joker=0.689-------- DR_AC=0.938, DF_AC=0.000 G_AC=0.953
# Prob_Limit: 0.00 ,KID= 3.83569, Extra =1
# >1, 6/80, DReal=0.692, DFake=0.693 G_Joker=0.688-------- DR_AC=1.000, DF_AC=0.000 G_AC=1.000
# Prob_Limit: 0.00 ,KID= 3.83569, Extra =1
# >1, 7/80, DReal=0.691, DFake=0.693 G_Joker=0.687-------- DR_AC=1.000, DF_AC=0.000 G_AC=1.000
# Prob_Limit: 0.00 ,KID= 3.83569, Extra =1
# >1, 8/80, DReal=0.690, DFake=0.693 G_Joker=0.686-------- DR_AC=1.000, DF_AC=0.031 G_AC=1.000
# Prob_Limit: 0.00 ,KID= 3.83569, Extra =1
# >1, 9/80, DReal=0.689, DFake=0.693 G_Joker=0.686-------- DR_AC=1.000, DF_AC=0.031 G_AC=1.000
# Prob_Limit: 0.00 ,KID= 3.83569, Extra =1
# >1, 10/80, DReal=0.689, DFake=0.693 G_Joker=0.685-------- DR_AC=1.000, DF_AC=0.031 G_AC=1.000
# Prob_Limit: 0.00 ,KID= 3.83569, Extra =1
# >1, 11/80, DReal=0.688, DFake=0.693 G_Joker=0.684-------- DR_AC=1.000, DF_AC=0.031 G_AC=1.000
# Prob_Limit: 0.00 ,KID= 3.83569, Extra =1
# >1, 12/80, DReal=0.686, DFake=0.693 G_Joker=0.684-------- DR_AC=1.000, DF_AC=0.000 G_AC=1.000
# Prob_Limit: 0.00 ,KID= 3.83569, Extra =1
# >1, 13/80, DReal=0.683, DFake=0.693 G_Joker=0.683-------- DR_AC=1.000, DF_AC=0.000 G_AC=1.000
# Prob_Limit: 0.00 ,KID= 3.83569, Extra =1
# >1, 14/80, DReal=0.683, DFake=0.693 G_Joker=0.682-------- DR_AC=1.000, DF_AC=0.000 G_AC=1.000
# Prob_Limit: 0.00 ,KID= 3.83569, Extra =1
# >1, 15/80, DReal=0.678, DFake=0.693 G_Joker=0.681-------- DR_AC=1.000, DF_AC=0.000 G_AC=1.000
# Prob_Limit: 0.00 ,KID= 3.83569, Extra =1
# >1, 16/80, DReal=0.683, DFake=0.693 G_Joker=0.680-------- DR_AC=1.000, DF_AC=0.000 G_AC=1.000
# Prob_Limit: 0.00 ,KID= 3.83569, Extra =1
# >1, 17/80, DReal=0.685, DFake=0.693 G_Joker=0.679-------- DR_AC=1.000, DF_AC=0.000 G_AC=1.000
# Prob_Limit: 0.00 ,KID= 3.83569, Extra =1
# >1, 18/80, DReal=0.680, DFake=0.693 G_Joker=0.678-------- DR_AC=1.000, DF_AC=0.000 G_AC=1.000
# Prob_Limit: 0.00 ,KID= 3.83569, Extra =1
# >1, 19/80, DReal=0.683, DFake=0.693 G_Joker=0.678-------- DR_AC=1.000, DF_AC=0.000 G_AC=1.000
# Prob_Limit: 0.00 ,KID= 3.83569, Extra =1
# >1, 20/80, DReal=0.677, DFake=0.693 G_Joker=0.676-------- DR_AC=1.000, DF_AC=0.000 G_AC=1.000
# Prob_Limit: 0.00 ,KID= 3.83569, Extra =1
# >1, 21/80, DReal=0.677, DFake=0.693 G_Joker=0.675-------- DR_AC=1.000, DF_AC=0.000 G_AC=1.000
# Prob_Limit: 0.00 ,KID= 3.83569, Extra =1
# >1, 22/80, DReal=0.676, DFake=0.693 G_Joker=0.674-------- DR_AC=1.000, DF_AC=0.000 G_AC=1.000
# Prob_Limit: 0.00 ,KID= 3.83569, Extra =1
# >1, 23/80, DReal=0.673, DFake=0.693 G_Joker=0.673-------- DR_AC=1.000, DF_AC=0.000 G_AC=1.000
# Prob_Limit: 0.00 ,KID= 3.83569, Extra =1
# >1, 24/80, DReal=0.671, DFake=0.693 G_Joker=0.672-------- DR_AC=1.000, DF_AC=0.000 G_AC=1.000
# Prob_Limit: 0.00 ,KID= 3.83569, Extra =1
# >1, 25/80, DReal=0.671, DFake=0.693 G_Joker=0.671-------- DR_AC=1.000, DF_AC=0.000 G_AC=1.000
# Prob_Limit: 0.00 ,KID= 3.83569, Extra =1
# >1, 26/80, DReal=0.664, DFake=0.693 G_Joker=0.670-------- DR_AC=1.000, DF_AC=0.000 G_AC=1.000
# Prob_Limit: 0.00 ,KID= 3.83569, Extra =1
# >1, 27/80, DReal=0.665, DFake=0.693 G_Joker=0.669-------- DR_AC=1.000, DF_AC=0.000 G_AC=1.000
# Prob_Limit: 0.00 ,KID= 3.83569, Extra =1
# >1, 28/80, DReal=0.668, DFake=0.693 G_Joker=0.668-------- DR_AC=1.000, DF_AC=0.000 G_AC=1.000
# Prob_Limit: 0.00 ,KID= 3.83569, Extra =1
# >1, 29/80, DReal=0.673, DFake=0.694 G_Joker=0.667-------- DR_AC=1.000, DF_AC=0.000 G_AC=1.000
# Prob_Limit: 0.00 ,KID= 3.83569, Extra =1
# >1, 30/80, DReal=0.668, DFake=0.694 G_Joker=0.666-------- DR_AC=1.000, DF_AC=0.000 G_AC=1.000
# Prob_Limit: 0.00 ,KID= 3.83569, Extra =1
# >1, 31/80, DReal=0.661, DFake=0.694 G_Joker=0.664-------- DR_AC=1.000, DF_AC=0.000 G_AC=1.000
# Prob_Limit: 0.00 ,KID= 3.83569, Extra =1
# >1, 32/80, DReal=0.662, DFake=0.694 G_Joker=0.663-------- DR_AC=1.000, DF_AC=0.000 G_AC=1.000
# Prob_Limit: 0.00 ,KID= 3.83569, Extra =1
# >1, 33/80, DReal=0.656, DFake=0.694 G_Joker=0.662-------- DR_AC=1.000, DF_AC=0.000 G_AC=1.000
# Prob_Limit: 0.00 ,KID= 3.83569, Extra =1
# >1, 34/80, DReal=0.656, DFake=0.694 G_Joker=0.660-------- DR_AC=1.000, DF_AC=0.000 G_AC=1.000
# Prob_Limit: 0.00 ,KID= 3.83569, Extra =1
# >1, 35/80, DReal=0.656, DFake=0.694 G_Joker=0.659-------- DR_AC=1.000, DF_AC=0.000 G_AC=1.000
# Prob_Limit: 0.00 ,KID= 3.83569, Extra =1
# >1, 36/80, DReal=0.655, DFake=0.694 G_Joker=0.657-------- DR_AC=1.000, DF_AC=0.000 G_AC=1.000
# Prob_Limit: 0.00 ,KID= 3.83569, Extra =1
# >1, 37/80, DReal=0.649, DFake=0.694 G_Joker=0.655-------- DR_AC=1.000, DF_AC=0.000 G_AC=1.000
# Prob_Limit: 0.00 ,KID= 3.83569, Extra =1
# >1, 38/80, DReal=0.662, DFake=0.694 G_Joker=0.654-------- DR_AC=1.000, DF_AC=0.000 G_AC=1.000
# Prob_Limit: 0.00 ,KID= 3.83569, Extra =1
# >1, 39/80, DReal=0.660, DFake=0.694 G_Joker=0.653-------- DR_AC=1.000, DF_AC=0.000 G_AC=1.000
# Prob_Limit: 0.00 ,KID= 3.83569, Extra =1
# >1, 40/80, DReal=0.662, DFake=0.694 G_Joker=0.651-------- DR_AC=1.000, DF_AC=0.000 G_AC=1.000
# Prob_Limit: 0.00 ,KID= 3.83569, Extra =1
# >1, 41/80, DReal=0.653, DFake=0.694 G_Joker=0.650-------- DR_AC=1.000, DF_AC=0.000 G_AC=1.000
# Prob_Limit: 0.00 ,KID= 3.83569, Extra =1
# >1, 42/80, DReal=0.655, DFake=0.694 G_Joker=0.648-------- DR_AC=1.000, DF_AC=0.000 G_AC=1.000
# Prob_Limit: 0.00 ,KID= 3.83569, Extra =1
# >1, 43/80, DReal=0.647, DFake=0.694 G_Joker=0.647-------- DR_AC=1.000, DF_AC=0.000 G_AC=1.000
# Prob_Limit: 0.00 ,KID= 3.83569, Extra =1
# >1, 44/80, DReal=0.647, DFake=0.694 G_Joker=0.645-------- DR_AC=1.000, DF_AC=0.000 G_AC=1.000
# Prob_Limit: 0.00 ,KID= 3.83569, Extra =1
# >1, 45/80, DReal=0.644, DFake=0.694 G_Joker=0.643-------- DR_AC=1.000, DF_AC=0.000 G_AC=1.000
# Prob_Limit: 0.00 ,KID= 3.83569, Extra =1
# >1, 46/80, DReal=0.644, DFake=0.694 G_Joker=0.642-------- DR_AC=1.000, DF_AC=0.000 G_AC=1.000
# Prob_Limit: 0.00 ,KID= 3.83569, Extra =1
# >1, 47/80, DReal=0.642, DFake=0.694 G_Joker=0.640-------- DR_AC=1.000, DF_AC=0.000 G_AC=1.000
# Prob_Limit: 0.00 ,KID= 3.83569, Extra =1
# >1, 48/80, DReal=0.624, DFake=0.694 G_Joker=0.638-------- DR_AC=1.000, DF_AC=0.000 G_AC=1.000
# Prob_Limit: 0.00 ,KID= 3.83569, Extra =1
# >1, 49/80, DReal=0.629, DFake=0.694 G_Joker=0.636-------- DR_AC=1.000, DF_AC=0.000 G_AC=1.000
# Prob_Limit: 0.00 ,KID= 3.83569, Extra =1
# >1, 50/80, DReal=0.622, DFake=0.695 G_Joker=0.634-------- DR_AC=1.000, DF_AC=0.000 G_AC=1.000
# Prob_Limit: 0.00 ,KID= 3.83569, Extra =1
# >1, 51/80, DReal=0.648, DFake=0.695 G_Joker=0.632-------- DR_AC=1.000, DF_AC=0.000 G_AC=1.000
# Prob_Limit: 0.00 ,KID= 3.83569, Extra =1
# >1, 52/80, DReal=0.625, DFake=0.695 G_Joker=0.630-------- DR_AC=1.000, DF_AC=0.000 G_AC=1.000
# Prob_Limit: 0.00 ,KID= 3.83569, Extra =1
# >1, 53/80, DReal=0.641, DFake=0.695 G_Joker=0.627-------- DR_AC=1.000, DF_AC=0.000 G_AC=1.000
# Prob_Limit: 0.00 ,KID= 3.83569, Extra =1
# >1, 54/80, DReal=0.613, DFake=0.695 G_Joker=0.625-------- DR_AC=1.000, DF_AC=0.000 G_AC=1.000
# Prob_Limit: 0.00 ,KID= 3.83569, Extra =1
# >1, 55/80, DReal=0.620, DFake=0.695 G_Joker=0.623-------- DR_AC=1.000, DF_AC=0.000 G_AC=1.000
# Prob_Limit: 0.00 ,KID= 3.83569, Extra =1
# >1, 56/80, DReal=0.608, DFake=0.695 G_Joker=0.620-------- DR_AC=1.000, DF_AC=0.000 G_AC=1.000
# Prob_Limit: 0.00 ,KID= 3.83569, Extra =1
# >1, 57/80, DReal=0.594, DFake=0.695 G_Joker=0.617-------- DR_AC=1.000, DF_AC=0.000 G_AC=1.000
# Prob_Limit: 0.00 ,KID= 3.83569, Extra =1
# >1, 58/80, DReal=0.606, DFake=0.695 G_Joker=0.614-------- DR_AC=1.000, DF_AC=0.000 G_AC=1.000
# Prob_Limit: 0.00 ,KID= 3.83569, Extra =1
# >1, 59/80, DReal=0.613, DFake=0.695 G_Joker=0.612-------- DR_AC=1.000, DF_AC=0.000 G_AC=1.000
# Prob_Limit: 0.00 ,KID= 3.83569, Extra =1
# >1, 60/80, DReal=0.602, DFake=0.695 G_Joker=0.609-------- DR_AC=1.000, DF_AC=0.000 G_AC=1.000
# Prob_Limit: 0.00 ,KID= 3.83569, Extra =1
# >1, 61/80, DReal=0.609, DFake=0.695 G_Joker=0.606-------- DR_AC=1.000, DF_AC=0.000 G_AC=1.000
# Prob_Limit: 0.00 ,KID= 3.83569, Extra =1
# >1, 62/80, DReal=0.590, DFake=0.695 G_Joker=0.603-------- DR_AC=1.000, DF_AC=0.000 G_AC=1.000
# Prob_Limit: 0.00 ,KID= 3.83569, Extra =1
# >1, 63/80, DReal=0.610, DFake=0.696 G_Joker=0.600-------- DR_AC=1.000, DF_AC=0.000 G_AC=1.000
# Prob_Limit: 0.00 ,KID= 3.83569, Extra =1
# >1, 64/80, DReal=0.599, DFake=0.696 G_Joker=0.598-------- DR_AC=1.000, DF_AC=0.000 G_AC=1.000
# Prob_Limit: 0.00 ,KID= 3.83569, Extra =1
# >1, 65/80, DReal=0.606, DFake=0.696 G_Joker=0.594-------- DR_AC=1.000, DF_AC=0.000 G_AC=1.000
# Prob_Limit: 0.00 ,KID= 3.83569, Extra =1
# >1, 66/80, DReal=0.611, DFake=0.696 G_Joker=0.592-------- DR_AC=1.000, DF_AC=0.000 G_AC=1.000
# Prob_Limit: 0.00 ,KID= 3.83569, Extra =1
# >1, 67/80, DReal=0.580, DFake=0.696 G_Joker=0.589-------- DR_AC=1.000, DF_AC=0.000 G_AC=1.000
# Prob_Limit: 0.00 ,KID= 3.83569, Extra =1
# >1, 68/80, DReal=0.574, DFake=0.696 G_Joker=0.585-------- DR_AC=1.000, DF_AC=0.000 G_AC=1.000
# Prob_Limit: 0.00 ,KID= 3.83569, Extra =1
# >1, 69/80, DReal=0.595, DFake=0.696 G_Joker=0.582-------- DR_AC=1.000, DF_AC=0.000 G_AC=1.000
# Prob_Limit: 0.00 ,KID= 3.83569, Extra =1
# >1, 70/80, DReal=0.580, DFake=0.696 G_Joker=0.578-------- DR_AC=1.000, DF_AC=0.000 G_AC=1.000
# Prob_Limit: 0.00 ,KID= 3.83569, Extra =1
# >1, 71/80, DReal=0.550, DFake=0.696 G_Joker=0.574-------- DR_AC=1.000, DF_AC=0.000 G_AC=1.000
# Prob_Limit: 0.00 ,KID= 3.83569, Extra =1
# >1, 72/80, DReal=0.552, DFake=0.696 G_Joker=0.571-------- DR_AC=1.000, DF_AC=0.000 G_AC=1.000
# Prob_Limit: 0.00 ,KID= 3.83569, Extra =1
# >1, 73/80, DReal=0.542, DFake=0.696 G_Joker=0.566-------- DR_AC=1.000, DF_AC=0.000 G_AC=1.000
# Prob_Limit: 0.00 ,KID= 3.83569, Extra =1
# >1, 74/80, DReal=0.560, DFake=0.696 G_Joker=0.562-------- DR_AC=1.000, DF_AC=0.000 G_AC=1.000
# Prob_Limit: 0.00 ,KID= 3.83569, Extra =1
# >1, 75/80, DReal=0.546, DFake=0.695 G_Joker=0.559-------- DR_AC=1.000, DF_AC=0.000 G_AC=1.000
# Prob_Limit: 0.00 ,KID= 3.83569, Extra =1
# >1, 76/80, DReal=0.572, DFake=0.695 G_Joker=0.552-------- DR_AC=1.000, DF_AC=0.000 G_AC=1.000
# Prob_Limit: 0.00 ,KID= 3.83569, Extra =1
# >1, 77/80, DReal=0.554, DFake=0.695 G_Joker=0.549-------- DR_AC=1.000, DF_AC=0.000 G_AC=1.000
# Prob_Limit: 0.00 ,KID= 3.83569, Extra =1
# >1, 78/80, DReal=0.576, DFake=0.695 G_Joker=0.545-------- DR_AC=1.000, DF_AC=0.000 G_AC=1.000
# Prob_Limit: 0.00 ,KID= 3.83569, Extra =1
# >1, 79/80, DReal=0.522, DFake=0.695 G_Joker=0.540-------- DR_AC=1.000, DF_AC=0.000 G_AC=1.000
# Prob_Limit: 0.00 ,KID= 3.83569, Extra =1
# >1, 80/80, DReal=0.521, DFake=0.695 G_Joker=0.534-------- DR_AC=1.000, DF_AC=0.000 G_AC=1.000
# Prob_Limit: 0.00 ,KID= 3.83569, Extra =1
# >2, 1/80, DReal=0.517, DFake=0.695 G_Joker=0.529-------- DR_AC=1.000, DF_AC=0.000 G_AC=1.000
# Prob_Limit: 0.00 ,KID= 4.08633, Extra =1
# >2, 2/80, DReal=0.513, DFake=0.695 G_Joker=0.523-------- DR_AC=1.000, DF_AC=0.000 G_AC=1.000
# Prob_Limit: 0.00 ,KID= 4.08633, Extra =1
# >2, 3/80, DReal=0.522, DFake=0.694 G_Joker=0.518-------- DR_AC=1.000, DF_AC=0.000 G_AC=1.000
# Prob_Limit: 0.00 ,KID= 4.08633, Extra =1
# >2, 4/80, DReal=0.500, DFake=0.694 G_Joker=0.512-------- DR_AC=1.000, DF_AC=0.000 G_AC=1.000
# Prob_Limit: 0.00 ,KID= 4.08633, Extra =1
# >2, 5/80, DReal=0.528, DFake=0.694 G_Joker=0.506-------- DR_AC=1.000, DF_AC=0.000 G_AC=1.000
# Prob_Limit: 0.00 ,KID= 4.08633, Extra =1
# >2, 6/80, DReal=0.556, DFake=0.694 G_Joker=0.501-------- DR_AC=1.000, DF_AC=0.000 G_AC=1.000
# Prob_Limit: 0.00 ,KID= 4.08633, Extra =1
# >2, 7/80, DReal=0.546, DFake=0.693 G_Joker=0.496-------- DR_AC=1.000, DF_AC=0.125 G_AC=1.000
# Prob_Limit: 0.00 ,KID= 4.08633, Extra =1
# >2, 8/80, DReal=0.505, DFake=0.693 G_Joker=0.489-------- DR_AC=1.000, DF_AC=0.688 G_AC=1.000
# Prob_Limit: 0.00 ,KID= 4.08633, Extra =1
# >2, 9/80, DReal=0.512, DFake=0.693 G_Joker=0.486-------- DR_AC=1.000, DF_AC=0.938 G_AC=1.000
# Prob_Limit: 0.01 ,KID= 4.08633, Extra =1
# >2, 10/80, DReal=0.491, DFake=0.692 G_Joker=0.480-------- DR_AC=1.000, DF_AC=0.969 G_AC=1.000
# Prob_Limit: 0.01 ,KID= 4.08633, Extra =1
# >2, 11/80, DReal=0.488, DFake=0.692 G_Joker=0.472-------- DR_AC=1.000, DF_AC=0.906 G_AC=1.000
# Prob_Limit: 0.01 ,KID= 4.08633, Extra =1
# >2, 12/80, DReal=0.473, DFake=0.692 G_Joker=0.463-------- DR_AC=1.000, DF_AC=0.906 G_AC=1.000
# Prob_Limit: 0.01 ,KID= 4.08633, Extra =1
# >2, 13/80, DReal=0.437, DFake=0.691 G_Joker=0.467-------- DR_AC=1.000, DF_AC=0.906 G_AC=1.000
# Prob_Limit: 0.02 ,KID= 4.08633, Extra =1
# >2, 14/80, DReal=0.453, DFake=0.691 G_Joker=0.455-------- DR_AC=1.000, DF_AC=0.969 G_AC=1.000
# Prob_Limit: 0.02 ,KID= 4.08633, Extra =1
# >2, 15/80, DReal=0.393, DFake=0.690 G_Joker=0.448-------- DR_AC=1.000, DF_AC=0.969 G_AC=1.000
# Prob_Limit: 0.02 ,KID= 4.08633, Extra =1
# >2, 16/80, DReal=0.477, DFake=0.690 G_Joker=0.443-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.02 ,KID= 4.08633, Extra =1
# >2, 17/80, DReal=0.518, DFake=0.689 G_Joker=0.436-------- DR_AC=1.000, DF_AC=0.969 G_AC=1.000
# Prob_Limit: 0.03 ,KID= 4.08633, Extra =1
# >2, 18/80, DReal=0.463, DFake=0.689 G_Joker=0.426-------- DR_AC=1.000, DF_AC=0.938 G_AC=1.000
# Prob_Limit: 0.03 ,KID= 4.08633, Extra =1
# >2, 19/80, DReal=0.523, DFake=0.688 G_Joker=0.418-------- DR_AC=1.000, DF_AC=0.938 G_AC=1.000
# Prob_Limit: 0.03 ,KID= 4.08633, Extra =1
# >2, 20/80, DReal=0.441, DFake=0.687 G_Joker=0.416-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.03 ,KID= 4.08633, Extra =1
# >2, 21/80, DReal=0.424, DFake=0.686 G_Joker=0.407-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.04 ,KID= 4.08633, Extra =1
# >2, 22/80, DReal=0.434, DFake=0.686 G_Joker=0.398-------- DR_AC=1.000, DF_AC=0.938 G_AC=1.000
# Prob_Limit: 0.04 ,KID= 4.08633, Extra =1
# >2, 23/80, DReal=0.397, DFake=0.685 G_Joker=0.389-------- DR_AC=1.000, DF_AC=0.938 G_AC=1.000
# Prob_Limit: 0.04 ,KID= 4.08633, Extra =1
# >2, 24/80, DReal=0.414, DFake=0.684 G_Joker=0.381-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.04 ,KID= 4.08633, Extra =1
# >2, 25/80, DReal=0.382, DFake=0.683 G_Joker=0.367-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.05 ,KID= 4.08633, Extra =1
# >2, 26/80, DReal=0.398, DFake=0.682 G_Joker=0.361-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.05 ,KID= 4.08633, Extra =1
# >2, 27/80, DReal=0.356, DFake=0.682 G_Joker=0.366-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.05 ,KID= 4.08633, Extra =1
# >2, 28/80, DReal=0.433, DFake=0.680 G_Joker=0.343-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.05 ,KID= 4.08633, Extra =1
# >2, 29/80, DReal=0.450, DFake=0.680 G_Joker=0.364-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.06 ,KID= 4.08633, Extra =1
# >2, 30/80, DReal=0.424, DFake=0.678 G_Joker=0.343-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.06 ,KID= 4.08633, Extra =1
# >2, 31/80, DReal=0.352, DFake=0.677 G_Joker=0.330-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.06 ,KID= 4.08633, Extra =1
# >2, 32/80, DReal=0.387, DFake=0.675 G_Joker=0.323-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.06 ,KID= 4.08633, Extra =1
# >2, 33/80, DReal=0.302, DFake=0.675 G_Joker=0.327-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.07 ,KID= 4.08633, Extra =1
# >2, 34/80, DReal=0.364, DFake=0.673 G_Joker=0.319-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.07 ,KID= 4.08633, Extra =1
# >2, 35/80, DReal=0.325, DFake=0.672 G_Joker=0.289-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.07 ,KID= 4.08633, Extra =1
# >2, 36/80, DReal=0.341, DFake=0.668 G_Joker=0.274-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.07 ,KID= 4.08633, Extra =1
# >2, 37/80, DReal=0.319, DFake=0.668 G_Joker=0.292-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.08 ,KID= 4.08633, Extra =1
# >2, 38/80, DReal=0.425, DFake=0.666 G_Joker=0.270-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.08 ,KID= 4.08633, Extra =1
# >2, 39/80, DReal=0.403, DFake=0.662 G_Joker=0.272-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.08 ,KID= 4.08633, Extra =1
# >2, 40/80, DReal=0.437, DFake=0.665 G_Joker=0.254-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.08 ,KID= 4.08633, Extra =1
# >2, 41/80, DReal=0.356, DFake=0.658 G_Joker=0.266-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.09 ,KID= 4.08633, Extra =1
# >2, 42/80, DReal=0.382, DFake=0.660 G_Joker=0.260-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.09 ,KID= 4.08633, Extra =1
# >2, 43/80, DReal=0.358, DFake=0.658 G_Joker=0.235-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.09 ,KID= 4.08633, Extra =1
# >2, 44/80, DReal=0.332, DFake=0.652 G_Joker=0.246-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.09 ,KID= 4.08633, Extra =1
# >2, 45/80, DReal=0.349, DFake=0.653 G_Joker=0.251-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.10 ,KID= 4.08633, Extra =1
# >2, 46/80, DReal=0.354, DFake=0.647 G_Joker=0.248-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.10 ,KID= 4.08633, Extra =1
# >2, 47/80, DReal=0.320, DFake=0.644 G_Joker=0.207-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.10 ,KID= 4.08633, Extra =1
# >2, 48/80, DReal=0.236, DFake=0.639 G_Joker=0.227-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.10 ,KID= 4.08633, Extra =1
# >2, 49/80, DReal=0.282, DFake=0.639 G_Joker=0.225-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.11 ,KID= 4.08633, Extra =1
# >2, 50/80, DReal=0.275, DFake=0.637 G_Joker=0.199-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.11 ,KID= 4.08633, Extra =1
# >2, 51/80, DReal=0.376, DFake=0.625 G_Joker=0.206-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.11 ,KID= 4.08633, Extra =1
# >2, 52/80, DReal=0.253, DFake=0.628 G_Joker=0.175-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.11 ,KID= 4.08633, Extra =1
# >2, 53/80, DReal=0.364, DFake=0.621 G_Joker=0.170-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.12 ,KID= 4.08633, Extra =1
# >2, 54/80, DReal=0.247, DFake=0.618 G_Joker=0.188-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.12 ,KID= 4.08633, Extra =1
# >2, 55/80, DReal=0.247, DFake=0.618 G_Joker=0.172-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.12 ,KID= 4.08633, Extra =1
# >2, 56/80, DReal=0.252, DFake=0.614 G_Joker=0.178-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.12 ,KID= 4.08633, Extra =1
# >2, 57/80, DReal=0.214, DFake=0.611 G_Joker=0.153-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.13 ,KID= 4.08633, Extra =1
# >2, 58/80, DReal=0.249, DFake=0.602 G_Joker=0.150-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.13 ,KID= 4.08633, Extra =1
# >2, 59/80, DReal=0.251, DFake=0.607 G_Joker=0.137-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.13 ,KID= 4.08633, Extra =1
# >2, 60/80, DReal=0.240, DFake=0.593 G_Joker=0.141-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.13 ,KID= 4.08633, Extra =1
# >2, 61/80, DReal=0.276, DFake=0.593 G_Joker=0.156-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.14 ,KID= 4.08633, Extra =1
# >2, 62/80, DReal=0.246, DFake=0.592 G_Joker=0.129-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.14 ,KID= 4.08633, Extra =1
# >2, 63/80, DReal=0.284, DFake=0.573 G_Joker=0.146-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.14 ,KID= 4.08633, Extra =1
# >2, 64/80, DReal=0.226, DFake=0.574 G_Joker=0.119-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.14 ,KID= 4.08633, Extra =1
# >2, 65/80, DReal=0.295, DFake=0.559 G_Joker=0.113-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.15 ,KID= 4.08633, Extra =1
# >2, 66/80, DReal=0.279, DFake=0.564 G_Joker=0.113-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.15 ,KID= 4.08633, Extra =1
# >2, 67/80, DReal=0.207, DFake=0.557 G_Joker=0.121-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.15 ,KID= 4.08633, Extra =1
# >2, 68/80, DReal=0.196, DFake=0.554 G_Joker=0.115-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.15 ,KID= 4.08633, Extra =1
# >2, 69/80, DReal=0.284, DFake=0.537 G_Joker=0.091-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.16 ,KID= 4.08633, Extra =1
# >2, 70/80, DReal=0.216, DFake=0.531 G_Joker=0.110-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.16 ,KID= 4.08633, Extra =1
# >2, 71/80, DReal=0.180, DFake=0.526 G_Joker=0.115-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.16 ,KID= 4.08633, Extra =1
# >2, 72/80, DReal=0.144, DFake=0.531 G_Joker=0.097-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.16 ,KID= 4.08633, Extra =1
# >2, 73/80, DReal=0.152, DFake=0.510 G_Joker=0.098-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.17 ,KID= 4.08633, Extra =1
# >2, 74/80, DReal=0.194, DFake=0.521 G_Joker=0.076-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.17 ,KID= 4.08633, Extra =1
# >2, 75/80, DReal=0.163, DFake=0.509 G_Joker=0.091-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.17 ,KID= 4.08633, Extra =1
# >2, 76/80, DReal=0.257, DFake=0.516 G_Joker=0.089-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.17 ,KID= 4.08633, Extra =1
# >2, 77/80, DReal=0.192, DFake=0.474 G_Joker=0.089-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.18 ,KID= 4.08633, Extra =1
# >2, 78/80, DReal=0.244, DFake=0.484 G_Joker=0.073-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.18 ,KID= 4.08633, Extra =1
# >2, 79/80, DReal=0.146, DFake=0.447 G_Joker=0.077-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.18 ,KID= 4.08633, Extra =1
# >2, 80/80, DReal=0.120, DFake=0.467 G_Joker=0.080-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.18 ,KID= 4.08633, Extra =1
# >3, 1/80, DReal=0.157, DFake=0.457 G_Joker=0.077-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.19 ,KID= 3.86085, Extra =1
# >3, 2/80, DReal=0.162, DFake=0.450 G_Joker=0.066-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.19 ,KID= 3.86085, Extra =1
# >3, 3/80, DReal=0.185, DFake=0.429 G_Joker=0.057-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.19 ,KID= 3.86085, Extra =1
# >3, 4/80, DReal=0.146, DFake=0.421 G_Joker=0.061-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.19 ,KID= 3.86085, Extra =1
# >3, 5/80, DReal=0.188, DFake=0.425 G_Joker=0.062-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.20 ,KID= 3.86085, Extra =1
# >3, 6/80, DReal=0.243, DFake=0.416 G_Joker=0.049-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.20 ,KID= 3.86085, Extra =1
# >3, 7/80, DReal=0.211, DFake=0.406 G_Joker=0.042-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.20 ,KID= 3.86085, Extra =1
# >3, 8/80, DReal=0.147, DFake=0.405 G_Joker=0.051-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.20 ,KID= 3.86085, Extra =1
# >3, 9/80, DReal=0.175, DFake=0.381 G_Joker=0.052-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.21 ,KID= 3.86085, Extra =1
# >3, 10/80, DReal=0.160, DFake=0.366 G_Joker=0.063-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.21 ,KID= 3.86085, Extra =1
# >3, 11/80, DReal=0.136, DFake=0.350 G_Joker=0.054-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.21 ,KID= 3.86085, Extra =1
# >3, 12/80, DReal=0.145, DFake=0.362 G_Joker=0.057-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.21 ,KID= 3.86085, Extra =1
# >3, 13/80, DReal=0.108, DFake=0.353 G_Joker=0.045-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.22 ,KID= 3.86085, Extra =1
# >3, 14/80, DReal=0.102, DFake=0.344 G_Joker=0.044-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.22 ,KID= 3.86085, Extra =1
# >3, 15/80, DReal=0.076, DFake=0.333 G_Joker=0.047-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.22 ,KID= 3.86085, Extra =1
# >3, 16/80, DReal=0.167, DFake=0.301 G_Joker=0.047-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.22 ,KID= 3.86085, Extra =1
# >3, 17/80, DReal=0.232, DFake=0.330 G_Joker=0.032-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.23 ,KID= 3.86085, Extra =1
# >3, 18/80, DReal=0.120, DFake=0.316 G_Joker=0.053-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.23 ,KID= 3.86085, Extra =1
# >3, 19/80, DReal=0.204, DFake=0.316 G_Joker=0.031-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.23 ,KID= 3.86085, Extra =1
# >3, 20/80, DReal=0.136, DFake=0.272 G_Joker=0.043-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.23 ,KID= 3.86085, Extra =1
# >3, 21/80, DReal=0.112, DFake=0.276 G_Joker=0.030-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.24 ,KID= 3.86085, Extra =1
# >3, 22/80, DReal=0.157, DFake=0.262 G_Joker=0.031-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.24 ,KID= 3.86085, Extra =1
# >3, 23/80, DReal=0.079, DFake=0.265 G_Joker=0.031-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.24 ,KID= 3.86085, Extra =1
# >3, 24/80, DReal=0.102, DFake=0.270 G_Joker=0.042-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.24 ,KID= 3.86085, Extra =1
# >3, 25/80, DReal=0.091, DFake=0.257 G_Joker=0.022-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.25 ,KID= 3.86085, Extra =1
# >3, 26/80, DReal=0.071, DFake=0.243 G_Joker=0.030-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.25 ,KID= 3.86085, Extra =1
# >3, 27/80, DReal=0.070, DFake=0.242 G_Joker=0.040-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.25 ,KID= 3.86085, Extra =1
# >3, 28/80, DReal=0.175, DFake=0.222 G_Joker=0.025-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.25 ,KID= 3.86085, Extra =1
# >3, 29/80, DReal=0.158, DFake=0.229 G_Joker=0.025-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.26 ,KID= 3.86085, Extra =1
# >3, 30/80, DReal=0.120, DFake=0.211 G_Joker=0.021-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.26 ,KID= 3.86085, Extra =1
# >3, 31/80, DReal=0.075, DFake=0.187 G_Joker=0.025-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.26 ,KID= 3.86085, Extra =1
# >3, 32/80, DReal=0.142, DFake=0.195 G_Joker=0.035-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.26 ,KID= 3.86085, Extra =1
# >3, 33/80, DReal=0.072, DFake=0.173 G_Joker=0.021-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.27 ,KID= 3.86085, Extra =1
# >3, 34/80, DReal=0.067, DFake=0.177 G_Joker=0.024-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.27 ,KID= 3.86085, Extra =1
# >3, 35/80, DReal=0.079, DFake=0.184 G_Joker=0.011-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.27 ,KID= 3.86085, Extra =1
# >3, 36/80, DReal=0.070, DFake=0.158 G_Joker=0.021-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.27 ,KID= 3.86085, Extra =1
# >3, 37/80, DReal=0.083, DFake=0.161 G_Joker=0.029-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.28 ,KID= 3.86085, Extra =1
# >3, 38/80, DReal=0.160, DFake=0.136 G_Joker=0.019-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.28 ,KID= 3.86085, Extra =1
# >3, 39/80, DReal=0.160, DFake=0.160 G_Joker=0.027-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.28 ,KID= 3.86085, Extra =1
# >3, 40/80, DReal=0.202, DFake=0.154 G_Joker=0.018-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.28 ,KID= 3.86085, Extra =1
# >3, 41/80, DReal=0.097, DFake=0.139 G_Joker=0.027-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.29 ,KID= 3.86085, Extra =1
# >3, 42/80, DReal=0.132, DFake=0.138 G_Joker=0.026-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.29 ,KID= 3.86085, Extra =1
# >3, 43/80, DReal=0.076, DFake=0.157 G_Joker=0.018-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.29 ,KID= 3.86085, Extra =1
# >3, 44/80, DReal=0.105, DFake=0.132 G_Joker=0.017-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.29 ,KID= 3.86085, Extra =1
# >3, 45/80, DReal=0.098, DFake=0.119 G_Joker=0.017-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.30 ,KID= 3.86085, Extra =1
# >3, 46/80, DReal=0.105, DFake=0.110 G_Joker=0.012-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.30 ,KID= 3.86085, Extra =1
# >3, 47/80, DReal=0.071, DFake=0.121 G_Joker=0.015-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.30 ,KID= 3.86085, Extra =1
# >3, 48/80, DReal=0.037, DFake=0.110 G_Joker=0.012-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.30 ,KID= 3.86085, Extra =1
# >3, 49/80, DReal=0.046, DFake=0.130 G_Joker=0.022-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.31 ,KID= 3.86085, Extra =1
# >3, 50/80, DReal=0.071, DFake=0.116 G_Joker=0.009-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.31 ,KID= 3.86085, Extra =1
# >3, 51/80, DReal=0.117, DFake=0.130 G_Joker=0.022-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.31 ,KID= 3.86085, Extra =1
# >3, 52/80, DReal=0.073, DFake=0.091 G_Joker=0.012-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.31 ,KID= 3.86085, Extra =1
# >3, 53/80, DReal=0.129, DFake=0.091 G_Joker=0.012-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.32 ,KID= 3.86085, Extra =1
# >3, 54/80, DReal=0.045, DFake=0.097 G_Joker=0.009-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.32 ,KID= 3.86085, Extra =1
# >3, 55/80, DReal=0.035, DFake=0.098 G_Joker=0.012-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.32 ,KID= 3.86085, Extra =1
# >3, 56/80, DReal=0.044, DFake=0.075 G_Joker=0.013-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.32 ,KID= 3.86085, Extra =1
# >3, 57/80, DReal=0.040, DFake=0.070 G_Joker=0.011-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.33 ,KID= 3.86085, Extra =1
# >3, 58/80, DReal=0.056, DFake=0.086 G_Joker=0.008-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.33 ,KID= 3.86085, Extra =1
# >3, 59/80, DReal=0.069, DFake=0.075 G_Joker=0.008-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.33 ,KID= 3.86085, Extra =1
# >3, 60/80, DReal=0.057, DFake=0.077 G_Joker=0.016-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.33 ,KID= 3.86085, Extra =1
# >3, 61/80, DReal=0.087, DFake=0.087 G_Joker=0.008-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.34 ,KID= 3.86085, Extra =1
# >3, 62/80, DReal=0.073, DFake=0.075 G_Joker=0.011-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.34 ,KID= 3.86085, Extra =1
# >3, 63/80, DReal=0.066, DFake=0.110 G_Joker=0.014-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.34 ,KID= 3.86085, Extra =1
# >3, 64/80, DReal=0.054, DFake=0.073 G_Joker=0.014-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.34 ,KID= 3.86085, Extra =1
# >3, 65/80, DReal=0.087, DFake=0.069 G_Joker=0.010-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.35 ,KID= 3.86085, Extra =1
# >3, 66/80, DReal=0.104, DFake=0.075 G_Joker=0.007-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.35 ,KID= 3.86085, Extra =1
# >3, 67/80, DReal=0.073, DFake=0.060 G_Joker=0.014-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.35 ,KID= 3.86085, Extra =1
# >3, 68/80, DReal=0.055, DFake=0.065 G_Joker=0.006-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.35 ,KID= 3.86085, Extra =1
# >3, 69/80, DReal=0.102, DFake=0.069 G_Joker=0.009-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.36 ,KID= 3.86085, Extra =1
# >3, 70/80, DReal=0.058, DFake=0.069 G_Joker=0.011-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.36 ,KID= 3.86085, Extra =1
# >3, 71/80, DReal=0.046, DFake=0.066 G_Joker=0.004-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.36 ,KID= 3.86085, Extra =1
# >3, 72/80, DReal=0.036, DFake=0.067 G_Joker=0.006-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.36 ,KID= 3.86085, Extra =1
# >3, 73/80, DReal=0.034, DFake=0.059 G_Joker=0.017-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.37 ,KID= 3.86085, Extra =1
# >3, 74/80, DReal=0.021, DFake=0.049 G_Joker=0.007-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.37 ,KID= 3.86085, Extra =1
# >3, 75/80, DReal=0.040, DFake=0.080 G_Joker=0.010-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.37 ,KID= 3.86085, Extra =1
# >3, 76/80, DReal=0.071, DFake=0.058 G_Joker=0.004-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.37 ,KID= 3.86085, Extra =1
# >3, 77/80, DReal=0.082, DFake=0.051 G_Joker=0.006-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.38 ,KID= 3.86085, Extra =1
# >3, 78/80, DReal=0.091, DFake=0.048 G_Joker=0.007-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.38 ,KID= 3.86085, Extra =1
# >3, 79/80, DReal=0.040, DFake=0.049 G_Joker=0.005-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.38 ,KID= 3.86085, Extra =1
# >3, 80/80, DReal=0.035, DFake=0.057 G_Joker=0.005-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.38 ,KID= 3.86085, Extra =1
# >4, 1/80, DReal=0.031, DFake=0.044 G_Joker=0.004-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.39 ,KID= 2.20380, Extra =1
# >4, 2/80, DReal=0.051, DFake=0.052 G_Joker=0.009-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.39 ,KID= 2.20380, Extra =1
# >4, 3/80, DReal=0.066, DFake=0.055 G_Joker=0.004-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.39 ,KID= 2.20380, Extra =1
# >4, 4/80, DReal=0.028, DFake=0.047 G_Joker=0.005-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.39 ,KID= 2.20380, Extra =1
# >4, 5/80, DReal=0.051, DFake=0.043 G_Joker=0.003-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.40 ,KID= 2.20380, Extra =1
# >4, 6/80, DReal=0.105, DFake=0.043 G_Joker=0.009-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.40 ,KID= 2.20380, Extra =1
# >4, 7/80, DReal=0.085, DFake=0.043 G_Joker=0.006-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.40 ,KID= 2.20380, Extra =1
# >4, 8/80, DReal=0.043, DFake=0.044 G_Joker=0.007-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.40 ,KID= 2.20380, Extra =1
# >4, 9/80, DReal=0.067, DFake=0.062 G_Joker=0.005-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.41 ,KID= 2.20380, Extra =1
# >4, 10/80, DReal=0.069, DFake=0.041 G_Joker=0.007-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.41 ,KID= 2.20380, Extra =1
# >4, 11/80, DReal=0.059, DFake=0.046 G_Joker=0.003-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.41 ,KID= 2.20380, Extra =1
# >4, 12/80, DReal=0.049, DFake=0.038 G_Joker=0.006-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.41 ,KID= 2.20380, Extra =1
# >4, 13/80, DReal=0.022, DFake=0.025 G_Joker=0.003-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.42 ,KID= 2.20380, Extra =1
# >4, 14/80, DReal=0.034, DFake=0.057 G_Joker=0.006-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.42 ,KID= 2.20380, Extra =1
# >4, 15/80, DReal=0.020, DFake=0.035 G_Joker=0.004-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.42 ,KID= 2.20380, Extra =1
# >4, 16/80, DReal=0.063, DFake=0.050 G_Joker=0.009-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.42 ,KID= 2.20380, Extra =1
# >4, 17/80, DReal=0.104, DFake=0.035 G_Joker=0.002-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.43 ,KID= 2.20380, Extra =1
# >4, 18/80, DReal=0.046, DFake=0.031 G_Joker=0.003-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.43 ,KID= 2.20380, Extra =1
# >4, 19/80, DReal=0.053, DFake=0.049 G_Joker=0.002-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.43 ,KID= 2.20380, Extra =1
# >4, 20/80, DReal=0.066, DFake=0.032 G_Joker=0.001-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.43 ,KID= 2.20380, Extra =1
# >4, 21/80, DReal=0.036, DFake=0.046 G_Joker=0.007-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.44 ,KID= 2.20380, Extra =1
# >4, 22/80, DReal=0.038, DFake=0.043 G_Joker=0.003-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.44 ,KID= 2.20380, Extra =1
# >4, 23/80, DReal=0.038, DFake=0.029 G_Joker=0.005-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.44 ,KID= 2.20380, Extra =1
# >4, 24/80, DReal=0.029, DFake=0.045 G_Joker=0.004-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.44 ,KID= 2.20380, Extra =1
# >4, 25/80, DReal=0.026, DFake=0.041 G_Joker=0.006-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.45 ,KID= 2.20380, Extra =1
# >4, 26/80, DReal=0.010, DFake=0.052 G_Joker=0.002-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.45 ,KID= 2.20380, Extra =1
# >4, 27/80, DReal=0.020, DFake=0.037 G_Joker=0.002-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.45 ,KID= 2.20380, Extra =1
# >4, 28/80, DReal=0.068, DFake=0.035 G_Joker=0.002-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.45 ,KID= 2.20380, Extra =1
# >4, 29/80, DReal=0.043, DFake=0.059 G_Joker=0.002-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.46 ,KID= 2.20380, Extra =1
# >4, 30/80, DReal=0.051, DFake=0.042 G_Joker=0.003-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.46 ,KID= 2.20380, Extra =1
# >4, 31/80, DReal=0.030, DFake=0.037 G_Joker=0.005-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.46 ,KID= 2.20380, Extra =1
# >4, 32/80, DReal=0.071, DFake=0.029 G_Joker=0.004-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.46 ,KID= 2.20380, Extra =1
# >4, 33/80, DReal=0.017, DFake=0.049 G_Joker=0.004-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.47 ,KID= 2.20380, Extra =1
# >4, 34/80, DReal=0.012, DFake=0.043 G_Joker=0.007-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.47 ,KID= 2.20380, Extra =1
# >4, 35/80, DReal=0.044, DFake=0.041 G_Joker=0.003-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.47 ,KID= 2.20380, Extra =1
# >4, 36/80, DReal=0.035, DFake=0.055 G_Joker=0.001-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.47 ,KID= 2.20380, Extra =1
# >4, 37/80, DReal=0.047, DFake=0.052 G_Joker=0.003-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.48 ,KID= 2.20380, Extra =1
# >4, 38/80, DReal=0.083, DFake=0.051 G_Joker=0.010-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.48 ,KID= 2.20380, Extra =1
# >4, 39/80, DReal=0.068, DFake=0.046 G_Joker=0.004-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.48 ,KID= 2.20380, Extra =1
# >4, 40/80, DReal=0.106, DFake=0.045 G_Joker=0.002-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.48 ,KID= 2.20380, Extra =1
# >4, 41/80, DReal=0.016, DFake=0.042 G_Joker=0.001-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.49 ,KID= 2.20380, Extra =1
# >4, 42/80, DReal=0.080, DFake=0.039 G_Joker=0.002-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.49 ,KID= 2.20380, Extra =1
# >4, 43/80, DReal=0.026, DFake=0.049 G_Joker=0.004-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.49 ,KID= 2.20380, Extra =1
# >4, 44/80, DReal=0.037, DFake=0.040 G_Joker=0.005-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.49 ,KID= 2.20380, Extra =1
# >4, 45/80, DReal=0.050, DFake=0.046 G_Joker=0.004-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.50 ,KID= 2.20380, Extra =1
# >4, 46/80, DReal=0.078, DFake=0.039 G_Joker=0.005-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.50 ,KID= 2.20380, Extra =1
# >4, 47/80, DReal=0.032, DFake=0.039 G_Joker=0.002-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.50 ,KID= 2.20380, Extra =1
# >4, 48/80, DReal=0.013, DFake=0.049 G_Joker=0.002-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.50 ,KID= 2.20380, Extra =1
# >4, 49/80, DReal=0.019, DFake=0.067 G_Joker=0.005-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.51 ,KID= 2.20380, Extra =1
# >4, 50/80, DReal=0.039, DFake=0.044 G_Joker=0.003-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.51 ,KID= 2.20380, Extra =1
# >4, 51/80, DReal=0.061, DFake=0.062 G_Joker=0.002-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.51 ,KID= 2.20380, Extra =1
# >4, 52/80, DReal=0.028, DFake=0.047 G_Joker=0.005-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.51 ,KID= 2.20380, Extra =1
# >4, 53/80, DReal=0.048, DFake=0.048 G_Joker=0.001-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.52 ,KID= 2.20380, Extra =1
# >4, 54/80, DReal=0.011, DFake=0.060 G_Joker=0.002-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.52 ,KID= 2.20380, Extra =1
# >4, 55/80, DReal=0.015, DFake=0.065 G_Joker=0.002-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.52 ,KID= 2.20380, Extra =1
# >4, 56/80, DReal=0.026, DFake=0.041 G_Joker=0.001-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.52 ,KID= 2.20380, Extra =1
# >4, 57/80, DReal=0.015, DFake=0.043 G_Joker=0.001-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.53 ,KID= 2.20380, Extra =1
# >4, 58/80, DReal=0.032, DFake=0.050 G_Joker=0.002-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.53 ,KID= 2.20380, Extra =1
# >4, 59/80, DReal=0.030, DFake=0.065 G_Joker=0.003-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.53 ,KID= 2.20380, Extra =1
# >4, 60/80, DReal=0.025, DFake=0.058 G_Joker=0.003-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.53 ,KID= 2.20380, Extra =1
# >4, 61/80, DReal=0.038, DFake=0.042 G_Joker=0.002-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.54 ,KID= 2.20380, Extra =1
# >4, 62/80, DReal=0.040, DFake=0.057 G_Joker=0.003-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.54 ,KID= 2.20380, Extra =1
# >4, 63/80, DReal=0.053, DFake=0.068 G_Joker=0.003-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.54 ,KID= 2.20380, Extra =1
# >4, 64/80, DReal=0.024, DFake=0.062 G_Joker=0.003-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.54 ,KID= 2.20380, Extra =1
# >4, 65/80, DReal=0.037, DFake=0.050 G_Joker=0.002-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.55 ,KID= 2.20380, Extra =1
# >4, 66/80, DReal=0.054, DFake=0.080 G_Joker=0.001-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.55 ,KID= 2.20380, Extra =1
# >4, 67/80, DReal=0.028, DFake=0.075 G_Joker=0.001-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.55 ,KID= 2.20380, Extra =1
# >4, 68/80, DReal=0.059, DFake=0.061 G_Joker=0.003-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.55 ,KID= 2.20380, Extra =1
# >4, 69/80, DReal=0.056, DFake=0.063 G_Joker=0.007-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.56 ,KID= 2.20380, Extra =1
# >4, 70/80, DReal=0.021, DFake=0.065 G_Joker=0.001-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.56 ,KID= 2.20380, Extra =1
# >4, 71/80, DReal=0.014, DFake=0.098 G_Joker=0.001-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.56 ,KID= 2.20380, Extra =1
# >4, 72/80, DReal=0.008, DFake=0.087 G_Joker=0.003-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.56 ,KID= 2.20380, Extra =1
# >4, 73/80, DReal=0.024, DFake=0.070 G_Joker=0.001-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.57 ,KID= 2.20380, Extra =1
# >4, 74/80, DReal=0.010, DFake=0.072 G_Joker=0.001-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.57 ,KID= 2.20380, Extra =1
# >4, 75/80, DReal=0.016, DFake=0.137 G_Joker=0.002-------- DR_AC=1.000, DF_AC=0.969 G_AC=1.000
# Prob_Limit: 0.57 ,KID= 2.20380, Extra =1
# >4, 76/80, DReal=0.032, DFake=0.100 G_Joker=0.001-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.57 ,KID= 2.20380, Extra =1
# >4, 77/80, DReal=0.047, DFake=0.073 G_Joker=0.003-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.58 ,KID= 2.20380, Extra =1
# >4, 78/80, DReal=0.048, DFake=0.136 G_Joker=0.002-------- DR_AC=1.000, DF_AC=0.969 G_AC=1.000
# Prob_Limit: 0.58 ,KID= 2.20380, Extra =1
# >4, 79/80, DReal=0.015, DFake=0.114 G_Joker=0.001-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.58 ,KID= 2.20380, Extra =1
# >4, 80/80, DReal=0.031, DFake=0.136 G_Joker=0.001-------- DR_AC=1.000, DF_AC=0.969 G_AC=1.000
# Prob_Limit: 0.58 ,KID= 2.20380, Extra =1
# >5, 1/80, DReal=0.016, DFake=0.134 G_Joker=0.002-------- DR_AC=1.000, DF_AC=0.969 G_AC=1.000
# Prob_Limit: 0.59 ,KID= 0.84003, Extra =1
# >5, 2/80, DReal=0.013, DFake=0.150 G_Joker=0.002-------- DR_AC=1.000, DF_AC=0.969 G_AC=1.000
# Prob_Limit: 0.59 ,KID= 0.84003, Extra =1
# >5, 3/80, DReal=0.035, DFake=0.102 G_Joker=0.001-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.59 ,KID= 0.84003, Extra =1
# >5, 4/80, DReal=0.010, DFake=0.114 G_Joker=0.002-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.59 ,KID= 0.84003, Extra =1
# >5, 5/80, DReal=0.029, DFake=0.147 G_Joker=0.003-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.60 ,KID= 0.84003, Extra =1
# >5, 6/80, DReal=0.046, DFake=0.158 G_Joker=0.002-------- DR_AC=1.000, DF_AC=0.969 G_AC=1.000
# Prob_Limit: 0.60 ,KID= 0.84003, Extra =1
# >5, 7/80, DReal=0.041, DFake=0.130 G_Joker=0.002-------- DR_AC=1.000, DF_AC=0.969 G_AC=1.000
# Prob_Limit: 0.60 ,KID= 0.84003, Extra =1
# >5, 8/80, DReal=0.021, DFake=0.216 G_Joker=0.005-------- DR_AC=1.000, DF_AC=0.938 G_AC=1.000
# Prob_Limit: 0.60 ,KID= 0.84003, Extra =1
# >5, 9/80, DReal=0.050, DFake=0.130 G_Joker=0.002-------- DR_AC=1.000, DF_AC=1.000 G_AC=1.000
# Prob_Limit: 0.61 ,KID= 0.84003, Extra =1
# >5, 10/80, DReal=0.042, DFake=0.229 G_Joker=0.003-------- DR_AC=1.000, DF_AC=0.938 G_AC=1.000
# Prob_Limit: 0.61 ,KID= 0.84003, Extra =1
# >5, 11/80, DReal=0.034, DFake=0.170 G_Joker=0.002-------- DR_AC=1.000, DF_AC=0.969 G_AC=1.000
# Prob_Limit: 0.61 ,KID= 0.84003, Extra =1
# >5, 12/80, DReal=0.032, DFake=0.223 G_Joker=0.001-------- DR_AC=1.000, DF_AC=0.938 G_AC=1.000
# Prob_Limit: 0.61 ,KID= 0.84003, Extra =1
# >5, 13/80, DReal=0.006, DFake=0.186 G_Joker=0.001-------- DR_AC=1.000, DF_AC=0.938 G_AC=1.000
# Prob_Limit: 0.62 ,KID= 0.84003, Extra =1
# >5, 14/80, DReal=0.013, DFake=0.215 G_Joker=0.002-------- DR_AC=1.000, DF_AC=0.906 G_AC=1.000
# Prob_Limit: 0.62 ,KID= 0.84003, Extra =1
# >5, 15/80, DReal=0.006, DFake=0.255 G_Joker=0.001-------- DR_AC=1.000, DF_AC=0.938 G_AC=1.000
# Prob_Limit: 0.62 ,KID= 0.84003, Extra =1
# >5, 16/80, DReal=0.055, DFake=0.283 G_Joker=0.002-------- DR_AC=1.000, DF_AC=0.875 G_AC=1.000
# Prob_Limit: 0.62 ,KID= 0.84003, Extra =1
# >5, 17/80, DReal=0.033, DFake=0.301 G_Joker=0.002-------- DR_AC=1.000, DF_AC=0.875 G_AC=1.000
# Prob_Limit: 0.63 ,KID= 0.84003, Extra =1
# >5, 18/80, DReal=0.047, DFake=0.329 G_Joker=0.002-------- DR_AC=1.000, DF_AC=0.906 G_AC=1.000
# Prob_Limit: 0.63 ,KID= 0.84003, Extra =1
# >5, 19/80, DReal=0.049, DFake=0.427 G_Joker=0.002-------- DR_AC=1.000, DF_AC=0.781 G_AC=1.000
# Prob_Limit: 0.63 ,KID= 0.84003, Extra =1
# >5, 20/80, DReal=0.038, DFake=0.368 G_Joker=0.001-------- DR_AC=1.000, DF_AC=0.812 G_AC=1.000
# Prob_Limit: 0.63 ,KID= 0.84003, Extra =1
# >5, 21/80, DReal=0.032, DFake=0.355 G_Joker=0.008-------- DR_AC=1.000, DF_AC=0.844 G_AC=1.000
# Prob_Limit: 0.64 ,KID= 0.84003, Extra =1
# >5, 22/80, DReal=0.055, DFake=0.248 G_Joker=0.004-------- DR_AC=1.000, DF_AC=0.938 G_AC=1.000
# Prob_Limit: 0.64 ,KID= 0.84003, Extra =1
# >5, 23/80, DReal=0.021, DFake=0.384 G_Joker=0.002-------- DR_AC=1.000, DF_AC=0.844 G_AC=1.000
# Prob_Limit: 0.64 ,KID= 0.84003, Extra =1
# >5, 24/80, DReal=0.010, DFake=0.450 G_Joker=0.001-------- DR_AC=1.000, DF_AC=0.812 G_AC=1.000
# Prob_Limit: 0.64 ,KID= 0.84003, Extra =1
# >5, 25/80, DReal=0.030, DFake=0.282 G_Joker=0.001-------- DR_AC=1.000, DF_AC=0.906 G_AC=1.000
# Prob_Limit: 0.65 ,KID= 0.84003, Extra =1
# >5, 26/80, DReal=0.012, DFake=0.340 G_Joker=0.002-------- DR_AC=1.000, DF_AC=0.781 G_AC=1.000
# Prob_Limit: 0.65 ,KID= 0.84003, Extra =1
# >5, 27/80, DReal=0.015, DFake=0.354 G_Joker=0.003-------- DR_AC=1.000, DF_AC=0.875 G_AC=1.000
# Prob_Limit: 0.65 ,KID= 0.84003, Extra =1
# >5, 28/80, DReal=0.059, DFake=0.354 G_Joker=0.002-------- DR_AC=1.000, DF_AC=0.812 G_AC=1.000
# Prob_Limit: 0.65 ,KID= 0.84003, Extra =1
# >5, 29/80, DReal=0.058, DFake=0.573 G_Joker=0.003-------- DR_AC=1.000, DF_AC=0.781 G_AC=1.000
# Prob_Limit: 0.66 ,KID= 0.84003, Extra =1
# >5, 30/80, DReal=0.076, DFake=0.382 G_Joker=0.004-------- DR_AC=1.000, DF_AC=0.844 G_AC=1.000
# Prob_Limit: 0.66 ,KID= 0.84003, Extra =1
# >5, 31/80, DReal=0.033, DFake=0.435 G_Joker=0.005-------- DR_AC=1.000, DF_AC=0.812 G_AC=1.000
# Prob_Limit: 0.66 ,KID= 0.84003, Extra =1
# >5, 32/80, DReal=0.051, DFake=0.457 G_Joker=0.003-------- DR_AC=1.000, DF_AC=0.844 G_AC=1.000
# Prob_Limit: 0.66 ,KID= 0.84003, Extra =1
# >5, 33/80, DReal=0.026, DFake=0.494 G_Joker=0.004-------- DR_AC=1.000, DF_AC=0.688 G_AC=1.000
# Prob_Limit: 0.67 ,KID= 0.84003, Extra =1
# ...
# Prob_Limit: 0.49 ,KID= 3.42294, Extra =8
# >11, 58/80, DReal=0.799, DFake=0.469 G_Joker=1.228-------- DR_AC=0.156, DF_AC=0.938 G_AC=0.109
# Prob_Limit: 0.49 ,KID= 3.42294, Extra =8
# >11, 59/80, DReal=0.721, DFake=0.463 G_Joker=1.195-------- DR_AC=0.531, DF_AC=0.781 G_AC=0.094
# Prob_Limit: 0.49 ,KID= 3.42294, Extra =8
# >11, 60/80, DReal=0.783, DFake=0.451 G_Joker=1.053-------- DR_AC=0.312, DF_AC=0.906 G_AC=0.062
# Prob_Limit: 0.49 ,KID= 3.42294, Extra =8
# >11, 61/80, DReal=0.762, DFake=0.484 G_Joker=1.157-------- DR_AC=0.344, DF_AC=0.969 G_AC=0.109
# Prob_Limit: 0.48 ,KID= 3.42294, Extra =8
# >11, 62/80, DReal=0.735, DFake=0.462 G_Joker=1.048-------- DR_AC=0.312, DF_AC=0.844 G_AC=0.109
# Prob_Limit: 0.48 ,KID= 3.42294, Extra =8
# >11, 63/80, DReal=0.733, DFake=0.445 G_Joker=1.287-------- DR_AC=0.344, DF_AC=0.938 G_AC=0.031
# Prob_Limit: 0.48 ,KID= 3.42294, Extra =8
# >11, 64/80, DReal=0.768, DFake=0.463 G_Joker=1.177-------- DR_AC=0.188, DF_AC=0.781 G_AC=0.078
# Prob_Limit: 0.48 ,KID= 3.42294, Extra =8
# >11, 65/80, DReal=0.706, DFake=0.488 G_Joker=1.283-------- DR_AC=0.406, DF_AC=0.906 G_AC=0.062
# Prob_Limit: 0.47 ,KID= 3.42294, Extra =8
# >11, 66/80, DReal=0.761, DFake=0.454 G_Joker=1.238-------- DR_AC=0.375, DF_AC=0.906 G_AC=0.062
# Prob_Limit: 0.47 ,KID= 3.42294, Extra =8
# >11, 67/80, DReal=0.711, DFake=0.483 G_Joker=1.207-------- DR_AC=0.375, DF_AC=0.969 G_AC=0.047
# Prob_Limit: 0.47 ,KID= 3.42294, Extra =8
# >11, 68/80, DReal=0.743, DFake=0.501 G_Joker=1.174-------- DR_AC=0.344, DF_AC=0.781 G_AC=0.031
# Prob_Limit: 0.47 ,KID= 3.42294, Extra =8
# >11, 69/80, DReal=0.712, DFake=0.444 G_Joker=1.137-------- DR_AC=0.406, DF_AC=0.969 G_AC=0.031
# Prob_Limit: 0.48 ,KID= 3.42294, Extra =8
# >11, 70/80, DReal=0.695, DFake=0.441 G_Joker=1.047-------- DR_AC=0.469, DF_AC=0.938 G_AC=0.078
# Prob_Limit: 0.48 ,KID= 3.42294, Extra =8
# >11, 71/80, DReal=0.699, DFake=0.494 G_Joker=1.215-------- DR_AC=0.438, DF_AC=0.938 G_AC=0.047
# Prob_Limit: 0.48 ,KID= 3.42294, Extra =8
# >11, 72/80, DReal=0.676, DFake=0.467 G_Joker=1.354-------- DR_AC=0.594, DF_AC=0.812 G_AC=0.094
# Prob_Limit: 0.48 ,KID= 3.42294, Extra =8
# >11, 73/80, DReal=0.710, DFake=0.470 G_Joker=1.108-------- DR_AC=0.406, DF_AC=0.938 G_AC=0.078
# Prob_Limit: 0.49 ,KID= 3.42294, Extra =8
# >11, 74/80, DReal=0.754, DFake=0.445 G_Joker=1.146-------- DR_AC=0.406, DF_AC=0.969 G_AC=0.094
# Prob_Limit: 0.49 ,KID= 3.42294, Extra =8
# >11, 75/80, DReal=0.736, DFake=0.530 G_Joker=1.140-------- DR_AC=0.406, DF_AC=0.812 G_AC=0.188
# Prob_Limit: 0.49 ,KID= 3.42294, Extra =8
# >11, 76/80, DReal=0.781, DFake=0.521 G_Joker=1.149-------- DR_AC=0.250, DF_AC=0.875 G_AC=0.094
# Prob_Limit: 0.49 ,KID= 3.42294, Extra =8
# >11, 77/80, DReal=0.654, DFake=0.516 G_Joker=1.156-------- DR_AC=0.594, DF_AC=0.844 G_AC=0.016
# Prob_Limit: 0.50 ,KID= 3.42294, Extra =8
# >11, 78/80, DReal=0.738, DFake=0.478 G_Joker=1.138-------- DR_AC=0.312, DF_AC=0.969 G_AC=0.141
# Prob_Limit: 0.50 ,KID= 3.42294, Extra =8
# >11, 79/80, DReal=0.680, DFake=0.512 G_Joker=1.188-------- DR_AC=0.594, DF_AC=0.875 G_AC=0.094
# Prob_Limit: 0.50 ,KID= 3.42294, Extra =8
# >11, 80/80, DReal=0.718, DFake=0.528 G_Joker=1.180-------- DR_AC=0.438, DF_AC=0.812 G_AC=0.094
# Prob_Limit: 0.50 ,KID= 3.42294, Extra =8
# >12, 1/80, DReal=0.747, DFake=0.484 G_Joker=1.247-------- DR_AC=0.344, DF_AC=0.875 G_AC=0.016
# Prob_Limit: 0.51 ,KID= 3.55987, Extra =8
# >12, 2/80, DReal=0.758, DFake=0.507 G_Joker=1.053-------- DR_AC=0.250, DF_AC=0.812 G_AC=0.141
# Prob_Limit: 0.51 ,KID= 3.55987, Extra =8
# >12, 3/80, DReal=0.750, DFake=0.460 G_Joker=1.193-------- DR_AC=0.438, DF_AC=0.906 G_AC=0.109
# Prob_Limit: 0.51 ,KID= 3.55987, Extra =8
# >12, 4/80, DReal=0.749, DFake=0.496 G_Joker=1.150-------- DR_AC=0.312, DF_AC=0.875 G_AC=0.062
# Prob_Limit: 0.51 ,KID= 3.55987, Extra =8
# >12, 5/80, DReal=0.718, DFake=0.499 G_Joker=1.372-------- DR_AC=0.375, DF_AC=0.844 G_AC=0.172
# Prob_Limit: 0.52 ,KID= 3.55987, Extra =8
# >12, 6/80, DReal=0.803, DFake=0.472 G_Joker=1.251-------- DR_AC=0.188, DF_AC=0.938 G_AC=0.125
# Prob_Limit: 0.52 ,KID= 3.55987, Extra =8
# >12, 7/80, DReal=0.757, DFake=0.500 G_Joker=1.245-------- DR_AC=0.344, DF_AC=0.969 G_AC=0.172
# Prob_Limit: 0.52 ,KID= 3.55987, Extra =8
# >12, 8/80, DReal=0.741, DFake=0.495 G_Joker=1.253-------- DR_AC=0.281, DF_AC=0.844 G_AC=0.062
# Prob_Limit: 0.52 ,KID= 3.55987, Extra =8
# >12, 9/80, DReal=0.719, DFake=0.480 G_Joker=1.221-------- DR_AC=0.406, DF_AC=1.000 G_AC=0.062
# Prob_Limit: 0.51 ,KID= 3.55987, Extra =8
# >12, 10/80, DReal=0.721, DFake=0.527 G_Joker=1.119-------- DR_AC=0.344, DF_AC=0.844 G_AC=0.078
# Prob_Limit: 0.51 ,KID= 3.55987, Extra =8
# >12, 11/80, DReal=0.733, DFake=0.447 G_Joker=1.194-------- DR_AC=0.281, DF_AC=0.844 G_AC=0.094
# Prob_Limit: 0.51 ,KID= 3.55987, Extra =8
# >12, 12/80, DReal=0.715, DFake=0.438 G_Joker=1.066-------- DR_AC=0.375, DF_AC=0.938 G_AC=0.047
# Prob_Limit: 0.51 ,KID= 3.55987, Extra =8
# >12, 13/80, DReal=0.804, DFake=0.434 G_Joker=1.067-------- DR_AC=0.156, DF_AC=0.906 G_AC=0.062
# Prob_Limit: 0.52 ,KID= 3.55987, Extra =8
# >12, 14/80, DReal=0.690, DFake=0.473 G_Joker=1.189-------- DR_AC=0.531, DF_AC=0.969 G_AC=0.062
# Prob_Limit: 0.52 ,KID= 3.55987, Extra =8
# >12, 15/80, DReal=0.721, DFake=0.555 G_Joker=1.019-------- DR_AC=0.438, DF_AC=0.781 G_AC=0.109
# Prob_Limit: 0.52 ,KID= 3.55987, Extra =8
# >12, 16/80, DReal=0.753, DFake=0.482 G_Joker=1.227-------- DR_AC=0.188, DF_AC=0.906 G_AC=0.141
# Prob_Limit: 0.52 ,KID= 3.55987, Extra =8
# >12, 17/80, DReal=0.845, DFake=0.557 G_Joker=1.050-------- DR_AC=0.094, DF_AC=0.844 G_AC=0.141
# Prob_Limit: 0.53 ,KID= 3.55987, Extra =8
# >12, 18/80, DReal=0.821, DFake=0.430 G_Joker=1.134-------- DR_AC=0.156, DF_AC=0.938 G_AC=0.047
# Prob_Limit: 0.53 ,KID= 3.55987, Extra =8
# >12, 19/80, DReal=0.743, DFake=0.523 G_Joker=1.265-------- DR_AC=0.375, DF_AC=0.812 G_AC=0.047
# Prob_Limit: 0.53 ,KID= 3.55987, Extra =8
# >12, 20/80, DReal=0.771, DFake=0.496 G_Joker=1.166-------- DR_AC=0.250, DF_AC=0.906 G_AC=0.062
# Prob_Limit: 0.53 ,KID= 3.55987, Extra =8
# >12, 21/80, DReal=0.732, DFake=0.421 G_Joker=1.044-------- DR_AC=0.281, DF_AC=0.969 G_AC=0.141
# Prob_Limit: 0.52 ,KID= 3.55987, Extra =8
# >12, 22/80, DReal=0.745, DFake=0.442 G_Joker=1.152-------- DR_AC=0.312, DF_AC=0.969 G_AC=0.109
# Prob_Limit: 0.52 ,KID= 3.55987, Extra =8
# >12, 23/80, DReal=0.722, DFake=0.468 G_Joker=1.036-------- DR_AC=0.344, DF_AC=0.906 G_AC=0.109
# Prob_Limit: 0.52 ,KID= 3.55987, Extra =8
# >12, 24/80, DReal=0.695, DFake=0.498 G_Joker=1.217-------- DR_AC=0.500, DF_AC=0.812 G_AC=0.109
# Prob_Limit: 0.52 ,KID= 3.55987, Extra =8
# >12, 25/80, DReal=0.673, DFake=0.529 G_Joker=1.171-------- DR_AC=0.625, DF_AC=0.875 G_AC=0.109
# Prob_Limit: 0.53 ,KID= 3.55987, Extra =8
# >12, 26/80, DReal=0.701, DFake=0.555 G_Joker=1.292-------- DR_AC=0.469, DF_AC=0.875 G_AC=0.047
# Prob_Limit: 0.53 ,KID= 3.55987, Extra =8
# >12, 27/80, DReal=0.755, DFake=0.526 G_Joker=1.084-------- DR_AC=0.312, DF_AC=0.875 G_AC=0.125
# Prob_Limit: 0.53 ,KID= 3.55987, Extra =8
# >12, 28/80, DReal=0.708, DFake=0.515 G_Joker=1.023-------- DR_AC=0.406, DF_AC=0.875 G_AC=0.188
# Prob_Limit: 0.53 ,KID= 3.55987, Extra =8
# >12, 29/80, DReal=0.813, DFake=0.457 G_Joker=0.998-------- DR_AC=0.250, DF_AC=0.938 G_AC=0.062
# Prob_Limit: 0.54 ,KID= 3.55987, Extra =8
# >12, 30/80, DReal=0.777, DFake=0.459 G_Joker=0.996-------- DR_AC=0.281, DF_AC=0.812 G_AC=0.047
# Prob_Limit: 0.54 ,KID= 3.55987, Extra =8
# >12, 31/80, DReal=0.733, DFake=0.497 G_Joker=0.974-------- DR_AC=0.438, DF_AC=0.844 G_AC=0.094
# Prob_Limit: 0.54 ,KID= 3.55987, Extra =8
# >12, 32/80, DReal=0.644, DFake=0.535 G_Joker=1.088-------- DR_AC=0.656, DF_AC=0.812 G_AC=0.156
# Prob_Limit: 0.54 ,KID= 3.55987, Extra =8
# >12, 33/80, DReal=0.711, DFake=0.507 G_Joker=1.135-------- DR_AC=0.312, DF_AC=0.812 G_AC=0.094
# Prob_Limit: 0.55 ,KID= 3.55987, Extra =8
# >12, 34/80, DReal=0.696, DFake=0.533 G_Joker=1.090-------- DR_AC=0.531, DF_AC=0.875 G_AC=0.109
# Prob_Limit: 0.55 ,KID= 3.55987, Extra =8
# >12, 35/80, DReal=0.698, DFake=0.546 G_Joker=1.056-------- DR_AC=0.500, DF_AC=0.875 G_AC=0.078
# Prob_Limit: 0.55 ,KID= 3.55987, Extra =8
# >12, 36/80, DReal=0.654, DFake=0.535 G_Joker=1.144-------- DR_AC=0.562, DF_AC=0.844 G_AC=0.125
# Prob_Limit: 0.55 ,KID= 3.55987, Extra =8
# >12, 37/80, DReal=0.702, DFake=0.502 G_Joker=1.161-------- DR_AC=0.438, DF_AC=0.969 G_AC=0.125
# Prob_Limit: 0.56 ,KID= 3.55987, Extra =8
# >12, 38/80, DReal=0.715, DFake=0.441 G_Joker=1.101-------- DR_AC=0.375, DF_AC=0.938 G_AC=0.078
# Prob_Limit: 0.56 ,KID= 3.55987, Extra =8
# >12, 39/80, DReal=0.835, DFake=0.537 G_Joker=1.160-------- DR_AC=0.062, DF_AC=0.750 G_AC=0.062
# Prob_Limit: 0.56 ,KID= 3.55987, Extra =8
# >12, 40/80, DReal=0.799, DFake=0.535 G_Joker=1.068-------- DR_AC=0.219, DF_AC=0.875 G_AC=0.031
# Prob_Limit: 0.56 ,KID= 3.55987, Extra =8
# >12, 41/80, DReal=0.725, DFake=0.490 G_Joker=1.131-------- DR_AC=0.406, DF_AC=0.906 G_AC=0.062
# Prob_Limit: 0.55 ,KID= 3.55987, Extra =8
# >12, 42/80, DReal=0.764, DFake=0.520 G_Joker=1.042-------- DR_AC=0.281, DF_AC=0.875 G_AC=0.047
# Prob_Limit: 0.55 ,KID= 3.55987, Extra =8
# >12, 43/80, DReal=0.718, DFake=0.442 G_Joker=1.115-------- DR_AC=0.281, DF_AC=0.875 G_AC=0.000
# Prob_Limit: 0.55 ,KID= 3.55987, Extra =8
# >12, 44/80, DReal=0.708, DFake=0.422 G_Joker=1.353-------- DR_AC=0.406, DF_AC=0.969 G_AC=0.031
# Prob_Limit: 0.55 ,KID= 3.55987, Extra =8
# >12, 45/80, DReal=0.722, DFake=0.524 G_Joker=1.131-------- DR_AC=0.344, DF_AC=0.938 G_AC=0.000
# Prob_Limit: 0.56 ,KID= 3.55987, Extra =8
# >12, 46/80, DReal=0.711, DFake=0.480 G_Joker=1.060-------- DR_AC=0.406, DF_AC=0.906 G_AC=0.016
# Prob_Limit: 0.56 ,KID= 3.55987, Extra =8
# >12, 47/80, DReal=0.700, DFake=0.495 G_Joker=1.282-------- DR_AC=0.438, DF_AC=0.875 G_AC=0.031
# Prob_Limit: 0.56 ,KID= 3.55987, Extra =8
# >12, 48/80, DReal=0.699, DFake=0.466 G_Joker=1.076-------- DR_AC=0.406, DF_AC=0.969 G_AC=0.078
# Prob_Limit: 0.56 ,KID= 3.55987, Extra =8
# >12, 49/80, DReal=0.709, DFake=0.495 G_Joker=1.055-------- DR_AC=0.406, DF_AC=0.875 G_AC=0.031
# Prob_Limit: 0.57 ,KID= 3.55987, Extra =8
# >12, 50/80, DReal=0.736, DFake=0.495 G_Joker=1.100-------- DR_AC=0.375, DF_AC=0.906 G_AC=0.047
# Prob_Limit: 0.57 ,KID= 3.55987, Extra =8
# >12, 51/80, DReal=0.795, DFake=0.513 G_Joker=1.105-------- DR_AC=0.250, DF_AC=0.844 G_AC=0.078
# Prob_Limit: 0.57 ,KID= 3.55987, Extra =8
# >12, 52/80, DReal=0.811, DFake=0.509 G_Joker=1.059-------- DR_AC=0.250, DF_AC=0.812 G_AC=0.016
# Prob_Limit: 0.57 ,KID= 3.55987, Extra =8
# >12, 53/80, DReal=0.741, DFake=0.488 G_Joker=1.008-------- DR_AC=0.281, DF_AC=0.906 G_AC=0.094
# Prob_Limit: 0.56 ,KID= 3.55987, Extra =8
# >12, 54/80, DReal=0.696, DFake=0.559 G_Joker=0.955-------- DR_AC=0.500, DF_AC=0.875 G_AC=0.047
# Prob_Limit: 0.56 ,KID= 3.55987, Extra =8
# >12, 55/80, DReal=0.708, DFake=0.540 G_Joker=1.079-------- DR_AC=0.500, DF_AC=0.969 G_AC=0.062
# Prob_Limit: 0.56 ,KID= 3.55987, Extra =8
# >12, 56/80, DReal=0.690, DFake=0.466 G_Joker=1.115-------- DR_AC=0.625, DF_AC=0.969 G_AC=0.031
# Prob_Limit: 0.56 ,KID= 3.55987, Extra =8
# >12, 57/80, DReal=0.762, DFake=0.527 G_Joker=1.192-------- DR_AC=0.375, DF_AC=0.906 G_AC=0.109
# Prob_Limit: 0.57 ,KID= 3.55987, Extra =8
# >12, 58/80, DReal=0.759, DFake=0.461 G_Joker=1.171-------- DR_AC=0.250, DF_AC=0.969 G_AC=0.047
# Prob_Limit: 0.57 ,KID= 3.55987, Extra =8
# >12, 59/80, DReal=0.738, DFake=0.518 G_Joker=1.064-------- DR_AC=0.312, DF_AC=0.938 G_AC=0.172
# Prob_Limit: 0.57 ,KID= 3.55987, Extra =8
# >12, 60/80, DReal=0.767, DFake=0.534 G_Joker=1.152-------- DR_AC=0.281, DF_AC=0.875 G_AC=0.109
# Prob_Limit: 0.57 ,KID= 3.55987, Extra =8
# >12, 61/80, DReal=0.722, DFake=0.513 G_Joker=1.103-------- DR_AC=0.375, DF_AC=0.938 G_AC=0.062
# Prob_Limit: 0.58 ,KID= 3.55987, Extra =8
# >12, 62/80, DReal=0.701, DFake=0.550 G_Joker=1.034-------- DR_AC=0.344, DF_AC=0.875 G_AC=0.109
# Prob_Limit: 0.58 ,KID= 3.55987, Extra =8
# >12, 63/80, DReal=0.727, DFake=0.525 G_Joker=1.051-------- DR_AC=0.375, DF_AC=0.938 G_AC=0.078
# Prob_Limit: 0.58 ,KID= 3.55987, Extra =8
# >12, 64/80, DReal=0.762, DFake=0.511 G_Joker=0.937-------- DR_AC=0.344, DF_AC=0.844 G_AC=0.125
# Prob_Limit: 0.58 ,KID= 3.55987, Extra =8
# >12, 65/80, DReal=0.717, DFake=0.460 G_Joker=1.203-------- DR_AC=0.375, DF_AC=0.969 G_AC=0.047
# Prob_Limit: 0.59 ,KID= 3.55987, Extra =8
# >12, 66/80, DReal=0.732, DFake=0.505 G_Joker=1.054-------- DR_AC=0.500, DF_AC=0.969 G_AC=0.031
# Prob_Limit: 0.59 ,KID= 3.55987, Extra =8
# >12, 67/80, DReal=0.734, DFake=0.441 G_Joker=1.034-------- DR_AC=0.312, DF_AC=0.906 G_AC=0.062
# Prob_Limit: 0.59 ,KID= 3.55987, Extra =8
# >12, 68/80, DReal=0.750, DFake=0.502 G_Joker=1.034-------- DR_AC=0.281, DF_AC=0.938 G_AC=0.000
# Prob_Limit: 0.59 ,KID= 3.55987, Extra =8
# >12, 69/80, DReal=0.715, DFake=0.539 G_Joker=0.932-------- DR_AC=0.281, DF_AC=0.906 G_AC=0.062
# Prob_Limit: 0.60 ,KID= 3.55987, Extra =8
# >12, 70/80, DReal=0.724, DFake=0.547 G_Joker=1.126-------- DR_AC=0.406, DF_AC=0.844 G_AC=0.031
# Prob_Limit: 0.60 ,KID= 3.55987, Extra =8
# >12, 71/80, DReal=0.691, DFake=0.482 G_Joker=1.016-------- DR_AC=0.531, DF_AC=1.000 G_AC=0.094
# Prob_Limit: 0.60 ,KID= 3.55987, Extra =8
# >12, 72/80, DReal=0.703, DFake=0.539 G_Joker=1.099-------- DR_AC=0.469, DF_AC=0.938 G_AC=0.078
# Prob_Limit: 0.60 ,KID= 3.55987, Extra =8
# >12, 73/80, DReal=0.715, DFake=0.547 G_Joker=1.081-------- DR_AC=0.469, DF_AC=0.844 G_AC=0.078
# Prob_Limit: 0.61 ,KID= 3.55987, Extra =8
# >12, 74/80, DReal=0.746, DFake=0.501 G_Joker=0.980-------- DR_AC=0.312, DF_AC=0.812 G_AC=0.094
# Prob_Limit: 0.61 ,KID= 3.55987, Extra =8
# >12, 75/80, DReal=0.735, DFake=0.514 G_Joker=0.965-------- DR_AC=0.375, DF_AC=0.938 G_AC=0.172
# Prob_Limit: 0.61 ,KID= 3.55987, Extra =8
# >12, 76/80, DReal=0.742, DFake=0.504 G_Joker=1.018-------- DR_AC=0.312, DF_AC=0.969 G_AC=0.047
# Prob_Limit: 0.61 ,KID= 3.55987, Extra =8
# >12, 77/80, DReal=0.693, DFake=0.520 G_Joker=0.989-------- DR_AC=0.438, DF_AC=0.938 G_AC=0.062
# Prob_Limit: 0.62 ,KID= 3.55987, Extra =8
# >12, 78/80, DReal=0.734, DFake=0.457 G_Joker=0.871-------- DR_AC=0.312, DF_AC=0.906 G_AC=0.141
# Prob_Limit: 0.62 ,KID= 3.55987, Extra =8
# >12, 79/80, DReal=0.678, DFake=0.510 G_Joker=0.917-------- DR_AC=0.625, DF_AC=0.844 G_AC=0.188
# Prob_Limit: 0.62 ,KID= 3.55987, Extra =8
# >12, 80/80, DReal=0.690, DFake=0.550 G_Joker=1.000-------- DR_AC=0.562, DF_AC=0.781 G_AC=0.094
# Prob_Limit: 0.62 ,KID= 3.55987, Extra =8
# >13, 1/80, DReal=0.755, DFake=0.551 G_Joker=1.073-------- DR_AC=0.312, DF_AC=0.875 G_AC=0.141
# Prob_Limit: 0.63 ,KID= 3.64378, Extra =8
# >13, 2/80, DReal=0.719, DFake=0.526 G_Joker=0.911-------- DR_AC=0.375, DF_AC=0.875 G_AC=0.062
# Prob_Limit: 0.63 ,KID= 3.64378, Extra =8
# >13, 3/80, DReal=0.753, DFake=0.535 G_Joker=0.932-------- DR_AC=0.344, DF_AC=0.750 G_AC=0.219
# Prob_Limit: 0.63 ,KID= 3.64378, Extra =8
# >13, 4/80, DReal=0.732, DFake=0.540 G_Joker=0.970-------- DR_AC=0.406, DF_AC=0.875 G_AC=0.125
# Prob_Limit: 0.63 ,KID= 3.64378, Extra =8
# >13, 5/80, DReal=0.747, DFake=0.483 G_Joker=0.956-------- DR_AC=0.281, DF_AC=0.906 G_AC=0.031
# Prob_Limit: 0.64 ,KID= 3.64378, Extra =8
# >13, 6/80, DReal=0.788, DFake=0.534 G_Joker=0.951-------- DR_AC=0.219, DF_AC=0.844 G_AC=0.109
# Prob_Limit: 0.64 ,KID= 3.64378, Extra =8
# >13, 7/80, DReal=0.737, DFake=0.493 G_Joker=1.023-------- DR_AC=0.219, DF_AC=0.938 G_AC=0.031
# Prob_Limit: 0.64 ,KID= 3.64378, Extra =8
# >13, 8/80, DReal=0.710, DFake=0.492 G_Joker=0.979-------- DR_AC=0.344, DF_AC=0.938 G_AC=0.031
# Prob_Limit: 0.64 ,KID= 3.64378, Extra =8
# >13, 9/80, DReal=0.698, DFake=0.501 G_Joker=0.906-------- DR_AC=0.500, DF_AC=0.844 G_AC=0.078
# Prob_Limit: 0.63 ,KID= 3.64378, Extra =8
# >13, 10/80, DReal=0.675, DFake=0.509 G_Joker=0.988-------- DR_AC=0.594, DF_AC=0.969 G_AC=0.047
# Prob_Limit: 0.63 ,KID= 3.64378, Extra =8
# >13, 11/80, DReal=0.717, DFake=0.537 G_Joker=1.012-------- DR_AC=0.406, DF_AC=0.781 G_AC=0.094
# Prob_Limit: 0.63 ,KID= 3.64378, Extra =8
# >13, 12/80, DReal=0.720, DFake=0.526 G_Joker=1.054-------- DR_AC=0.406, DF_AC=0.875 G_AC=0.062
# Prob_Limit: 0.63 ,KID= 3.64378, Extra =8
# >13, 13/80, DReal=0.769, DFake=0.555 G_Joker=0.919-------- DR_AC=0.344, DF_AC=0.719 G_AC=0.125
# Prob_Limit: 0.64 ,KID= 3.64378, Extra =8

# %%
#historical Values
Save=[]
from tqdm import tqdm

Step_T=7

for i in tqdm(range(1000)):
    EnergyPu=EnergyPu[np.random.permutation(EnergyPu.shape[0]),:,:,:]

    x=EnergyPu[Step_T*0:Step_T*1,:,:,:]
    y=EnergyPu[Step_T*1:Step_T*2,:,:,:]
    x_torch=torch.from_numpy(np.reshape(x,(x.shape[0],-1))).double()
    y_torch=torch.from_numpy(np.reshape(y,(y.shape[0],-1))).double()

    Save.append(MMD(x_torch, y_torch, kernel="rbf"))
 
Save=np.array(Save)
plt.boxplot(Save)  
plt.show()
# Out:
# 100%|██████████| 1000/1000 [00:05<00:00, 166.68it/s]

# %%
plt.boxplot(Save)  
plt.show()
A=Save

# %%
#synthetic Values
Save=[]
def generate_latent_points(latent_dim_G, n_samples):
  x_input = randn(latent_dim_G * n_samples)
  x_input = x_input.reshape(n_samples, latent_dim_G)

  return x_input

GENERATOR = load_model("/home/victor-duraes/Projects/Ocean2/GANs/SaveStep/GENERATOR_C2.hdf5")
latent_dim_G=GENERATOR.input_shape[1]
n_samples=365


from tqdm import tqdm
for i in tqdm(range(1000)):
    x_input=generate_latent_points(latent_dim_G, n_samples)
    y=(GENERATOR.predict(x_input))
    y[y<0]=0
    y[:,Idx_Exclude]=0

    x_input=generate_latent_points(latent_dim_G, n_samples)
    x=(GENERATOR.predict(x_input))
    x[x<0]=0
    x[:,Idx_Exclude]=0

    x_torch=torch.from_numpy(np.reshape(x,(x.shape[0],-1))).double()
    y_torch=torch.from_numpy(np.reshape(y,(y.shape[0],-1))).double()

    Save.append(MMD(x_torch, y_torch, kernel="rbf"))
 
Save=np.array(Save)
plt.boxplot(Save)  
plt.show()
# Out:
# 100%|██████████| 1000/1000 [03:33<00:00,  4.68it/s]

# %%
RealData=A
SyntheticData=Save
plt.boxplot([RealData,SyntheticData])
plt.show()

# %%
#KID comparison Real with Synthetic
KID_RS=[]
def generate_latent_points(latent_dim_G, n_samples):
  x_input = randn(latent_dim_G * n_samples)
  x_input = x_input.reshape(n_samples, latent_dim_G)

  return x_input

GENERATOR = load_model("/home/victor-duraes/Projects/Ocean2/GANs/SaveStep/GENERATOR_C2.hdf5")
latent_dim_G=GENERATOR.input_shape[1]
n_samples=365

from tqdm import tqdm
for i in tqdm(range(1000)):
    x_input=generate_latent_points(latent_dim_G, n_samples)
    y=(GENERATOR.predict(x_input))
    y[y<0]=0
    y[:,Idx_Exclude]=0

    EnergyPu=EnergyPu[np.random.permutation(EnergyPu.shape[0]),:,:,:]
    x=EnergyPu[0:n_samples,:,:,:]

    x_torch=torch.from_numpy(np.reshape(x,(x.shape[0],-1))).double()
    y_torch=torch.from_numpy(np.reshape(y,(y.shape[0],-1))).double()

    KID_RS.append(MMD(x_torch, y_torch, kernel="rbf"))
 
KID_RS=np.array(KID_RS)
# Out:
# 100%|██████████| 1000/1000 [01:57<00:00,  8.52it/s]

# %%
RealData=A
SyntheticData=Save
plt.boxplot([KID_RS,SyntheticData])
plt.show()

# %%
plt.boxplot([KID_RS])
plt.show()

# %%
#Evaluate Model
from tqdm import tqdm
from keras.models import load_model
def generate_latent_points(latent_dim_G, n_samples):
  x_input = randn(latent_dim_G * n_samples)
  x_input = x_input.reshape(n_samples, latent_dim_G)

  return x_input

Save=[]
Index_i=[]
for i in tqdm(np.arange(0,500,1)):
  try:
    GENERATOR = load_model("/home/victor-duraes/Projects/Ocean2/GANs/SaveStep/GENERATOR_W"+str(i)+".hdf5")
    latent_dim_G=GENERATOR.input_shape[1]
    n_samples=2557
    x_input=generate_latent_points(latent_dim_G, n_samples)
    Y=(GENERATOR.predict(x_input))
    EnergyPu=EnergyPu[np.random.permutation(EnergyPu.shape[0]),:,:,:]

    x=EnergyPu
 
    x_torch=torch.from_numpy(np.reshape(x,(x.shape[0],-1))).double()
    y_torch=torch.from_numpy(np.reshape(Y,(Y.shape[0],-1))).double()

    Save.append(MMD(x_torch, y_torch, kernel="rbf"))
    Index_i.append(i)
  except:
    pass
Save=np.array(Save)
plt.plot(Index_i, Save)  
plt.show()
# Out:
# 100%|██████████| 500/500 [02:05<00:00,  3.98it/s]

# %%
Index_i[39]
# Out:
# 84

# %%
np.min(Save)
# Out:
# 0.5818812
